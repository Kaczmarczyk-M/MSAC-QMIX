# %%
# %pip install stable-baselines3 numpy torch supersuit pettingzoo pymunk scipy gymnasium matplotlib einops tensorboard wandb imageio
# Out:
# Requirement already satisfied: stable-baselines3 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (2.4.1)
# Requirement already satisfied: numpy in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (1.26.4)
# Requirement already satisfied: torch in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: supersuit in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (3.9.3)
# Requirement already satisfied: pettingzoo in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (1.24.3)
# Requirement already satisfied: pymunk in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (6.10.0)
# Requirement already satisfied: scipy in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (1.15.0)
# Requirement already satisfied: gymnasium in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (0.29.1)
# Requirement already satisfied: matplotlib in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (3.9.2)
# Requirement already satisfied: einops in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (0.8.0)
# Requirement already satisfied: tensorboard in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (2.18.0)
# Requirement already satisfied: wandb in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (0.19.4)
# Requirement already satisfied: imageio in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (2.35.0)
# Requirement already satisfied: cloudpickle in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from stable-baselines3) (3.0.0)
# Requirement already satisfied: pandas in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from stable-baselines3) (2.2.3)
# Requirement already satisfied: filelock in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from torch) (1.13.2)
# Requirement already satisfied: networkx in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from torch) (2024.6.1)
# Requirement already satisfied: tinyscaler>=1.2.6 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from supersuit) (1.2.8)
# Requirement already satisfied: cffi>=1.17.1 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from pymunk) (1.17.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: absl-py>=0.4 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from tensorboard) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from tensorboard) (1.69.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from tensorboard) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from tensorboard) (5.29.3)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from tensorboard) (72.2.0)
# Requirement already satisfied: six>1.9 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from tensorboard) (3.1.3)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from wandb) (3.1.44)
# Requirement already satisfied: platformdirs in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from wandb) (4.2.2)
# Requirement already satisfied: psutil>=5.0.0 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from wandb) (6.0.0)
# Requirement already satisfied: pydantic<3,>=2.6 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from wandb) (2.10.5)
# Requirement already satisfied: pyyaml in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from wandb) (2.20.0)
# Requirement already satisfied: setproctitle in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from wandb) (1.3.4)
# Requirement already satisfied: pycparser in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from cffi>=1.17.1->pymunk) (2.22)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from pydantic<3,>=2.6->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from pydantic<3,>=2.6->wandb) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.5)
# Requirement already satisfied: pytz>=2020.1 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from pandas->stable-baselines3) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from pandas->stable-baselines3) (2024.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import datetime
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import random
from collections import deque
from typing import List, Dict, NamedTuple
import gymnasium as gym
from pettingzoo.mpe import simple_spread_v3
import os
from torch.utils.tensorboard import SummaryWriter
from argparse import Namespace
import time
import sys
import json


class WritterUtil:
    def __init__(self, writter: SummaryWriter, args):
        self.writter = writter
        self.log_every = args.log_every
        self.scalars = {}
        self.step = 0
        self.log_step = 0

    def set_step(self, step):
        self.step += 1
        self.log_step = step

    def WriteScalar(self, tag, value):
        
        step = self.step
        log_step = self.log_step
        self.writter.add_scalar('raw/'+tag, value, log_step)

        if tag not in self.scalars:
            self.scalars[tag] = [0, step-1, torch.zeros(self.log_every)]
        
        n, last_step, buffer = self.scalars[tag]
        
        buffer[n] = value
        n += 1
        if step - last_step >= self.log_every:
            mean = torch.mean(buffer[0:n])
            self.writter.add_scalar('mean/'+tag, mean, log_step)
            self.writter.add_histogram(tag, buffer[0:n], log_step)
            
            last_step = step
            n=0


        self.scalars[tag] = [n,last_step,buffer]

class Controller:
    def __init__(self, sys_agent, args):
        self.n_agents = args.n_agents
        self.n_actions = args.n_actions        
        self.agent_id = args.agent_id
        self.last_action = args.last_action
        self.device = args.device    
        self.sys_agent_src = sys_agent
        self.sys_agent = type(sys_agent)(args)        
        self.sys_agent.requires_grad_(False)        
        self.episode = 0

    def new_episode(self):
        state_dict = self.sys_agent_src.state_dict()
        self.sys_agent.load_state_dict(state_dict)        
        self.hiddens = self.sys_agent.init_hiddens(1)
        self.last_actions = torch.zeros(1, self.n_agents, self.n_actions)      
        self.episode += 1

    def get_actions(self, states, avail_actions, explore=False):
        # Explicit tensor conversion with device and dtype
        states = torch.tensor(states, dtype=torch.float32, device=self.device)
        if states.dim() == 2:
            states = states.unsqueeze(0)
                
        avail_actions = torch.tensor(avail_actions, dtype=torch.float32, device=self.device)
        if avail_actions.dim() == 2:
            avail_actions = avail_actions.unsqueeze(0)
            
        if self.agent_id:
            agent_ids = torch.eye(self.n_agents, device=self.device)
            agent_ids = agent_ids.unsqueeze(0).expand(states.size(0), -1, -1)
            states = torch.cat([states, agent_ids], dim=-1)
        
        if self.last_action:            
            states = torch.cat([states, self.last_actions], -1)
        
        with torch.no_grad():
            ps, hs_next = self.sys_agent.forward(states, avail_actions, self.hiddens)
        self.hiddens = hs_next
        
        # Action selection with validation
        if explore:
            while True:
                actions = torch.multinomial(ps[0], 1).squeeze(-1)
                selected_avails = avail_actions[0][torch.arange(self.n_agents), actions]
                if not (selected_avails == 0).sum().item():
                    break
        else:
            actions = torch.argmax(ps[0], -1)
        
        self.last_actions = self.one_hot(actions, self.n_actions).unsqueeze(0)
        return actions.cpu().numpy()

    def one_hot(self, tensor, n_classes):
        return F.one_hot(tensor.to(dtype=torch.int64), n_classes).to(dtype=torch.float32)



class Actor(nn.Module):
    def __init__(self, args):
        super(Actor, self).__init__()
        self.args = args

        self.input_dim = args.input_dim        
        self.n_actions = args.n_actions
        self.n_agents = args.n_agents
        self.rnn_hidden_dim = args.rnn_hidden_dim

        self.fc1 = nn.Linear(self.input_dim, self.rnn_hidden_dim)
        self.rnn = nn.GRUCell(self.rnn_hidden_dim, self.rnn_hidden_dim)
        self.fc2 = nn.Linear(self.rnn_hidden_dim, self.n_actions)

    def init_hidden(self, n_batch):
        # make hidden states on same device as model
        return self.fc1.weight.new_zeros(n_batch, self.rnn_hidden_dim)

    def forward(self, inputs, avail_actions, h_last):
        
        h = F.relu(self.fc1(inputs))        
        h = self.rnn(h, h_last)
        y = self.fc2(h)
        y[avail_actions == 0] = -float('inf')
        y = torch.softmax(y,-1)

        return y,h
    
class Actors(nn.Module):
    def __init__(self, args):
        super(Actors, self).__init__()
        self.n_agents = args.n_agents
        self.n_actions = args.n_actions
        self.agent = Actor(args)

    def init_hiddens(self, n_batch):
        hiddens = self.agent.init_hidden(n_batch*self.n_agents)
        hiddens = hiddens.reshape(n_batch,self.n_agents,-1)
        return hiddens

    def forward(self, states, avail_actions, hiddens):
        n_batch = states.shape[0]
        states = states.reshape(-1,states.shape[-1])
        hiddens = hiddens.reshape(-1,hiddens.shape[-1])
        avail_actions = avail_actions.reshape(-1,avail_actions.shape[-1])
        ys, hs_next = self.agent.forward(states, avail_actions, hiddens)
        ys = ys.reshape(n_batch,self.n_agents,-1)
        hs_next = hs_next.reshape(n_batch,self.n_agents,-1)
        
        return ys, hs_next

class Critic(nn.Module):
    def __init__(self, args):
        super(Critic, self).__init__()
        self.args = args

        self.input_dim = args.input_dim
        
        self.n_actions = args.n_actions
        self.n_agents = args.n_agents
        self.rnn_hidden_dim = args.rnn_hidden_dim

        self.fc1 = nn.Linear(self.input_dim, self.rnn_hidden_dim)
        self.rnn = nn.GRUCell(self.rnn_hidden_dim, self.rnn_hidden_dim)
        self.fc2 = nn.Linear(self.rnn_hidden_dim, self.n_actions)

    def init_hidden(self, n_batch):
        # make hidden states on same device as model
        return self.fc1.weight.new_zeros(n_batch, self.rnn_hidden_dim)

    def forward(self, inputs, avail_actions, h_last):
        # x = torch.cat([inputs, action],1)
        h = F.relu(self.fc1(inputs))
        h = self.rnn(h, h_last)
        y = self.fc2(h)
        y[avail_actions == 0] = -1e38
        return y, h

class Critics(nn.Module):
    def __init__(self, args):
        super(Critics, self).__init__()
        self.n_agents = args.n_agents
        self.n_actions = args.n_actions
        self.agent = Critic(args)



    def init_hiddens(self, n_batch):
        hiddens = self.agent.init_hidden(n_batch*self.n_agents)
        hiddens = hiddens.reshape(n_batch,self.n_agents,-1)
        return hiddens

    def forward(self, states, avail_actions, hiddens):

        n_batch = states.shape[0]
        states = states.reshape(-1,states.shape[-1])
        hiddens = hiddens.reshape(-1,hiddens.shape[-1])
        avail_actions = avail_actions.reshape(-1,avail_actions.shape[-1])
        ys, hs_next = self.agent.forward(states, avail_actions, hiddens)
        ys = ys.reshape(n_batch,self.n_agents,-1)
        hs_next = hs_next.reshape(n_batch,self.n_agents,-1)
        
        return ys, hs_next



class EpisodeBuffer:
    def __init__(self, scheme, args):
        self.scheme = scheme.copy()
        self.buffer_size = args.buffer_size
        self.max_seq_length = args.episode_limit
        # self.device = args.device
        self.device = 'cpu'
        self._setup_data()

    def _setup_data(self):
        self.index_st = 0
        self.n_sample = 0

        self.data = {}
        for k, v in self.scheme.items():
            shape = (self.buffer_size, self.max_seq_length) + v['shape']
            self.data[k] = torch.zeros(shape, dtype=v['dtype'],device=self.device)

    def sample(self, batch_size, top_n = 0):
        if self.n_sample < batch_size:
            return None

        def trans_ids(ep_id):
            ep_id += self.index_st
            ep_id %= self.buffer_size
            return ep_id

        ep_ids = np.random.choice(self.n_sample - top_n, batch_size - top_n, replace=False)
        ep_ids = list(ep_ids) + [self.n_sample-i-1 for i in range(top_n)]# [self.n_sample -1]
        ep_ids = list(map(trans_ids, ep_ids))

        ret = {}
        for k, v in self.data.items():
            ret[k] = v[ep_ids]

        return ret
    

    def add_episode(self, data):

        #len_ep = len
        if self.n_sample < self.buffer_size:
            self.n_sample += 1
        else:
            self.index_st += 1
            self.index_st %= self.buffer_size

        index_ep = (self.index_st + self.n_sample - 1) % self.buffer_size
        
        for k, v in data.items():

            ep_len = len(v)
            dtype = self.scheme[k]['dtype']
            self.data[k][index_ep].zero_()
            self.data[k][index_ep, 0:ep_len] = torch.as_tensor(v, dtype=dtype, device=self.device)

    def clear(self):
        self.index_st = 0
        self.n_sample = 0
        for item in self.data.values():
            item.zero_()
        

    def state_dict(self):
        buffer_state = {'index_st': self.index_st, 'n_sample': self.n_sample, 'data': self.data}
        return buffer_state
    
    def load_state_dict(self, state_dict):
        self.index_st = state_dict['index_st']
        self.n_sample = state_dict['n_sample']    
        self.data = state_dict['data']

class QMixNet(nn.Module):
    def __init__(self, args):
        super(QMixNet, self).__init__()
        self.args = args
        # 因为生成的hyper_w1需要是一个矩阵，而pytorch神经网络只能输出一个向量，
        # 所以就先输出长度为需要的 矩阵行*矩阵列 的向量，然后再转化成矩阵

        # args.n_agents是使用hyper_w1作为参数的网络的输入维度，args.qmix_hidden_dim是网络隐藏层参数个数
        # 从而经过hyper_w1得到(经验条数，args.n_agents * args.qmix_hidden_dim)的矩阵
        
        input_dim = args.state_dim
        
        self.input_dim = input_dim
        self.hyper_w1 = nn.Linear(input_dim, args.n_agents * args.qmix_hidden_dim)
        # 经过hyper_w2得到(经验条数, 1)的矩阵
        self.hyper_w2 = nn.Linear(input_dim, args.qmix_hidden_dim * 1)

        # hyper_w1得到的(经验条数，args.qmix_hidden_dim)矩阵需要同样维度的hyper_b1
        self.hyper_b1 = nn.Linear(input_dim, args.qmix_hidden_dim)
        # hyper_w2得到的(经验条数，1)的矩阵需要同样维度的hyper_b1
        self.hyper_b2 =nn.Sequential(nn.Linear(input_dim, args.qmix_hidden_dim),
                                     nn.ReLU(),
                                     nn.Linear(args.qmix_hidden_dim, 1)
                                     )

    def forward(self, q_values, states):  # states的shape为(episode_num, max_episode_len， state_dim)
        # 传入的q_values是三维的，shape为(episode_num, max_episode_len， n_agents)
        episode_num = q_values.size(0)
        q_values = q_values.view(-1, 1, self.args.n_agents)  # (episode_num * max_episode_len, 1, n_agents) = (1920,1,5)
        states = states.reshape(-1, self.input_dim)  # (episode_num * max_episode_len, state_dim)

        w1 = torch.abs(self.hyper_w1(states))  # (1920, 160)
        b1 = self.hyper_b1(states)  # (1920, 32)

        w1 = w1.view(-1, self.args.n_agents, self.args.qmix_hidden_dim)  # (1920, 5, 32)
        b1 = b1.view(-1, 1, self.args.qmix_hidden_dim)  # (1920, 1, 32)

        hidden = F.elu(torch.bmm(q_values, w1) + b1)  # (1920, 1, 32)

        w2 = torch.abs(self.hyper_w2(states))  # (1920, 32)
        b2 = self.hyper_b2(states)  # (1920, 1)

        w2 = w2.view(-1, self.args.qmix_hidden_dim, 1)  # (1920, 32, 1)
        b2 = b2.view(-1, 1, 1)  # (1920, 1， 1)

        q_total = torch.bmm(hidden, w2) + b2  # (1920, 1, 1)
        q_total = q_total.view(episode_num, -1, 1)  # (32, 60, 1)
        return q_total

class Learner:
    def __init__(self, w_util, args):
        
        self.w_util = w_util
        self.device = args.device
        self.critic_attn = args.critic_attn

        # if self.critic_attn:                        
        #     from .attn_critics import Critics
        # else:            
        #     from .critics import Critics

        self.sys_actor = Actors(args)
        self.sys_critic1 = Critics(args)
        self.sys_critic2 = Critics(args)
        self.sys_critic1_tar = Critics(args)
        self.sys_critic2_tar = Critics(args)
        #self.sys_critic1.train()
        #self.sys_critic2.train()
    
        self.mix_net1 = QMixNet(args)        
        self.mix_net2 = QMixNet(args)        
        self.mix_net1_tar = QMixNet(args)
        self.mix_net2_tar = QMixNet(args)
        
        if self.device != 'cpu':
            self.sys_actor.cuda(self.device)
            self.sys_critic1.cuda(self.device)
            self.sys_critic2.cuda(self.device)
            self.sys_critic1_tar.cuda(self.device)
            self.sys_critic2_tar.cuda(self.device)
            self.mix_net1.cuda(self.device)
            self.mix_net2.cuda(self.device)
            self.mix_net1_tar.cuda(self.device)
            self.mix_net2_tar.cuda(self.device)
        
        self.sys_critic1_tar.requires_grad_(False)
        self.sys_critic2_tar.requires_grad_(False)
        self.mix_net1_tar.requires_grad_(False)
        self.mix_net2_tar.requires_grad_(False)



        self._sync_target()

        
        self.n_agents = args.n_agents
        self.n_actions = args.n_actions
        self.gamma = args.gamma
        self.entropy_tar = args.entropy_tar
        self.lr = args.lr
        self.lr_actor = args.lr_actor
        self.lr_alpha = args.lr_alpha
        self.l2 = args.l2
        self.target_update = args.target_update
        self.step = 0                
        self.agent_id = args.agent_id
        self.last_action = args.last_action  
        self.log_alpha_st = args.log_alpha_st
        self.shared_alpha = args.shared_alpha
        self.maximum_entropy = args.maximum_entropy     
        self.args = args

        
        if self.shared_alpha:
            self.log_alpha = torch.tensor(args.log_alpha_st, dtype=torch.float32, requires_grad=True, device = self.device)
        else:
            self.log_alpha = torch.tensor([args.log_alpha_st]*self.n_agents, dtype=torch.float32, requires_grad=True, device = self.device)
        
        params_critic = list(self.sys_critic1.parameters()) + list(self.sys_critic2.parameters()) + list(self.mix_net1.parameters()) + list(self.mix_net2.parameters())
        
        self.params_critic = params_critic
        self.params_actor = list(self.sys_actor.parameters())

    
        self.optim_actor = torch.optim.Adam(self.sys_actor.parameters(), lr = self.lr_actor, weight_decay=self.l2)
        self.optim_critic = torch.optim.Adam(params_critic, lr = self.lr, weight_decay=self.l2)        
        self.optim_alpha = torch.optim.Adam([self.log_alpha], lr=self.lr_alpha)

    def train(self, data):

        self.step += 1
        w_util = self.w_util

        state = data['state'].to(device=self.device, non_blocking=True)
        obs = data['obs'].to(device=self.device, non_blocking=True)
        actions = data['actions'].to(device=self.device, non_blocking=True)
        reward = data['reward'].to(device=self.device, non_blocking=True)
        valid = data['valid'].to(device=self.device, non_blocking=True)
        avail_actions = data['avail_actions'].to(device=self.device, non_blocking=True)
        actions_onehot = self.one_hot(actions,self.n_actions)
 
        n_batch = obs.shape[0]
        T = obs.shape[1]
        alpha = torch.exp(self.log_alpha.detach())
        valid_rate = torch.mean(valid.float())

        if self.agent_id:
            agent_ids = torch.eye(self.n_agents,device=obs.device)
            agent_ids = agent_ids.reshape((1,)*(obs.ndim-2)+agent_ids.shape)            
            agent_ids = agent_ids.expand(obs.shape[:-2]+(-1,-1))
            obs = torch.cat([obs,agent_ids],-1)
        if self.last_action:
            last_actions = torch.zeros_like(actions_onehot)
            last_actions[:,1:] = actions_onehot[:,:-1]
            obs = torch.cat([obs,last_actions],-1)

        hiddens1 = self.sys_critic1.init_hiddens(n_batch)
        hiddens1_tar = self.sys_critic1_tar.init_hiddens(n_batch)
        hiddens2 = self.sys_critic2.init_hiddens(n_batch)
        hiddens2_tar = self.sys_critic2_tar.init_hiddens(n_batch)
        hiddens_actor = self.sys_actor.init_hiddens(n_batch)
        

        Q1s = []
        Q2s = []
        Q1s_tar = []
        Q2s_tar = []        
        ps = []
        
        

        for i in range(T):
            
            Q1, hiddens1 = self.sys_critic1.forward(obs[:,i], avail_actions[:,i], hiddens1)
            Q2, hiddens2 = self.sys_critic2.forward(obs[:,i], avail_actions[:,i], hiddens2)
            p, hiddens_actor = self.sys_actor.forward(obs[:,i], avail_actions[:,i], hiddens_actor)
            
            #with torch.no_grad():
                
            Q1_tar, hiddens1_tar = self.sys_critic1_tar.forward(obs[:,i], avail_actions[:,i], hiddens1_tar)
            Q2_tar, hiddens2_tar = self.sys_critic2_tar.forward(obs[:,i], avail_actions[:,i], hiddens2_tar)
            
            Q1s.append(Q1)
            Q2s.append(Q2)
            Q1s_tar.append(Q1_tar)
            Q2s_tar.append(Q2_tar)
            ps.append(p)

        Q1s = torch.stack(Q1s,1)
        Q2s = torch.stack(Q2s,1)
        Q1s_tar = torch.stack(Q1s_tar,1)
        Q2s_tar = torch.stack(Q2s_tar,1)

        ps = torch.stack(ps,1)
        ps[valid == 0] = 0
        
        log_ps = torch.log(ps + 1e-38)
        log_ps[valid == 0] = 0
        #log_ps[avail_actions == 0] = 0
        entropy = -torch.sum(ps*log_ps, -1)
        

        Q1s[valid == 0] = 0
        Q2s[valid == 0] = 0
        Q1s_tar[valid == 0] = 0
        Q2s_tar[valid == 0] = 0

        q1s = self.gather_end(Q1s,actions)
        q2s = self.gather_end(Q2s,actions)

        q1s_tot = self.mix_net1(q1s, state)
        q2s_tot = self.mix_net2(q2s, state)
        
        q1s_tot[valid == 0] = 0
        q2s_tot[valid == 0] = 0
        
        V1s = torch.sum(ps * Q1s.detach(), -1)
        V2s = torch.sum(ps * Q2s.detach(), -1)
        
        V1s_tar = torch.sum(ps.detach() * Q1s_tar, -1)
        V2s_tar = torch.sum(ps.detach() * Q2s_tar, -1)
        
        self.mix_net1.requires_grad_(False)
        self.mix_net2.requires_grad_(False)
        
        V1s_tot = self.mix_net1.forward(V1s, state)
        V2s_tot = self.mix_net2.forward(V2s, state)

        self.mix_net1.requires_grad_(True)
        self.mix_net2.requires_grad_(True)

        V1s_tot_tar = self.mix_net1_tar.forward(V1s_tar, state)
        V2s_tot_tar = self.mix_net2_tar.forward(V2s_tar, state)
        
        Vs_tot = torch.min(torch.stack([V1s_tot,V2s_tot],-1), -1)[0]
        Vs_tot_tar = torch.min(torch.stack([V1s_tot_tar,V2s_tot_tar],-1), -1)[0]

        Vs_tot[valid == 0] = 0
        Vs_tot_tar[valid == 0] = 0

        

        alpha_entropy = torch.sum(alpha * entropy, -1, keepdim=True)     
        Ves_tot = Vs_tot + alpha_entropy
        Ves_tot_tar = Vs_tot_tar + alpha_entropy.detach()
        
        # train actor        
        loss_actor = - torch.mean(Ves_tot)/valid_rate
        self.optim_actor.zero_grad()
        loss_actor.backward()
        torch.nn.utils.clip_grad_norm_(self.params_actor, self.args.grad_norm_clip)
        self.optim_actor.step()
               
        
                        
        qs_star = torch.zeros_like(q1s_tot)
        qs_star += reward.unsqueeze(-1)

        if self.maximum_entropy:
            sys_v_tar = Ves_tot_tar
        else:
            sys_v_tar = Vs_tot_tar

        qs_star[:,:-1] += self.gamma * (sys_v_tar[:,1:])
        
        loss1 = F.mse_loss(q1s_tot,qs_star)/valid_rate
        loss2 = F.mse_loss(q2s_tot,qs_star)/valid_rate        
        loss = loss1+loss2
        self.optim_critic.zero_grad()        
        loss.backward()  
        torch.nn.utils.clip_grad_norm_(self.params_critic, self.args.grad_norm_clip)      
        self.optim_critic.step()        
        self.update_target()
        
        loss_alpha = self.log_alpha*(entropy.detach()-self.entropy_tar)
        loss_alpha[valid ==0] = 0
        loss_alpha = torch.mean(loss_alpha)/valid_rate

        self.optim_alpha.zero_grad()
        loss_alpha.backward()
        self.optim_alpha.step()
        
        m_loss = loss/2
        m_alpha = alpha.mean()    
        m_v = torch.mean(V1s.detach())/valid_rate        
        m_v_total = torch.mean(Vs_tot.detach())/valid_rate
        m_entropy = torch.mean(entropy.detach())/valid_rate        
        m_max_p = torch.mean(torch.max(ps.detach(),-1)[0])/valid_rate
        
        w_util.WriteScalar('train/loss', m_loss.item())
        w_util.WriteScalar('train/v', m_v.item())
        w_util.WriteScalar('train/v_total', m_v_total.item())
        w_util.WriteScalar('train/entropy', m_entropy.item())
        w_util.WriteScalar('train/alpha', m_alpha.item())        
        w_util.WriteScalar('train/max_p', m_max_p.item())
        
        return m_loss.item()

    def state_dict(self):
        state_dict = {}
        state_dict['critic1'] = self.sys_critic1.state_dict()
        state_dict['critic2'] = self.sys_critic2.state_dict()
        state_dict['critic1_tar'] = self.sys_critic1_tar.state_dict()
        state_dict['critic2_tar'] = self.sys_critic2_tar.state_dict()
        state_dict['mix_net1'] = self.mix_net1.state_dict()
        state_dict['mix_net2'] = self.mix_net2.state_dict()
        state_dict['mix_net1_tar'] = self.mix_net1_tar.state_dict()
        state_dict['mix_net2_tar'] = self.mix_net2_tar.state_dict()
        state_dict['actor'] = self.sys_actor.state_dict()
        state_dict['log_alpha'] = self.log_alpha.detach()
        state_dict['optim_critic'] = self.optim_critic.state_dict()
        state_dict['optim_actor'] = self.optim_actor.state_dict()
        state_dict['optim_alpha'] = self.optim_alpha.state_dict()
        return state_dict        

    def load_state_dict(self, state_dict):
        self.sys_critic1.load_state_dict(state_dict['critic1'])
        self.sys_critic2.load_state_dict(state_dict['critic2'])
        self.sys_critic1_tar.load_state_dict(state_dict['critic1_tar'])
        self.sys_critic2_tar.load_state_dict(state_dict['critic2_tar'])
        self.mix_net1.load_state_dict(state_dict['mix_net1'])
        self.mix_net2.load_state_dict(state_dict['mix_net2'])
        self.mix_net1_tar.load_state_dict(state_dict['mix_net1_tar'])
        self.mix_net2_tar.load_state_dict(state_dict['mix_net2_tar'])
        self.sys_actor.load_state_dict(state_dict['actor'])
        with torch.no_grad():
            self.log_alpha.copy_(state_dict['log_alpha'])
        self.optim_critic.load_state_dict(state_dict['optim_critic'])
        self.optim_actor.load_state_dict(state_dict['optim_actor'])
        self.optim_alpha.load_state_dict(state_dict['optim_alpha'])

        
    def gather_end(self, input, index):
        index = torch.unsqueeze(index,-1).to(dtype=torch.int64)
        return torch.gather(input, input.ndim -1, index).squeeze(-1)

    def one_hot(self, tensor, n_classes):
        return F.one_hot(tensor.to(dtype=torch.int64), n_classes).to(dtype=torch.float32)

    def update_target(self):
        if self.target_update >=1:
            if self.step % self.target_update == 0:
                self._sync_target()
        else:
            def soft_update(src,tar):
                cur_state = src.state_dict()
                tar_state = tar.state_dict()
                for key in tar_state:                
                    v_tar = tar_state[key]
                    v_cur = cur_state[key]
                    v_tar += self.target_update*(v_cur-v_tar).detach()
            soft_update(self.sys_critic1,self.sys_critic1_tar)
            soft_update(self.sys_critic2,self.sys_critic2_tar)
            soft_update(self.mix_net1,self.mix_net1_tar)
            soft_update(self.mix_net2,self.mix_net2_tar)
    
    def _sync_target(self):
        self.sys_critic1_tar.load_state_dict(self.sys_critic1.state_dict())
        self.sys_critic2_tar.load_state_dict(self.sys_critic2.state_dict())
        self.mix_net1_tar.load_state_dict(self.mix_net1.state_dict())
        self.mix_net2_tar.load_state_dict(self.mix_net2.state_dict())
 
    def _valid_mask(self, input, valid):
        input *= valid.view(list(valid.shape) + [1] * (input.ndim - valid.ndim))
        return input
        
class Experiment:
    def __init__(self, args):        
        self.args = args


    def save(self):

        run_state = {}                
        run_state['episode'] = self.e
        run_state['step'] = self.step
        run_state['best_win_rate'] = self.best_win_rate
        run_state['learner'] = self.learner.state_dict()
        run_state['buffer'] = self.buffer.state_dict()
        torch.save(run_state, self.path_checkpt)        

    def load(self):
        run_state = torch.load(self.path_checkpt)
        self.e = run_state['episode']
        self.step = run_state['step']
        self.best_win_rate = run_state['best_win_rate']
        self.learner.load_state_dict(run_state['learner'])                
        self.buffer.load_state_dict(run_state['buffer'])
        self.result = np.load(self.path_result)

    def start(self):
        args = self.args

        path_checkpt = 'checkpoints'
        path_result = 'results'
        path_model = 'models'
        if not os.path.exists(path_checkpt):
            os.mkdir(path_checkpt)
        if not os.path.exists(path_result):
            os.mkdir(path_result)
        if not os.path.exists(path_model):
            os.mkdir(path_model)
        path_checkpt = os.path.join(path_checkpt, args.run_name + '.tar')
        path_result = os.path.join(path_result, args.run_name + '.npy')
        path_model = os.path.join(path_model, args.run_name + '.tar')
            
        # env = StarCraft2Env(map_name=args.map_name, window_size_x=640, window_size_y=480)
        env = simple_spread_v3.parallel_env(N=args.N, local_ratio=args.local_ratio, max_cycles=args.max_cycles, continuous_actions=args.continuous_actions)
        print(env)
        env.reset()

        env_info = {
            "n_agents": args.N,
            "n_actions": 5,  # no_action, move_left, move_right, move_down, move_up
            "obs_shape": 18,
            "state_shape": 54,
            "episode_limit": args.max_cycles
        }
        # env_info = env.get_env_info()

        args.n_agents = env_info["n_agents"]
        args.n_actions = env_info["n_actions"]
        args.obs_dim = env_info['obs_shape']
        args.input_dim = args.obs_dim
        if args.agent_id:
            args.input_dim += args.n_agents
        if args.last_action:        
            args.input_dim += args.n_actions        
        args.state_dim = env_info['state_shape']
        args.episode_limit = env_info['episode_limit']
        
        writter = SummaryWriter('runs/'+ args.run_name + '/' + datetime.datetime.now().strftime('%Y-%m-%d,%H%M%S'))
        w_util = WritterUtil(writter,args)
        learner = Learner(w_util,args)               
        ctrler = Controller(learner.sys_actor,args)
        runner = Runner(env,ctrler,args)
                
        scheme = {}
        n_agents = args.n_agents
        scheme['obs'] = {'shape':(n_agents, args.obs_dim), 'dtype': torch.float32}
        scheme['valid'] = {'shape':(), 'dtype': torch.int32}
        scheme['actions'] = {'shape':(n_agents,), 'dtype': torch.int32}
        scheme['avail_actions'] = {'shape':(n_agents, args.n_actions), 'dtype': torch.int32}
        scheme['reward'] = {'shape':(), 'dtype': torch.float32}
        scheme['state'] = {'shape':(args.state_dim,), 'dtype': torch.float32}

        buffer = EpisodeBuffer(scheme, args)
        result = np.zeros((3, args.n_steps // args.test_every_step))

        self.e = 0
        self.step = 0
        self.best_win_rate = 0                   
        self.path_checkpt = path_checkpt
        self.path_result = path_result
        self.path_model = path_model      
        self.env = env        
        self.writter = writter
        self.w_util = w_util
        self.ctrler = ctrler
        self.runner = runner
        self.learner = learner
        self.buffer = buffer
        self.result = result

        if args.continue_run:
            self.load()
                    
        
    def run(self):
        
        args = self.args
        buffer = self.buffer        
        runner = self.runner
        learner = self.learner
        w_util = self.w_util
        
        while self.step < args.n_steps:
        #for self.e in range(self.e, args.n_episodes+1):
            self.e += 1            
            data, episode_reward, win_tag, step =  runner.run()
            old_step = self.step
            self.step += step                   
            w_util.set_step(self.step)            
            w_util.WriteScalar('train/reward', episode_reward)
            print("Episode {}, step {}, win = {}, reward = {}".format(self.e, self.step, win_tag, episode_reward))
            buffer.add_episode(data)
            data = buffer.sample(args.n_batch, args.top_n)
            if data:
                loss = learner.train(data)                        
                        
            if self.step // args.test_every_step != old_step // args.test_every_step:
                self.test_model()            

            if args.save_every and self.e % args.save_every == 0:                
                self.save()

        self.env.close()

    def test_model(self):
        args = self.args
        w_util = self.w_util
        runner = self.runner
        result = self.result

        win_count = 0
        reward_avg = 0
        for i in range(args.test_count):
            _, episode_reward, win_tag, _ =  runner.run(test_mode=True)
            if win_tag:
                win_count += 1
            reward_avg += episode_reward                
        win_rate = win_count/args.test_count        
        reward_avg /= args.test_count
        w_util.WriteScalar('test/reward', reward_avg)
        w_util.WriteScalar('test/win_rate', win_rate)
        result[:, self.step // args.test_every_step - 1] = [self.e, self.step, win_rate]
        np.save(self.path_result, self.result)
        if win_rate >= self.best_win_rate:
            self.best_win_rate = win_rate
            torch.save(self.learner.sys_actor.state_dict(), self.path_model)            
        print('Test reward = {}, win_rate = {}'.format(reward_avg, win_rate))
        
class Runner:
    def __init__(self, env, controller, args):
        """
        Initialize the Runner.
        Args:
            env: The PettingZoo environment.
            controller: The controller that decides agent actions.
            args: Additional arguments, including max_cycles and number of agents (N).
        """
        self.controller = controller
        self.env = env
        self.args = args

    def run(self, test_mode=False):
        """
        Runs a single episode in a parallel PettingZoo environment using the provided controller.
        In the Parallel API, all agents receive observations and take actions simultaneously, as outlined in:
            https://pettingzoo.farama.org/api/parallel/
        This function:
            1. Resets the environment and the controller for a new episode.
            2. Iteratively collects observations in a parallel fashion for all agents.
            3. Obtains actions from the controller and steps the environment.
            4. Logs transition data (observations, actions, rewards, etc.) during each time step.
            5. Terminates when the maximum number of cycles is reached.
            6. Returns episode data, the total reward, whether a win condition was met, and the number of steps taken.
        Args:
            test_mode (bool, optional): If True, disables exploration to evaluate a learned policy. Defaults to False.
        Returns:
            tuple:
                - data (dict): Dictionary containing keys 'state', 'obs', 'valid', 'actions', 'avail_actions', and 'reward'.
                - episode_reward (float): Cumulative reward over the episode.
                - win_tag (bool): Indicator of whether a win condition was satisfied (criteria can be environment-specific).
                - steps (int): Number of steps taken in the episode.
        Notes on Prints and Asserts (Parallel API):
            - Print statements can be added throughout to debug the flow of observations and actions in a multi-agent setting.
            - Asserts can validate that the environment adheres to the Parallel API, such as checking that the step() method
              returns dictionaries keyed by agent for observations, rewards, terminations, truncations, and info.
            - Additional prints and asserts can be useful when converting or wrapping an AEC environment into a Parallel environment
              to ensure consistent multi-agent behavior across all agents.
        """
class Runner:
    def __init__(self, env, controller, args):
        """
        Initialize the Runner.
        Args:
            env: The PettingZoo environment.
            controller: The controller that decides agent actions.
            args: Additional arguments, including max_cycles and number of agents (N).
        """
        self.controller = controller
        self.env = env
        self.args = args

    def run(self, test_mode=False):
        """
        Run a single episode in the PettingZoo environment.

        Args:
            test_mode (bool): If True, disables exploration. Defaults to False.

        Returns:
            tuple: (data, episode_reward, win_tag, steps)
        """
        print("Resetting environment...")
        observations, infos = self.env.reset()

        self.controller.new_episode()
        data = {
            'state': [],
            'obs': [],
            'valid': [],
            'actions': [],
            'avail_actions': [],
            'reward': []
        }
        episode_reward = 0
        steps = 0

        while steps < self.args.max_cycles:
            steps += 1
            print(f"Step {steps}...")

            # Ensure environment state is valid
            assert hasattr(self.env, 'state'), "Environment does not have a 'state()' method."
            state = self.env.state()

            # Validate observations dictionary
            assert isinstance(observations, dict), "Observations must be a dictionary."
            assert len(observations) == len(self.env.agents), "Mismatch between agents and observations."

            # Convert observations dict to list in consistent order
            obs_list = [observations[agent_id] for agent_id in self.env.agents]

            # Validate available actions
            avail_actions_list = [[1] * 5 for _ in range(self.args.N)]  # Example: 5 actions per agent
            assert len(avail_actions_list) == self.args.N, "Available actions list size mismatch."

            explore = not test_mode

            # Get actions from controller
            actions_array = self.controller.get_actions(obs_list, avail_actions_list, explore)
            assert len(actions_array) == len(self.env.agents), "Mismatch between actions and agents."

            # Convert actions array to dict for PettingZoo environment
            actions_dict = {agent_id: action for agent_id, action in zip(self.env.agents, actions_array)}

            # Step the environment
            try:
                observations, rewards, terminations, truncations, infos = self.env.step(actions_dict)
            except Exception as e:
                print(f"Error during environment step: {e}")
                break

            # Validate rewards dictionary
            assert isinstance(rewards, dict), "Rewards must be a dictionary."

            # Calculate total reward for this step
            step_reward = sum(rewards.values())
            episode_reward += step_reward

            # Store transition data
            data['state'].append(state)
            data['obs'].append(obs_list)
            data['valid'].append(1)  # Assume all steps are valid
            data['actions'].append(actions_array)
            data['avail_actions'].append(avail_actions_list)
            data['reward'].append(step_reward)

            # Check if all agents are done
            if all(terminations.values()) or all(truncations.values()):
                print("All agents are done. Ending episode.")
                break

        # Define win condition placeholder
        win_tag = episode_reward > 0  # Modify based on environment-specific criteria

        print(f"Episode completed: Total reward = {episode_reward}, Steps = {steps}")
        return data, episode_reward, win_tag, steps

class Args:
    pass


if __name__ == "__main__":

    
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    config_path='config.json'
        
    with open(config_path, 'r') as f:
        config = json.load(f)
    args = Args()
    args.__dict__.update(config)

    args.continue_run = False
    argv = sys.argv
    if len(argv)>1:
        if argv[1] == '-c':  ##continue
            args.continue_run = True

    experiment = Experiment(args)
    experiment.start()
    experiment.run()
# Out:
# simple_spread_v3
# /var/folders/1d/k2nxt21n3qn7tn1clzr__dkm0000gq/T/ipykernel_74541/185860592.py:77: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:278.)
#   states = torch.tensor(states, dtype=torch.float32, device=self.device)
# Episode 1, step 75, win = False, reward = -201.64315439027226
# Episode 2, step 150, win = False, reward = -247.29705847593397
# Episode 3, step 225, win = False, reward = -170.6050698286561
# Episode 4, step 300, win = False, reward = -209.49429941613272
# Episode 5, step 375, win = False, reward = -300.85708127775433
# Episode 6, step 450, win = False, reward = -207.32737051604016
# Episode 7, step 525, win = False, reward = -195.1960283159677
# Episode 8, step 600, win = False, reward = -392.14266254465457
# Episode 9, step 675, win = False, reward = -274.30037174555565
# Episode 10, step 750, win = False, reward = -353.50969332649896
# Episode 11, step 825, win = False, reward = -361.81960794015333
# Episode 12, step 900, win = False, reward = -218.97218741922927
# Episode 13, step 975, win = False, reward = -245.06183661749407
# Episode 14, step 1050, win = False, reward = -282.2472511972546
# Episode 15, step 1125, win = False, reward = -435.27203127968085
# Episode 16, step 1200, win = False, reward = -491.96265465672604
# Episode 17, step 1275, win = False, reward = -218.68231507320112
# Episode 18, step 1350, win = False, reward = -221.60819186549264
# Episode 19, step 1425, win = False, reward = -206.72341700939268
# Episode 20, step 1500, win = False, reward = -244.19503324324887
# Episode 21, step 1575, win = False, reward = -245.48409195438828
# Episode 22, step 1650, win = False, reward = -302.56705134278286
# Episode 23, step 1725, win = False, reward = -250.85069787405288
# Episode 24, step 1800, win = False, reward = -317.11837849734326
# Episode 25, step 1875, win = False, reward = -223.13921336443138
# Episode 26, step 1950, win = False, reward = -207.547214555471
# Episode 27, step 2025, win = False, reward = -230.15311570824892
# Episode 28, step 2100, win = False, reward = -359.1680344732603
# Episode 29, step 2175, win = False, reward = -302.8075206176016
# Episode 30, step 2250, win = False, reward = -331.7743107801086
# Episode 31, step 2325, win = False, reward = -305.4366773491879
# Episode 32, step 2400, win = False, reward = -273.57791079742975
# Episode 33, step 2475, win = False, reward = -231.4558301983424
# Episode 34, step 2550, win = False, reward = -195.54992876025574
# Episode 35, step 2625, win = False, reward = -242.72784477636222
# Episode 36, step 2700, win = False, reward = -435.5437524235298
# Episode 37, step 2775, win = False, reward = -276.83905938046496
# Episode 38, step 2850, win = False, reward = -337.1250202525685
# Episode 39, step 2925, win = False, reward = -206.01967316986114
# Episode 40, step 3000, win = False, reward = -348.0963955007562
# Episode 41, step 3075, win = False, reward = -255.84931499111187
# Episode 42, step 3150, win = False, reward = -240.90737212126726
# Episode 43, step 3225, win = False, reward = -263.5749183721112
# Episode 44, step 3300, win = False, reward = -385.0862718665315
# Episode 45, step 3375, win = False, reward = -176.3964669607784
# Episode 46, step 3450, win = False, reward = -311.5741351195643
# Episode 47, step 3525, win = False, reward = -286.2205631896231
# Episode 48, step 3600, win = False, reward = -375.36608416900947
# Episode 49, step 3675, win = False, reward = -328.2843011981904
# Episode 50, step 3750, win = False, reward = -383.92246134081563
# Episode 51, step 3825, win = False, reward = -476.39551158231757
# Episode 52, step 3900, win = False, reward = -226.88602987435692
# Episode 53, step 3975, win = False, reward = -205.97123215015054
# Episode 54, step 4050, win = False, reward = -303.47922252486836
# Episode 55, step 4125, win = False, reward = -233.64121856856238
# Episode 56, step 4200, win = False, reward = -433.5528504667678
# Episode 57, step 4275, win = False, reward = -187.4605549976738
# Episode 58, step 4350, win = False, reward = -301.90582661209055
# Episode 59, step 4425, win = False, reward = -264.75653120978245
# Episode 60, step 4500, win = False, reward = -471.3667118956924
# Episode 61, step 4575, win = False, reward = -252.73418154150858
# Episode 62, step 4650, win = False, reward = -388.730092090572
# Episode 63, step 4725, win = False, reward = -299.8547532460522
# Episode 64, step 4800, win = False, reward = -302.00273515535224
# Episode 65, step 4875, win = False, reward = -235.51933339660988
# Episode 66, step 4950, win = False, reward = -379.7078246687948
# Episode 67, step 5025, win = False, reward = -267.1233226436547
# Episode 68, step 5100, win = False, reward = -316.4488384945829
# Episode 69, step 5175, win = False, reward = -275.3276584310318
# Episode 70, step 5250, win = False, reward = -268.4731029953103
# Episode 71, step 5325, win = False, reward = -482.55452609605237
# Episode 72, step 5400, win = False, reward = -383.9921926897896
# Episode 73, step 5475, win = False, reward = -551.5281204070849
# Episode 74, step 5550, win = False, reward = -377.4474181397284
# Episode 75, step 5625, win = False, reward = -345.736752449251
# Episode 76, step 5700, win = False, reward = -273.92136365988847
# Episode 77, step 5775, win = False, reward = -300.8845321220596
# Episode 78, step 5850, win = False, reward = -238.1126108491193
# Episode 79, step 5925, win = False, reward = -392.22922767905607
# Episode 80, step 6000, win = False, reward = -302.0975363180323
# Episode 81, step 6075, win = False, reward = -226.3650181597929
# Episode 82, step 6150, win = False, reward = -234.9907647052943
# Episode 83, step 6225, win = False, reward = -381.4744893514662
# Episode 84, step 6300, win = False, reward = -303.39555993185127
# Episode 85, step 6375, win = False, reward = -246.53600960470604
# Episode 86, step 6450, win = False, reward = -432.6074107343691
# Episode 87, step 6525, win = False, reward = -277.2862952995735
# Episode 88, step 6600, win = False, reward = -361.63543413815535
# Episode 89, step 6675, win = False, reward = -290.8264446072642
# Episode 90, step 6750, win = False, reward = -465.27664405024143
# Episode 91, step 6825, win = False, reward = -390.31696093098896
# Episode 92, step 6900, win = False, reward = -367.7482679472043
# Episode 93, step 6975, win = False, reward = -406.96185328897235
# Episode 94, step 7050, win = False, reward = -253.8386965960363
# Episode 95, step 7125, win = False, reward = -223.14335577855883
# Episode 96, step 7200, win = False, reward = -314.20191952076107
# Episode 97, step 7275, win = False, reward = -559.1177147958869
# Episode 98, step 7350, win = False, reward = -205.46839595319693
# Episode 99, step 7425, win = False, reward = -405.36035184372315
# Episode 100, step 7500, win = False, reward = -274.66275851528854
# Episode 101, step 7575, win = False, reward = -241.693287174787
# Episode 102, step 7650, win = False, reward = -412.9117109460701
# Episode 103, step 7725, win = False, reward = -306.27690107244945
# Episode 104, step 7800, win = False, reward = -206.0003592519695
# Episode 105, step 7875, win = False, reward = -314.80397525621055
# Episode 106, step 7950, win = False, reward = -246.62890502493462
# Episode 107, step 8025, win = False, reward = -243.0700971368315
# Episode 108, step 8100, win = False, reward = -249.111258973643
# Episode 109, step 8175, win = False, reward = -363.3443478629625
# Episode 110, step 8250, win = False, reward = -628.3283681442467
# Episode 111, step 8325, win = False, reward = -236.22817688830227
# Episode 112, step 8400, win = False, reward = -471.9461916910051
# Episode 113, step 8475, win = False, reward = -283.70465422560557
# Episode 114, step 8550, win = False, reward = -232.62971441442127
# Episode 115, step 8625, win = False, reward = -312.9438026722417
# Episode 116, step 8700, win = False, reward = -305.2730445371356
# Episode 117, step 8775, win = False, reward = -216.52519893737076
# Episode 118, step 8850, win = False, reward = -224.86274180299228
# Episode 119, step 8925, win = False, reward = -439.484680716452
# Episode 120, step 9000, win = False, reward = -379.80821466328285
# Episode 121, step 9075, win = False, reward = -336.96395167277467
# Episode 122, step 9150, win = False, reward = -376.0567881416585
# Episode 123, step 9225, win = False, reward = -300.1536963202219
# Episode 124, step 9300, win = False, reward = -283.32441369669755
# Episode 125, step 9375, win = False, reward = -400.41948450789215
# Episode 126, step 9450, win = False, reward = -281.48772446808783
# Episode 127, step 9525, win = False, reward = -346.28610220762613
# Episode 128, step 9600, win = False, reward = -232.1403541896583
# Episode 129, step 9675, win = False, reward = -202.15253522833913
# Episode 130, step 9750, win = False, reward = -362.46690429251
# Episode 131, step 9825, win = False, reward = -403.11552591042465
# Episode 132, step 9900, win = False, reward = -315.8418384099446
# Episode 133, step 9975, win = False, reward = -287.9489232703257
# Episode 134, step 10050, win = False, reward = -343.9230564841112
# Test reward = -1691.4776077315883, win_rate = 0.0
# Episode 135, step 10125, win = False, reward = -256.8842052666255
# Episode 136, step 10200, win = False, reward = -363.5567576190866
# Episode 137, step 10275, win = False, reward = -204.45342978582602
# Episode 138, step 10350, win = False, reward = -255.9732091572103
# Episode 139, step 10425, win = False, reward = -420.3668764218001
# Episode 140, step 10500, win = False, reward = -578.4705007442698
# Episode 141, step 10575, win = False, reward = -157.16420180089048
# Episode 142, step 10650, win = False, reward = -265.19119038067976
# Episode 143, step 10725, win = False, reward = -357.79180919086474
# Episode 144, step 10800, win = False, reward = -265.34326485900095
# Episode 145, step 10875, win = False, reward = -216.68251771678874
# Episode 146, step 10950, win = False, reward = -453.9117090410084
# Episode 147, step 11025, win = False, reward = -239.7419313375708
# Episode 148, step 11100, win = False, reward = -543.7570709017341
# Episode 149, step 11175, win = False, reward = -556.5408726184423
# Episode 150, step 11250, win = False, reward = -424.5725398546733
# Episode 151, step 11325, win = False, reward = -329.91107265385966
# Episode 152, step 11400, win = False, reward = -298.4817163485252
# Episode 153, step 11475, win = False, reward = -292.4923389107955
# Episode 154, step 11550, win = False, reward = -517.4162681403222
# Episode 155, step 11625, win = False, reward = -285.9721312193064
# Episode 156, step 11700, win = False, reward = -181.56078813031377
# Episode 157, step 11775, win = False, reward = -190.1254479992798
# Episode 158, step 11850, win = False, reward = -229.35578431340215
# Episode 159, step 11925, win = False, reward = -165.74092194135528
# Episode 160, step 12000, win = False, reward = -321.22142487574354
# Episode 161, step 12075, win = False, reward = -164.02825844335234
# Episode 162, step 12150, win = False, reward = -205.50212527019184
# Episode 163, step 12225, win = False, reward = -234.03212245133167
# Episode 164, step 12300, win = False, reward = -306.0686480226618
# Episode 165, step 12375, win = False, reward = -381.43126925016594
# Episode 166, step 12450, win = False, reward = -401.3233933645466
# Episode 167, step 12525, win = False, reward = -452.1751023463895
# Episode 168, step 12600, win = False, reward = -330.430230099285
# Episode 169, step 12675, win = False, reward = -374.869964763386
# Episode 170, step 12750, win = False, reward = -563.9809777280261
# Episode 171, step 12825, win = False, reward = -261.4180757899515
# Episode 172, step 12900, win = False, reward = -213.8541562761143
# Episode 173, step 12975, win = False, reward = -236.46749933119534
# Episode 174, step 13050, win = False, reward = -420.6292171165719
# Episode 175, step 13125, win = False, reward = -472.2012759434123
# Episode 176, step 13200, win = False, reward = -445.1783823772508
# Episode 177, step 13275, win = False, reward = -226.86898199967837
# Episode 178, step 13350, win = False, reward = -295.1314491951271
# Episode 179, step 13425, win = False, reward = -281.069685513883
# Episode 180, step 13500, win = False, reward = -164.21838720597611
# Episode 181, step 13575, win = False, reward = -367.1319221015403
# Episode 182, step 13650, win = False, reward = -235.6392780247942
# Episode 183, step 13725, win = False, reward = -387.69507295538773
# Episode 184, step 13800, win = False, reward = -162.97741761424643
# Episode 185, step 13875, win = False, reward = -203.2952367107908
# Episode 186, step 13950, win = False, reward = -361.81879118237464
# Episode 187, step 14025, win = False, reward = -332.4165402500849
# Episode 188, step 14100, win = False, reward = -227.16389581849973
# Episode 189, step 14175, win = False, reward = -275.2105300866228
# Episode 190, step 14250, win = False, reward = -420.76962628179126
# Episode 191, step 14325, win = False, reward = -294.15689906417583
# Episode 192, step 14400, win = False, reward = -412.4943532913009
# Episode 193, step 14475, win = False, reward = -199.18794850403216
# Episode 194, step 14550, win = False, reward = -342.42894703713415
# Episode 195, step 14625, win = False, reward = -253.21945537903537
# Episode 196, step 14700, win = False, reward = -242.4457317873909
# Episode 197, step 14775, win = False, reward = -348.56039231412785
# Episode 198, step 14850, win = False, reward = -436.27459605369285
# Episode 199, step 14925, win = False, reward = -256.9556646196116
# Episode 200, step 15000, win = False, reward = -439.446580212007
# Episode 201, step 15075, win = False, reward = -392.79168687091453
# Episode 202, step 15150, win = False, reward = -605.6780531988297
# Episode 203, step 15225, win = False, reward = -298.9019277959747
# Episode 204, step 15300, win = False, reward = -245.16700220860832
# Episode 205, step 15375, win = False, reward = -289.00451387864337
# Episode 206, step 15450, win = False, reward = -294.6181691716853
# Episode 207, step 15525, win = False, reward = -389.51086555863094
# Episode 208, step 15600, win = False, reward = -323.9450789793925
# Episode 209, step 15675, win = False, reward = -324.57885303440656
# Episode 210, step 15750, win = False, reward = -390.6696287511562
# Episode 211, step 15825, win = False, reward = -710.4791551558494
# Episode 212, step 15900, win = False, reward = -285.3572507421063
# Episode 213, step 15975, win = False, reward = -368.4576209156779
# Episode 214, step 16050, win = False, reward = -171.24540760725452
# Episode 215, step 16125, win = False, reward = -259.79984829621895
# Episode 216, step 16200, win = False, reward = -446.8583068069946
# Episode 217, step 16275, win = False, reward = -253.2097401119296
# Episode 218, step 16350, win = False, reward = -275.75099471624753
# Episode 219, step 16425, win = False, reward = -257.87739689452746
# Episode 220, step 16500, win = False, reward = -360.9594419072985
# Episode 221, step 16575, win = False, reward = -320.87412450093217
# Episode 222, step 16650, win = False, reward = -192.64081013118135
# Episode 223, step 16725, win = False, reward = -549.0153444768745
# Episode 224, step 16800, win = False, reward = -247.94994791949932
# Episode 225, step 16875, win = False, reward = -241.83062070276608
# Episode 226, step 16950, win = False, reward = -239.98987504589547
# Episode 227, step 17025, win = False, reward = -271.9945859709882
# Episode 228, step 17100, win = False, reward = -192.94784992048375
# Episode 229, step 17175, win = False, reward = -150.0260262269095
# Episode 230, step 17250, win = False, reward = -233.02053336309766
# Episode 231, step 17325, win = False, reward = -441.99672193087986
# Episode 232, step 17400, win = False, reward = -194.89554396713956
# Episode 233, step 17475, win = False, reward = -502.3782230970191
# Episode 234, step 17550, win = False, reward = -307.1690143749405
# Episode 235, step 17625, win = False, reward = -242.89260799645808
# Episode 236, step 17700, win = False, reward = -220.08045381288483
# Episode 237, step 17775, win = False, reward = -351.6000022454233
# Episode 238, step 17850, win = False, reward = -279.3837643693689
# Episode 239, step 17925, win = False, reward = -199.0717911331838
# Episode 240, step 18000, win = False, reward = -251.82785810475883
# Episode 241, step 18075, win = False, reward = -150.5296688219926
# Episode 242, step 18150, win = False, reward = -470.2605946543696
# Episode 243, step 18225, win = False, reward = -335.81075433608714
# Episode 244, step 18300, win = False, reward = -350.7115906283797
# Episode 245, step 18375, win = False, reward = -193.31297998547169
# Episode 246, step 18450, win = False, reward = -445.2412726732665
# Episode 247, step 18525, win = False, reward = -356.15755507660896
# Episode 248, step 18600, win = False, reward = -231.2607014211868
# Episode 249, step 18675, win = False, reward = -509.78524230620525
# Episode 250, step 18750, win = False, reward = -290.52061430441654
# Episode 251, step 18825, win = False, reward = -240.94806690656418
# Episode 252, step 18900, win = False, reward = -192.10819743999704
# Episode 253, step 18975, win = False, reward = -307.3621843610904
# Episode 254, step 19050, win = False, reward = -177.7745732547308
# Episode 255, step 19125, win = False, reward = -225.05442204068785
# Episode 256, step 19200, win = False, reward = -259.22879392043444
# Episode 257, step 19275, win = False, reward = -238.82227703725397
# Episode 258, step 19350, win = False, reward = -353.23863036252305
# Episode 259, step 19425, win = False, reward = -481.39124048382774
# Episode 260, step 19500, win = False, reward = -314.2193484435255
# Episode 261, step 19575, win = False, reward = -462.2470934890609
# Episode 262, step 19650, win = False, reward = -516.4637993575965
# Episode 263, step 19725, win = False, reward = -311.5576200472696
# Episode 264, step 19800, win = False, reward = -261.83510172062574
# Episode 265, step 19875, win = False, reward = -228.72107613079513
# Episode 266, step 19950, win = False, reward = -331.8386508092044
# Episode 267, step 20025, win = False, reward = -158.01391663248597
# Test reward = -1547.9359008796828, win_rate = 0.0
# Episode 268, step 20100, win = False, reward = -364.3125163535414
# Episode 269, step 20175, win = False, reward = -315.40997892400435
# Episode 270, step 20250, win = False, reward = -238.25462433015542
# Episode 271, step 20325, win = False, reward = -215.17302447019077
# Episode 272, step 20400, win = False, reward = -251.08716930540467
# Episode 273, step 20475, win = False, reward = -302.4088837955255
# Episode 274, step 20550, win = False, reward = -223.6418783542528
# Episode 275, step 20625, win = False, reward = -259.76813766694085
# Episode 276, step 20700, win = False, reward = -280.74144082485844
# Episode 277, step 20775, win = False, reward = -247.78602826647167
# Episode 278, step 20850, win = False, reward = -153.7776848288441
# Episode 279, step 20925, win = False, reward = -254.07277087669442
# Episode 280, step 21000, win = False, reward = -200.36534919112154
# Episode 281, step 21075, win = False, reward = -612.2080595144146
# Episode 282, step 21150, win = False, reward = -299.28493738480654
# Episode 283, step 21225, win = False, reward = -468.0446624098887
# Episode 284, step 21300, win = False, reward = -224.46969958571836
# Episode 285, step 21375, win = False, reward = -234.599035927566
# Episode 286, step 21450, win = False, reward = -377.93709513398
# Episode 287, step 21525, win = False, reward = -276.1235849376293
# Episode 288, step 21600, win = False, reward = -400.6684094018107
# Episode 289, step 21675, win = False, reward = -400.06322429682547
# Episode 290, step 21750, win = False, reward = -493.5366773550219
# Episode 291, step 21825, win = False, reward = -402.7476913247189
# Episode 292, step 21900, win = False, reward = -310.5937446400277
# Episode 293, step 21975, win = False, reward = -285.0343445022278
# Episode 294, step 22050, win = False, reward = -315.12331043527394
# Episode 295, step 22125, win = False, reward = -340.1467869475614
# Episode 296, step 22200, win = False, reward = -198.0095108955038
# Episode 297, step 22275, win = False, reward = -249.0147007884988
# Episode 298, step 22350, win = False, reward = -224.7612163707337
# Episode 299, step 22425, win = False, reward = -311.0972926027247
# Episode 300, step 22500, win = False, reward = -243.07263162481522
# Episode 301, step 22575, win = False, reward = -312.13267856098906
# Episode 302, step 22650, win = False, reward = -282.4376994639249
# Episode 303, step 22725, win = False, reward = -574.2119364070885
# Episode 304, step 22800, win = False, reward = -331.5158310787982
# Episode 305, step 22875, win = False, reward = -646.33766598407
# Episode 306, step 22950, win = False, reward = -302.53972556278467
# Episode 307, step 23025, win = False, reward = -309.20759153484886
# Episode 308, step 23100, win = False, reward = -377.17214727442826
# Episode 309, step 23175, win = False, reward = -288.29953955823567
# Episode 310, step 23250, win = False, reward = -343.6319738692072
# Episode 311, step 23325, win = False, reward = -247.61644978150142
# Episode 312, step 23400, win = False, reward = -288.29329607863644
# Episode 313, step 23475, win = False, reward = -443.08052054627274
# Episode 314, step 23550, win = False, reward = -231.1395925903553
# Episode 315, step 23625, win = False, reward = -248.768383820942
# Episode 316, step 23700, win = False, reward = -336.4440557658622
# Episode 317, step 23775, win = False, reward = -189.06098563952634
# Episode 318, step 23850, win = False, reward = -249.58578800121643
# Episode 319, step 23925, win = False, reward = -352.3577852959513
# Episode 320, step 24000, win = False, reward = -234.28213499995772
# Episode 321, step 24075, win = False, reward = -445.80440342150905
# Episode 322, step 24150, win = False, reward = -405.01088409559287
# Episode 323, step 24225, win = False, reward = -172.36111037145156
# Episode 324, step 24300, win = False, reward = -265.37605221960365
# Episode 325, step 24375, win = False, reward = -163.10333869085346
# Episode 326, step 24450, win = False, reward = -285.803266150746
# Episode 327, step 24525, win = False, reward = -412.9126347091766
# Episode 328, step 24600, win = False, reward = -252.94440588312403
# Episode 329, step 24675, win = False, reward = -292.4143657041505
# Episode 330, step 24750, win = False, reward = -267.9167268008759
# Episode 331, step 24825, win = False, reward = -295.99546361030224
# Episode 332, step 24900, win = False, reward = -230.1529845781684
# Episode 333, step 24975, win = False, reward = -273.5777440123446
# Episode 334, step 25050, win = False, reward = -280.89620764226777
# Episode 335, step 25125, win = False, reward = -524.409713119093
# Episode 336, step 25200, win = False, reward = -284.2173034741011
# Episode 337, step 25275, win = False, reward = -395.0935784696512
# Episode 338, step 25350, win = False, reward = -239.80861661287204
# Episode 339, step 25425, win = False, reward = -205.63565507833508
# Episode 340, step 25500, win = False, reward = -411.154032317632
# Episode 341, step 25575, win = False, reward = -354.7712103300542
# Episode 342, step 25650, win = False, reward = -343.13732244869306
# Episode 343, step 25725, win = False, reward = -262.0637541240584
# Episode 344, step 25800, win = False, reward = -341.8442532922989
# Episode 345, step 25875, win = False, reward = -264.12716096208857
# Episode 346, step 25950, win = False, reward = -292.4830224699161
# Episode 347, step 26025, win = False, reward = -409.67653357585027
# Episode 348, step 26100, win = False, reward = -489.0191668437285
# Episode 349, step 26175, win = False, reward = -231.4623640629842
# Episode 350, step 26250, win = False, reward = -288.9036062158058
# Episode 351, step 26325, win = False, reward = -301.9068713437697
# Episode 352, step 26400, win = False, reward = -219.96729314265386
# Episode 353, step 26475, win = False, reward = -548.8702153540635
# Episode 354, step 26550, win = False, reward = -396.5300680960173
# Episode 355, step 26625, win = False, reward = -487.47377490370616
# Episode 356, step 26700, win = False, reward = -353.20584195330935
# Episode 357, step 26775, win = False, reward = -287.3031803582738
# Episode 358, step 26850, win = False, reward = -445.8795571945864
# Episode 359, step 26925, win = False, reward = -269.6858983338436
# Episode 360, step 27000, win = False, reward = -206.811504030249
# Episode 361, step 27075, win = False, reward = -275.42754523255826
# Episode 362, step 27150, win = False, reward = -256.58956195107356
# Episode 363, step 27225, win = False, reward = -297.1010420397866
# Episode 364, step 27300, win = False, reward = -225.38570076591697
# Episode 365, step 27375, win = False, reward = -304.9995759207995
# Episode 366, step 27450, win = False, reward = -264.7369366114789
# Episode 367, step 27525, win = False, reward = -377.74256107633755
# Episode 368, step 27600, win = False, reward = -445.6348214913816
# Episode 369, step 27675, win = False, reward = -169.29160216799968
# Episode 370, step 27750, win = False, reward = -328.1317583088821
# Episode 371, step 27825, win = False, reward = -243.47872251055196
# Episode 372, step 27900, win = False, reward = -352.8787309382466
# Episode 373, step 27975, win = False, reward = -339.7125177251981
# Episode 374, step 28050, win = False, reward = -309.7712016186959
# Episode 375, step 28125, win = False, reward = -295.4915769799404
# Episode 376, step 28200, win = False, reward = -249.03419702931438
# Episode 377, step 28275, win = False, reward = -284.6687421778567
# Episode 378, step 28350, win = False, reward = -274.8544174665031
# Episode 379, step 28425, win = False, reward = -308.7101383255923
# Episode 380, step 28500, win = False, reward = -163.14988963554603
# Episode 381, step 28575, win = False, reward = -306.7370063879723
# Episode 382, step 28650, win = False, reward = -339.80098747838855
# Episode 383, step 28725, win = False, reward = -640.6492422860631
# Episode 384, step 28800, win = False, reward = -277.26719643779603
# Episode 385, step 28875, win = False, reward = -455.4483403338329
# Episode 386, step 28950, win = False, reward = -255.4353098889406
# Episode 387, step 29025, win = False, reward = -292.3754837296291
# Episode 388, step 29100, win = False, reward = -374.45666973813906
# Episode 389, step 29175, win = False, reward = -279.0511472598605
# Episode 390, step 29250, win = False, reward = -347.1264152157037
# Episode 391, step 29325, win = False, reward = -279.4760525378988
# Episode 392, step 29400, win = False, reward = -344.8447219228386
# Episode 393, step 29475, win = False, reward = -249.72681029671546
# Episode 394, step 29550, win = False, reward = -389.34539765118984
# Episode 395, step 29625, win = False, reward = -355.2705570693503
# Episode 396, step 29700, win = False, reward = -278.9199280046318
# Episode 397, step 29775, win = False, reward = -549.12681147047
# Episode 398, step 29850, win = False, reward = -400.42387476663873
# Episode 399, step 29925, win = False, reward = -199.28657625105296
# Episode 400, step 30000, win = False, reward = -233.56844613571636
# Test reward = -768.3513464666477, win_rate = 0.0
# Episode 401, step 30075, win = False, reward = -283.2475328355266
# Episode 402, step 30150, win = False, reward = -285.8750067532385
# Episode 403, step 30225, win = False, reward = -387.48571759399914
# Episode 404, step 30300, win = False, reward = -331.3156922239598
# Episode 405, step 30375, win = False, reward = -237.36639642110958
# Episode 406, step 30450, win = False, reward = -251.45445577875503
# Episode 407, step 30525, win = False, reward = -488.3004014021391
# Episode 408, step 30600, win = False, reward = -283.5164035167667
# Episode 409, step 30675, win = False, reward = -217.94685788315502
# Episode 410, step 30750, win = False, reward = -373.4806956359336
# Episode 411, step 30825, win = False, reward = -296.7158350671295
# Episode 412, step 30900, win = False, reward = -350.52684741900015
# Episode 413, step 30975, win = False, reward = -318.38614519631466
# Episode 414, step 31050, win = False, reward = -191.99220492706033
# Episode 415, step 31125, win = False, reward = -330.62258861672063
# Episode 416, step 31200, win = False, reward = -387.2609539569413
# Episode 417, step 31275, win = False, reward = -258.2555349351839
# Episode 418, step 31350, win = False, reward = -200.08828417986686
# Episode 419, step 31425, win = False, reward = -326.66534845233144
# Episode 420, step 31500, win = False, reward = -241.4701973005941
# Episode 421, step 31575, win = False, reward = -244.156278785054
# Episode 422, step 31650, win = False, reward = -223.0646537025635
# Episode 423, step 31725, win = False, reward = -322.27503254301894
# Episode 424, step 31800, win = False, reward = -183.2069063415533
# Episode 425, step 31875, win = False, reward = -323.10681659112214
# Episode 426, step 31950, win = False, reward = -193.48891978126352
# Episode 427, step 32025, win = False, reward = -332.2570001756682
# Episode 428, step 32100, win = False, reward = -220.53039545539968
# Episode 429, step 32175, win = False, reward = -266.6317482175356
# Episode 430, step 32250, win = False, reward = -310.04514975720826
# Episode 431, step 32325, win = False, reward = -345.3389763122785
# Episode 432, step 32400, win = False, reward = -439.6626005646936
# Episode 433, step 32475, win = False, reward = -660.9387100470418
# Episode 434, step 32550, win = False, reward = -287.55745315834037
# Episode 435, step 32625, win = False, reward = -219.66676515650593
# Episode 436, step 32700, win = False, reward = -486.69456272510075
# Episode 437, step 32775, win = False, reward = -205.07187193475818
# Episode 438, step 32850, win = False, reward = -280.6200549487129
# Episode 439, step 32925, win = False, reward = -269.3046160697748
# Episode 440, step 33000, win = False, reward = -351.24323282227135
# Episode 441, step 33075, win = False, reward = -388.7544782964618
# Episode 442, step 33150, win = False, reward = -224.73247271273405
# Episode 443, step 33225, win = False, reward = -438.5169256422648
# Episode 444, step 33300, win = False, reward = -412.9548390806663
# Episode 445, step 33375, win = False, reward = -268.9875967191856
# Episode 446, step 33450, win = False, reward = -260.4948680888907
# Episode 447, step 33525, win = False, reward = -201.98615193211577
# Episode 448, step 33600, win = False, reward = -237.66664950089526
# Episode 449, step 33675, win = False, reward = -189.5719056359135
# Episode 450, step 33750, win = False, reward = -233.67662040243755
# Episode 451, step 33825, win = False, reward = -303.1236395236099
# Episode 452, step 33900, win = False, reward = -289.6615446793342
# Episode 453, step 33975, win = False, reward = -206.59233981621756
# Episode 454, step 34050, win = False, reward = -207.33584779350622
# Episode 455, step 34125, win = False, reward = -366.59041483086156
# Episode 456, step 34200, win = False, reward = -226.64884614946558
# Episode 457, step 34275, win = False, reward = -244.85069426815772
# Episode 458, step 34350, win = False, reward = -167.5796742675279
# Episode 459, step 34425, win = False, reward = -291.8184286797501
# Episode 460, step 34500, win = False, reward = -320.98513739193334
# Episode 461, step 34575, win = False, reward = -149.95629046098702
# Episode 462, step 34650, win = False, reward = -217.49927832002865
# Episode 463, step 34725, win = False, reward = -278.0535350712698
# Episode 464, step 34800, win = False, reward = -323.5122124265264
# Episode 465, step 34875, win = False, reward = -448.38857762040556
# Episode 466, step 34950, win = False, reward = -385.61959162839065
# Episode 467, step 35025, win = False, reward = -287.9332988838434
# Episode 468, step 35100, win = False, reward = -322.0687244611306
# Episode 469, step 35175, win = False, reward = -292.86429160913343
# Episode 470, step 35250, win = False, reward = -357.3700533472363
# Episode 471, step 35325, win = False, reward = -444.603872032316
# Episode 472, step 35400, win = False, reward = -272.6673725996621
# Episode 473, step 35475, win = False, reward = -383.1275285026109
# Episode 474, step 35550, win = False, reward = -515.5053843464215
# Episode 475, step 35625, win = False, reward = -545.2230474916596
# Episode 476, step 35700, win = False, reward = -295.7108217543888
# Episode 477, step 35775, win = False, reward = -266.9292964355249
# Episode 478, step 35850, win = False, reward = -225.05579157543505
# Episode 479, step 35925, win = False, reward = -280.6920751537185
# Episode 480, step 36000, win = False, reward = -253.80147103074307
# Episode 481, step 36075, win = False, reward = -259.9704583422339
# Episode 482, step 36150, win = False, reward = -227.74104736651233
# Episode 483, step 36225, win = False, reward = -269.12566443314677
# Episode 484, step 36300, win = False, reward = -183.24418502121958
# Episode 485, step 36375, win = False, reward = -167.8554983797499
# Episode 486, step 36450, win = False, reward = -181.1355111864663
# Episode 487, step 36525, win = False, reward = -234.06379182562708
# Episode 488, step 36600, win = False, reward = -234.3719925963841
# Episode 489, step 36675, win = False, reward = -248.71237996034282
# Episode 490, step 36750, win = False, reward = -368.6327858152875
# Episode 491, step 36825, win = False, reward = -182.16371808399788
# Episode 492, step 36900, win = False, reward = -313.8556665180722
# Episode 493, step 36975, win = False, reward = -219.88704858228812
# Episode 494, step 37050, win = False, reward = -329.8528318463621
# Episode 495, step 37125, win = False, reward = -430.54730821248927
# Episode 496, step 37200, win = False, reward = -226.83187167591726
# Episode 497, step 37275, win = False, reward = -222.4615027476341
# Episode 498, step 37350, win = False, reward = -381.532499528759
# Episode 499, step 37425, win = False, reward = -242.13234886596135
# Episode 500, step 37500, win = False, reward = -189.00203015508077
# Episode 501, step 37575, win = False, reward = -333.85041599561157
# Episode 502, step 37650, win = False, reward = -239.6956695365232
# Episode 503, step 37725, win = False, reward = -148.34891264264652
# Episode 504, step 37800, win = False, reward = -403.18628279346547
# Episode 505, step 37875, win = False, reward = -310.67379131397104
# Episode 506, step 37950, win = False, reward = -184.1353686934838
# Episode 507, step 38025, win = False, reward = -273.77494322471404
# Episode 508, step 38100, win = False, reward = -282.8292039649027
# Episode 509, step 38175, win = False, reward = -223.7693834474225
# Episode 510, step 38250, win = False, reward = -147.82836420151827
# Episode 511, step 38325, win = False, reward = -226.66262906172156
# Episode 512, step 38400, win = False, reward = -296.36402052283944
# Episode 513, step 38475, win = False, reward = -456.38780679197794
# Episode 514, step 38550, win = False, reward = -259.9461461246837
# Episode 515, step 38625, win = False, reward = -259.4659859182466
# Episode 516, step 38700, win = False, reward = -476.4041303122693
# Episode 517, step 38775, win = False, reward = -234.4544103482156
# Episode 518, step 38850, win = False, reward = -244.1052034062791
# Episode 519, step 38925, win = False, reward = -425.47384459603586
# Episode 520, step 39000, win = False, reward = -276.7515227379226
# Episode 521, step 39075, win = False, reward = -336.8427641816197
# Episode 522, step 39150, win = False, reward = -220.36244361287802
# Episode 523, step 39225, win = False, reward = -323.7224450046889
# Episode 524, step 39300, win = False, reward = -444.5289492778701
# Episode 525, step 39375, win = False, reward = -208.71946113187178
# Episode 526, step 39450, win = False, reward = -216.70679002181305
# Episode 527, step 39525, win = False, reward = -256.74708403972284
# Episode 528, step 39600, win = False, reward = -502.2740423042567
# Episode 529, step 39675, win = False, reward = -270.6137261217031
# Episode 530, step 39750, win = False, reward = -165.29980081873524
# Episode 531, step 39825, win = False, reward = -287.5942666956478
# Episode 532, step 39900, win = False, reward = -339.57405763577304
# Episode 533, step 39975, win = False, reward = -470.1077538326484
# Episode 534, step 40050, win = False, reward = -265.53577787914486
# Test reward = -720.4656706577086, win_rate = 0.0
# Episode 535, step 40125, win = False, reward = -272.8276031005792
# Episode 536, step 40200, win = False, reward = -358.2570004626842
# Episode 537, step 40275, win = False, reward = -193.86292953283802
# Episode 538, step 40350, win = False, reward = -279.8030857799955
# Episode 539, step 40425, win = False, reward = -449.52619720488843
# Episode 540, step 40500, win = False, reward = -300.2907573165202
# Episode 541, step 40575, win = False, reward = -232.80668529833108
# Episode 542, step 40650, win = False, reward = -216.41443616895702
# Episode 543, step 40725, win = False, reward = -338.1790610980938
# Episode 544, step 40800, win = False, reward = -381.31479375041397
# Episode 545, step 40875, win = False, reward = -302.8615186686663
# Episode 546, step 40950, win = False, reward = -363.5700140659864
# Episode 547, step 41025, win = False, reward = -331.2332677892917
# Episode 548, step 41100, win = False, reward = -365.97617945355717
# Episode 549, step 41175, win = False, reward = -313.77269007074005
# Episode 550, step 41250, win = False, reward = -246.54166479108179
# Episode 551, step 41325, win = False, reward = -175.31571784380847
# Episode 552, step 41400, win = False, reward = -467.31999093698454
# Episode 553, step 41475, win = False, reward = -418.76957165024163
# Episode 554, step 41550, win = False, reward = -195.13560998608213
# Episode 555, step 41625, win = False, reward = -251.53464613488907
# Episode 556, step 41700, win = False, reward = -200.40276119293543
# Episode 557, step 41775, win = False, reward = -208.16603843096752
# Episode 558, step 41850, win = False, reward = -192.27342854351716
# Episode 559, step 41925, win = False, reward = -314.65467136697396
# Episode 560, step 42000, win = False, reward = -347.21241665156424
# Episode 561, step 42075, win = False, reward = -225.50382324783436
# Episode 562, step 42150, win = False, reward = -251.55362632860462
# Episode 563, step 42225, win = False, reward = -390.0614639583588
# Episode 564, step 42300, win = False, reward = -398.2941242600286
# Episode 565, step 42375, win = False, reward = -245.233916709298
# Episode 566, step 42450, win = False, reward = -331.8848282009373
# Episode 567, step 42525, win = False, reward = -395.097775014258
# Episode 568, step 42600, win = False, reward = -368.43303150645676
# Episode 569, step 42675, win = False, reward = -480.08526131872236
# Episode 570, step 42750, win = False, reward = -504.3552806768447
# Episode 571, step 42825, win = False, reward = -298.6484555582174
# Episode 572, step 42900, win = False, reward = -255.0705643338053
# Episode 573, step 42975, win = False, reward = -176.4836396573934
# Episode 574, step 43050, win = False, reward = -532.7969980078497
# Episode 575, step 43125, win = False, reward = -184.46436748675478
# Episode 576, step 43200, win = False, reward = -208.53089890305128
# Episode 577, step 43275, win = False, reward = -226.40822547171967
# Episode 578, step 43350, win = False, reward = -333.7150507922328
# Episode 579, step 43425, win = False, reward = -365.34508123095736
# Episode 580, step 43500, win = False, reward = -214.94422347348896
# Episode 581, step 43575, win = False, reward = -196.22934688402066
# Episode 582, step 43650, win = False, reward = -268.629482182557
# Episode 583, step 43725, win = False, reward = -315.8366152685714
# Episode 584, step 43800, win = False, reward = -279.49664647862284
# Episode 585, step 43875, win = False, reward = -159.22259231185018
# Episode 586, step 43950, win = False, reward = -579.0091165090519
# Episode 587, step 44025, win = False, reward = -342.146433468262
# Episode 588, step 44100, win = False, reward = -325.17521180104796
# Episode 589, step 44175, win = False, reward = -227.44996465093402
# Episode 590, step 44250, win = False, reward = -469.1981204231163
# Episode 591, step 44325, win = False, reward = -286.7612824683333
# Episode 592, step 44400, win = False, reward = -407.68443501900055
# Episode 593, step 44475, win = False, reward = -258.46619475405566
# Episode 594, step 44550, win = False, reward = -649.1011603719558
# Episode 595, step 44625, win = False, reward = -439.53047000834107
# Episode 596, step 44700, win = False, reward = -315.64850012383806
# Episode 597, step 44775, win = False, reward = -251.42988395542147
# Episode 598, step 44850, win = False, reward = -218.28354204792447
# Episode 599, step 44925, win = False, reward = -222.0029997850619
# Episode 600, step 45000, win = False, reward = -296.27476066522166
# Episode 601, step 45075, win = False, reward = -262.2772940616818
# Episode 602, step 45150, win = False, reward = -238.13214125752924
# Episode 603, step 45225, win = False, reward = -353.6088698652788
# Episode 604, step 45300, win = False, reward = -253.5261441880032
# Episode 605, step 45375, win = False, reward = -462.85445288901644
# Episode 606, step 45450, win = False, reward = -413.63783878513635
# Episode 607, step 45525, win = False, reward = -263.0772803973412
# Episode 608, step 45600, win = False, reward = -262.7057038910682
# Episode 609, step 45675, win = False, reward = -288.1244904976937
# Episode 610, step 45750, win = False, reward = -228.31445762149542
# Episode 611, step 45825, win = False, reward = -260.9918203404368
# Episode 612, step 45900, win = False, reward = -272.1017402408805
# Episode 613, step 45975, win = False, reward = -244.50228690676326
# Episode 614, step 46050, win = False, reward = -399.03870178119445
# Episode 615, step 46125, win = False, reward = -342.79739766993976
# Episode 616, step 46200, win = False, reward = -345.3018869046337
# Episode 617, step 46275, win = False, reward = -449.00132458845616
# Episode 618, step 46350, win = False, reward = -244.94670032927752
# Episode 619, step 46425, win = False, reward = -248.99639696382184
# Episode 620, step 46500, win = False, reward = -188.50305748101962
# Episode 621, step 46575, win = False, reward = -322.654457730295
# Episode 622, step 46650, win = False, reward = -256.47970064064435
# Episode 623, step 46725, win = False, reward = -295.75627404720575
# Episode 624, step 46800, win = False, reward = -296.00871510433814
# Episode 625, step 46875, win = False, reward = -264.1184179196055
# Episode 626, step 46950, win = False, reward = -278.93938654991223
# Episode 627, step 47025, win = False, reward = -277.08628651534883
# Episode 628, step 47100, win = False, reward = -312.4301288842465
# Episode 629, step 47175, win = False, reward = -467.715683848023
# Episode 630, step 47250, win = False, reward = -240.12426561736612
# Episode 631, step 47325, win = False, reward = -173.17555216519344
# Episode 632, step 47400, win = False, reward = -283.7556996448152
# Episode 633, step 47475, win = False, reward = -336.6060297368722
# Episode 634, step 47550, win = False, reward = -231.81060336982452
# Episode 635, step 47625, win = False, reward = -392.15353868994134
# Episode 636, step 47700, win = False, reward = -330.34776149004875
# Episode 637, step 47775, win = False, reward = -424.89465421467156
# Episode 638, step 47850, win = False, reward = -343.1540248017961
# Episode 639, step 47925, win = False, reward = -357.3672011999649
# Episode 640, step 48000, win = False, reward = -344.6744634713026
# Episode 641, step 48075, win = False, reward = -310.54037343650754
# Episode 642, step 48150, win = False, reward = -240.03997454274665
# Episode 643, step 48225, win = False, reward = -285.250387307774
# Episode 644, step 48300, win = False, reward = -233.36702485974035
# Episode 645, step 48375, win = False, reward = -243.84020783050997
# Episode 646, step 48450, win = False, reward = -328.8941149081296
# Episode 647, step 48525, win = False, reward = -220.86285420231806
# Episode 648, step 48600, win = False, reward = -362.5885234251819
# Episode 649, step 48675, win = False, reward = -302.18573905876036
# Episode 650, step 48750, win = False, reward = -548.6378528608135
# Episode 651, step 48825, win = False, reward = -272.81328627892884
# Episode 652, step 48900, win = False, reward = -227.13736818291653
# Episode 653, step 48975, win = False, reward = -263.8818161425651
# Episode 654, step 49050, win = False, reward = -304.2774304519491
# Episode 655, step 49125, win = False, reward = -388.60056699046817
# Episode 656, step 49200, win = False, reward = -317.8593409331595
# Episode 657, step 49275, win = False, reward = -225.88540295441928
# Episode 658, step 49350, win = False, reward = -210.09770817771027
# Episode 659, step 49425, win = False, reward = -176.2896641476382
# Episode 660, step 49500, win = False, reward = -270.75722794109987
# Episode 661, step 49575, win = False, reward = -218.86196385963632
# Episode 662, step 49650, win = False, reward = -340.8757974696426
# Episode 663, step 49725, win = False, reward = -260.73713825790696
# Episode 664, step 49800, win = False, reward = -284.8220143906433
# Episode 665, step 49875, win = False, reward = -179.34043321541512
# Episode 666, step 49950, win = False, reward = -275.01047209661124
# Episode 667, step 50025, win = False, reward = -381.4742504435464
# Test reward = -232.6328247871605, win_rate = 0.0
# Episode 668, step 50100, win = False, reward = -204.29250064039405
# Episode 669, step 50175, win = False, reward = -217.03444727486172
# Episode 670, step 50250, win = False, reward = -215.33768077005755
# Episode 671, step 50325, win = False, reward = -304.86202527666654
# Episode 672, step 50400, win = False, reward = -405.28352843111406
# Episode 673, step 50475, win = False, reward = -184.89206520096675
# Episode 674, step 50550, win = False, reward = -342.19435597711043
# Episode 675, step 50625, win = False, reward = -249.14973030095973
# Episode 676, step 50700, win = False, reward = -310.36461771265715
# Episode 677, step 50775, win = False, reward = -383.6138256878736
# Episode 678, step 50850, win = False, reward = -358.96385376931113
# Episode 679, step 50925, win = False, reward = -293.8329802585232
# Episode 680, step 51000, win = False, reward = -195.71618393163834
# Episode 681, step 51075, win = False, reward = -202.68953413914755
# Episode 682, step 51150, win = False, reward = -183.55964273180308
# Episode 683, step 51225, win = False, reward = -258.1477313425269
# Episode 684, step 51300, win = False, reward = -592.9520845173689
# Episode 685, step 51375, win = False, reward = -416.40644284731246
# Episode 686, step 51450, win = False, reward = -326.22355754706905
# Episode 687, step 51525, win = False, reward = -270.87742896320214
# Episode 688, step 51600, win = False, reward = -239.04703802802183
# Episode 689, step 51675, win = False, reward = -372.98287457431263
# Episode 690, step 51750, win = False, reward = -192.62899677350327
# Episode 691, step 51825, win = False, reward = -205.9109119871191
# Episode 692, step 51900, win = False, reward = -466.80420235419433
# Episode 693, step 51975, win = False, reward = -198.7178353389389
# Episode 694, step 52050, win = False, reward = -171.85834517147032
# Episode 695, step 52125, win = False, reward = -309.30420025662403
# Episode 696, step 52200, win = False, reward = -218.57716650986544
# Episode 697, step 52275, win = False, reward = -181.2287956207089
# Episode 698, step 52350, win = False, reward = -196.46551145132824
# Episode 699, step 52425, win = False, reward = -163.07549824165378
# Episode 700, step 52500, win = False, reward = -256.15973073454626
# Episode 701, step 52575, win = False, reward = -294.5405790952102
# Episode 702, step 52650, win = False, reward = -269.24560863080444
# Episode 703, step 52725, win = False, reward = -349.2812403861376
# Episode 704, step 52800, win = False, reward = -222.26255282742534
# Episode 705, step 52875, win = False, reward = -133.93026044017182
# Episode 706, step 52950, win = False, reward = -311.63394315682757
# Episode 707, step 53025, win = False, reward = -259.27354383313957
# Episode 708, step 53100, win = False, reward = -249.3069292998511
# Episode 709, step 53175, win = False, reward = -248.51295674115204
# Episode 710, step 53250, win = False, reward = -200.50784539310413
# Episode 711, step 53325, win = False, reward = -255.62232707966731
# Episode 712, step 53400, win = False, reward = -264.959776206706
# Episode 713, step 53475, win = False, reward = -292.60013476183906
# Episode 714, step 53550, win = False, reward = -217.5601810042811
# Episode 715, step 53625, win = False, reward = -296.34412771465134
# ...
# Episode 3422, step 256650, win = False, reward = -213.53219720131014
# Episode 3423, step 256725, win = False, reward = -129.2693287626641
# Episode 3424, step 256800, win = False, reward = -138.8987524824967
# Episode 3425, step 256875, win = False, reward = -204.35831247879557
# Episode 3426, step 256950, win = False, reward = -193.63242678572794
# Episode 3427, step 257025, win = False, reward = -206.390446784437
# Episode 3428, step 257100, win = False, reward = -137.6211354875772
# Episode 3429, step 257175, win = False, reward = -172.74871271968385
# Episode 3430, step 257250, win = False, reward = -276.9862603574131
# Episode 3431, step 257325, win = False, reward = -207.55918747045246
# Episode 3432, step 257400, win = False, reward = -189.87889895865234
# Episode 3433, step 257475, win = False, reward = -158.35728615431373
# Episode 3434, step 257550, win = False, reward = -189.22661071217115
# Episode 3435, step 257625, win = False, reward = -155.4521838000459
# Episode 3436, step 257700, win = False, reward = -174.6640724709214
# Episode 3437, step 257775, win = False, reward = -170.97454126301625
# Episode 3438, step 257850, win = False, reward = -175.85580207169784
# Episode 3439, step 257925, win = False, reward = -206.06204874254146
# Episode 3440, step 258000, win = False, reward = -187.79020246517487
# Episode 3441, step 258075, win = False, reward = -204.40244489186557
# Episode 3442, step 258150, win = False, reward = -177.1710165301015
# Episode 3443, step 258225, win = False, reward = -200.70562659034385
# Episode 3444, step 258300, win = False, reward = -183.91804487740404
# Episode 3445, step 258375, win = False, reward = -184.31771394095495
# Episode 3446, step 258450, win = False, reward = -211.9947202964494
# Episode 3447, step 258525, win = False, reward = -197.26984498012516
# Episode 3448, step 258600, win = False, reward = -232.3808970431002
# Episode 3449, step 258675, win = False, reward = -273.67086382089155
# Episode 3450, step 258750, win = False, reward = -180.05736166570443
# Episode 3451, step 258825, win = False, reward = -184.8448033540259
# Episode 3452, step 258900, win = False, reward = -205.34270350646048
# Episode 3453, step 258975, win = False, reward = -339.1894763268839
# Episode 3454, step 259050, win = False, reward = -238.06520577201846
# Episode 3455, step 259125, win = False, reward = -268.1612271605063
# Episode 3456, step 259200, win = False, reward = -222.47872411437865
# Episode 3457, step 259275, win = False, reward = -191.1158643174787
# Episode 3458, step 259350, win = False, reward = -194.17315807656848
# Episode 3459, step 259425, win = False, reward = -255.85281247714883
# Episode 3460, step 259500, win = False, reward = -177.8403939634644
# Episode 3461, step 259575, win = False, reward = -131.15654201757397
# Episode 3462, step 259650, win = False, reward = -140.5246488978993
# Episode 3463, step 259725, win = False, reward = -147.09473287976294
# Episode 3464, step 259800, win = False, reward = -170.30065977816355
# Episode 3465, step 259875, win = False, reward = -124.18372334722812
# Episode 3466, step 259950, win = False, reward = -196.40186358243122
# Episode 3467, step 260025, win = False, reward = -132.62599888403986
# Test reward = -206.01271256622672, win_rate = 0.0
# Episode 3468, step 260100, win = False, reward = -190.66634855648115
# Episode 3469, step 260175, win = False, reward = -264.7313243601692
# Episode 3470, step 260250, win = False, reward = -243.92556789444427
# Episode 3471, step 260325, win = False, reward = -180.02218259160682
# Episode 3472, step 260400, win = False, reward = -212.4882276983286
# Episode 3473, step 260475, win = False, reward = -179.06977142408923
# Episode 3474, step 260550, win = False, reward = -182.23748288148224
# Episode 3475, step 260625, win = False, reward = -156.88294214337262
# Episode 3476, step 260700, win = False, reward = -197.96846751218027
# Episode 3477, step 260775, win = False, reward = -166.1308574512641
# Episode 3478, step 260850, win = False, reward = -275.37631831785035
# Episode 3479, step 260925, win = False, reward = -269.08011602970475
# Episode 3480, step 261000, win = False, reward = -250.04243280068977
# Episode 3481, step 261075, win = False, reward = -195.77092838987218
# Episode 3482, step 261150, win = False, reward = -177.49198975463366
# Episode 3483, step 261225, win = False, reward = -167.6355496081758
# Episode 3484, step 261300, win = False, reward = -199.22130086597505
# Episode 3485, step 261375, win = False, reward = -151.53258743305264
# Episode 3486, step 261450, win = False, reward = -185.7787974393661
# Episode 3487, step 261525, win = False, reward = -233.7289274217939
# Episode 3488, step 261600, win = False, reward = -160.3342463609876
# Episode 3489, step 261675, win = False, reward = -199.72100143941174
# Episode 3490, step 261750, win = False, reward = -183.63823848513684
# Episode 3491, step 261825, win = False, reward = -211.74145276334986
# Episode 3492, step 261900, win = False, reward = -227.505202385855
# Episode 3493, step 261975, win = False, reward = -267.725568425009
# Episode 3494, step 262050, win = False, reward = -227.0846105943469
# Episode 3495, step 262125, win = False, reward = -183.38105494602885
# Episode 3496, step 262200, win = False, reward = -131.23865888062062
# Episode 3497, step 262275, win = False, reward = -237.5574075489676
# Episode 3498, step 262350, win = False, reward = -204.52489208482905
# Episode 3499, step 262425, win = False, reward = -289.06960793094214
# Episode 3500, step 262500, win = False, reward = -215.81660176614608
# Episode 3501, step 262575, win = False, reward = -232.07020677359452
# Episode 3502, step 262650, win = False, reward = -129.94733898500257
# Episode 3503, step 262725, win = False, reward = -161.1421441887839
# Episode 3504, step 262800, win = False, reward = -249.9863043152177
# Episode 3505, step 262875, win = False, reward = -248.4494368836416
# Episode 3506, step 262950, win = False, reward = -132.87136296522132
# Episode 3507, step 263025, win = False, reward = -153.88136954911315
# Episode 3508, step 263100, win = False, reward = -255.84566068282268
# Episode 3509, step 263175, win = False, reward = -212.02387745882714
# Episode 3510, step 263250, win = False, reward = -158.7643338164169
# Episode 3511, step 263325, win = False, reward = -176.77707747835774
# Episode 3512, step 263400, win = False, reward = -204.41098743568065
# Episode 3513, step 263475, win = False, reward = -178.478767071755
# Episode 3514, step 263550, win = False, reward = -129.17510911757788
# Episode 3515, step 263625, win = False, reward = -179.43756954356434
# Episode 3516, step 263700, win = False, reward = -154.62105950213947
# Episode 3517, step 263775, win = False, reward = -142.20194533421537
# Episode 3518, step 263850, win = False, reward = -195.39096456050947
# Episode 3519, step 263925, win = False, reward = -190.84836022312737
# Episode 3520, step 264000, win = False, reward = -179.5937422241665
# Episode 3521, step 264075, win = False, reward = -255.52337061664502
# Episode 3522, step 264150, win = False, reward = -175.19849101567232
# Episode 3523, step 264225, win = False, reward = -116.90623402215513
# Episode 3524, step 264300, win = False, reward = -156.2726125431622
# Episode 3525, step 264375, win = False, reward = -170.8419711329281
# Episode 3526, step 264450, win = False, reward = -183.06480146263794
# Episode 3527, step 264525, win = False, reward = -243.03884842397449
# Episode 3528, step 264600, win = False, reward = -133.12424053552937
# Episode 3529, step 264675, win = False, reward = -162.20593966849827
# Episode 3530, step 264750, win = False, reward = -234.4330209235387
# Episode 3531, step 264825, win = False, reward = -190.26117050692795
# Episode 3532, step 264900, win = False, reward = -232.2951847633684
# Episode 3533, step 264975, win = False, reward = -152.6895270304731
# Episode 3534, step 265050, win = False, reward = -237.38913739885274
# Episode 3535, step 265125, win = False, reward = -162.6049043217449
# Episode 3536, step 265200, win = False, reward = -208.33625486346054
# Episode 3537, step 265275, win = False, reward = -230.32026750195698
# Episode 3538, step 265350, win = False, reward = -268.49234856720693
# Episode 3539, step 265425, win = False, reward = -150.00931771869662
# Episode 3540, step 265500, win = False, reward = -174.90194918083463
# Episode 3541, step 265575, win = False, reward = -202.60347644136775
# Episode 3542, step 265650, win = False, reward = -175.33776848885893
# Episode 3543, step 265725, win = False, reward = -238.1719744654847
# Episode 3544, step 265800, win = False, reward = -175.1064674722954
# Episode 3545, step 265875, win = False, reward = -140.1572686788993
# Episode 3546, step 265950, win = False, reward = -203.05716912904066
# Episode 3547, step 266025, win = False, reward = -187.56374144885797
# Episode 3548, step 266100, win = False, reward = -127.77179647892429
# Episode 3549, step 266175, win = False, reward = -152.7810560441789
# Episode 3550, step 266250, win = False, reward = -182.23059456171157
# Episode 3551, step 266325, win = False, reward = -197.9884650304202
# Episode 3552, step 266400, win = False, reward = -196.9376358910834
# Episode 3553, step 266475, win = False, reward = -176.85958109699305
# Episode 3554, step 266550, win = False, reward = -198.42658525672894
# Episode 3555, step 266625, win = False, reward = -205.00642638482654
# Episode 3556, step 266700, win = False, reward = -162.05167799480745
# Episode 3557, step 266775, win = False, reward = -114.48827270791261
# Episode 3558, step 266850, win = False, reward = -195.6111621876929
# Episode 3559, step 266925, win = False, reward = -180.93772596075885
# Episode 3560, step 267000, win = False, reward = -196.72505076775207
# Episode 3561, step 267075, win = False, reward = -194.64582405291307
# Episode 3562, step 267150, win = False, reward = -229.99619312975588
# Episode 3563, step 267225, win = False, reward = -250.89883291044293
# Episode 3564, step 267300, win = False, reward = -184.84318147609218
# Episode 3565, step 267375, win = False, reward = -170.83548961472937
# Episode 3566, step 267450, win = False, reward = -177.57685468020208
# Episode 3567, step 267525, win = False, reward = -226.645091422077
# Episode 3568, step 267600, win = False, reward = -186.19393843126835
# Episode 3569, step 267675, win = False, reward = -135.080962254984
# Episode 3570, step 267750, win = False, reward = -202.4025800153158
# Episode 3571, step 267825, win = False, reward = -165.51328661410608
# Episode 3572, step 267900, win = False, reward = -199.67127657732172
# Episode 3573, step 267975, win = False, reward = -245.1539445069629
# Episode 3574, step 268050, win = False, reward = -139.8609172600367
# Episode 3575, step 268125, win = False, reward = -246.83580807389157
# Episode 3576, step 268200, win = False, reward = -233.99734446979005
# Episode 3577, step 268275, win = False, reward = -220.90524831085693
# Episode 3578, step 268350, win = False, reward = -157.75450328604992
# Episode 3579, step 268425, win = False, reward = -176.01223685855288
# Episode 3580, step 268500, win = False, reward = -189.73411622619932
# Episode 3581, step 268575, win = False, reward = -189.17199807184477
# Episode 3582, step 268650, win = False, reward = -211.48729958627655
# Episode 3583, step 268725, win = False, reward = -166.68796600091085
# Episode 3584, step 268800, win = False, reward = -124.55438449126108
# Episode 3585, step 268875, win = False, reward = -122.61239953096917
# Episode 3586, step 268950, win = False, reward = -136.08071538867773
# Episode 3587, step 269025, win = False, reward = -259.69982896668483
# Episode 3588, step 269100, win = False, reward = -146.6550254429586
# Episode 3589, step 269175, win = False, reward = -222.11920768547415
# Episode 3590, step 269250, win = False, reward = -170.33409857981144
# Episode 3591, step 269325, win = False, reward = -214.8559023691397
# Episode 3592, step 269400, win = False, reward = -258.1295852325667
# Episode 3593, step 269475, win = False, reward = -148.8353151086777
# Episode 3594, step 269550, win = False, reward = -242.9233198408047
# Episode 3595, step 269625, win = False, reward = -197.30646325897163
# Episode 3596, step 269700, win = False, reward = -239.93998713719907
# Episode 3597, step 269775, win = False, reward = -243.71956628851794
# Episode 3598, step 269850, win = False, reward = -195.60511352832293
# Episode 3599, step 269925, win = False, reward = -176.43377579376957
# Episode 3600, step 270000, win = False, reward = -191.03244024239245
# Test reward = -219.22521718230828, win_rate = 0.0
# Episode 3601, step 270075, win = False, reward = -170.8917532940855
# Episode 3602, step 270150, win = False, reward = -159.8768159290629
# Episode 3603, step 270225, win = False, reward = -192.8128035332369
# Episode 3604, step 270300, win = False, reward = -173.86285707495995
# Episode 3605, step 270375, win = False, reward = -164.5393096300016
# Episode 3606, step 270450, win = False, reward = -186.10533876270458
# Episode 3607, step 270525, win = False, reward = -213.535285130071
# Episode 3608, step 270600, win = False, reward = -160.40554166337446
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 899
#     897 experiment = Experiment(args)
#     898 experiment.start()
# --> 899 experiment.run()
#
# Cell In[4], line 784, in Experiment.run(self)
#     782 data = buffer.sample(args.n_batch, args.top_n)
#     783 if data:
# --> 784     loss = learner.train(data)
#     786 if self.step // args.test_every_step != old_step // args.test_every_step:
#     787     self.test_model()
#
# Cell In[4], line 471, in Learner.train(self, data)
#     469 Q1, hiddens1 = self.sys_critic1.forward(obs[:,i], avail_actions[:,i], hiddens1)
#     470 Q2, hiddens2 = self.sys_critic2.forward(obs[:,i], avail_actions[:,i], hiddens2)
# --> 471 p, hiddens_actor = self.sys_actor.forward(obs[:,i], avail_actions[:,i], hiddens_actor)
#     473 #with torch.no_grad():
#     475 Q1_tar, hiddens1_tar = self.sys_critic1_tar.forward(obs[:,i], avail_actions[:,i], hiddens1_tar)
#
# Cell In[4], line 163, in Actors.forward(self, states, avail_actions, hiddens)
#     161 hiddens = hiddens.reshape(-1,hiddens.shape[-1])
#     162 avail_actions = avail_actions.reshape(-1,avail_actions.shape[-1])
# --> 163 ys, hs_next = self.agent.forward(states, avail_actions, hiddens)
#     164 ys = ys.reshape(n_batch,self.n_agents,-1)
#     165 hs_next = hs_next.reshape(n_batch,self.n_agents,-1)
#
# Cell In[4], line 139, in Actor.forward(self, inputs, avail_actions, h_last)
#     136 def forward(self, inputs, avail_actions, h_last):
#     138     h = F.relu(self.fc1(inputs))
# --> 139     h = self.rnn(h, h_last)
#     140     y = self.fc2(h)
#     141     y[avail_actions == 0] = -float('inf')
#
# File ~/miniconda/envs/drlzh/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda/envs/drlzh/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/miniconda/envs/drlzh/lib/python3.11/site-packages/torch/nn/modules/rnn.py:1438, in GRUCell.forward(self, input, hx)
#    1435 else:
#    1436     hx = hx.unsqueeze(0) if not is_batched else hx
# -> 1438 ret = _VF.gru_cell(
#    1439     input, hx,
#    1440     self.weight_ih, self.weight_hh,
#    1441     self.bias_ih, self.bias_hh,
#    1442 )
#    1444 if not is_batched:
#    1445     ret = ret.squeeze(0)
#
# KeyboardInterrupt:
