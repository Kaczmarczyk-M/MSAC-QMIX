# %%
# %pip install stable-baselines3 numpy torch supersuit pettingzoo pymunk scipy gymnasium matplotlib einops tensorboard wandb imageio
# Out:
# Requirement already satisfied: stable-baselines3 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (2.4.1)
# Requirement already satisfied: numpy in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (1.26.4)
# Requirement already satisfied: torch in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: supersuit in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (3.9.3)
# Requirement already satisfied: pettingzoo in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (1.24.3)
# Requirement already satisfied: pymunk in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (6.10.0)
# Requirement already satisfied: scipy in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (1.15.0)
# Requirement already satisfied: gymnasium in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (0.29.1)
# Requirement already satisfied: matplotlib in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (3.9.2)
# Requirement already satisfied: einops in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (0.8.0)
# Requirement already satisfied: tensorboard in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (2.18.0)
# Requirement already satisfied: wandb in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (0.19.4)
# Requirement already satisfied: imageio in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (2.35.0)
# Requirement already satisfied: cloudpickle in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from stable-baselines3) (3.0.0)
# Requirement already satisfied: pandas in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from stable-baselines3) (2.2.3)
# Requirement already satisfied: filelock in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from torch) (1.13.2)
# Requirement already satisfied: networkx in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from torch) (2024.6.1)
# Requirement already satisfied: tinyscaler>=1.2.6 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from supersuit) (1.2.8)
# Requirement already satisfied: cffi>=1.17.1 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from pymunk) (1.17.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: absl-py>=0.4 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from tensorboard) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from tensorboard) (1.69.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from tensorboard) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from tensorboard) (5.29.3)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from tensorboard) (72.2.0)
# Requirement already satisfied: six>1.9 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from tensorboard) (3.1.3)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from wandb) (3.1.44)
# Requirement already satisfied: platformdirs in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from wandb) (4.2.2)
# Requirement already satisfied: psutil>=5.0.0 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from wandb) (6.0.0)
# Requirement already satisfied: pydantic<3,>=2.6 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from wandb) (2.10.5)
# Requirement already satisfied: pyyaml in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from wandb) (2.20.0)
# Requirement already satisfied: setproctitle in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from wandb) (1.3.4)
# Requirement already satisfied: pycparser in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from cffi>=1.17.1->pymunk) (2.22)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from pydantic<3,>=2.6->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from pydantic<3,>=2.6->wandb) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.5)
# Requirement already satisfied: pytz>=2020.1 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from pandas->stable-baselines3) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from pandas->stable-baselines3) (2024.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/michal/miniconda/envs/drlzh/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import datetime
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import random
from collections import deque
from typing import List, Dict, NamedTuple
import gymnasium as gym
from pettingzoo.mpe import simple_spread_v3
import os
from torch.utils.tensorboard import SummaryWriter
from argparse import Namespace
import time
import sys
import json


class WritterUtil:
    def __init__(self, writter: SummaryWriter, args):
        self.writter = writter
        self.log_every = args.log_every
        self.scalars = {}
        self.step = 0
        self.log_step = 0

    def set_step(self, step):
        self.step += 1
        self.log_step = step

    def WriteScalar(self, tag, value):
        
        step = self.step
        log_step = self.log_step
        self.writter.add_scalar('raw/'+tag, value, log_step)

        if tag not in self.scalars:
            self.scalars[tag] = [0, step-1, torch.zeros(self.log_every)]
        
        n, last_step, buffer = self.scalars[tag]
        
        buffer[n] = value
        n += 1
        if step - last_step >= self.log_every:
            mean = torch.mean(buffer[0:n])
            self.writter.add_scalar('mean/'+tag, mean, log_step)
            self.writter.add_histogram(tag, buffer[0:n], log_step)
            
            last_step = step
            n=0


        self.scalars[tag] = [n,last_step,buffer]

class Controller:
    def __init__(self, sys_agent, args):
        self.n_agents = args.n_agents
        self.n_actions = args.n_actions        
        self.agent_id = args.agent_id
        self.last_action = args.last_action
        self.device = args.device    
        self.sys_agent_src = sys_agent
        self.sys_agent = type(sys_agent)(args)        
        self.sys_agent.requires_grad_(False)        
        self.episode = 0

    def new_episode(self):
        state_dict = self.sys_agent_src.state_dict()
        self.sys_agent.load_state_dict(state_dict)        
        self.hiddens = self.sys_agent.init_hiddens(1)
        self.last_actions = torch.zeros(1, self.n_agents, self.n_actions)      
        self.episode += 1

    # def get_actions(self, states, avail_actions, explore=False):
                        
    #     states = torch.as_tensor(states).unsqueeze(0)
    #     avail_actions = torch.as_tensor(avail_actions).unsqueeze(0)
    #     if self.agent_id:
    #         agent_ids = torch.eye(self.n_agents,device=states.device)
    #         agent_ids = agent_ids.reshape((1,)*(states.ndim-2)+agent_ids.shape)            
    #         agent_ids = agent_ids.expand(states.shape[:-2]+(-1,-1))
    #         states = torch.cat([states,agent_ids],-1)
    #     if self.last_action:            
    #         states = torch.cat([states, self.last_actions],-1)
    #     with torch.no_grad():
    #         ps, hs_next = self.sys_agent.forward(states, avail_actions, self.hiddens)
    #     self.hiddens = hs_next
    #     #ps[avail_actions == 0] = 0
    #     while True:
    #         acts = torch.multinomial(ps[0],1).squeeze(-1)        
    #         #acts = torch.randint(self.n_actions, size=(self.n_agents,))
    #         selected_avails = avail_actions[0][torch.arange(self.n_agents),acts]
    #         if not (selected_avails == 0).sum().item():
    #             break

    #     if explore:
    #         actions = acts
    #     else:
    #         actions = torch.argmax(ps[0],-1)
    #     self.last_actions = self.one_hot(actions, self.n_actions).unsqueeze(0)
    #     return actions.numpy()
    def get_actions(self, states, avail_actions, explore=False):
        # Convert states to tensor and ensure proper dimensions
        states = torch.tensor(states, dtype=torch.float32, device=self.device)
        if states.dim() == 2:  # If states is [n_agents, state_dim]
            states = states.unsqueeze(0)  # Add batch dimension [1, n_agents, state_dim]
            
        avail_actions = torch.tensor(avail_actions, dtype=torch.float32, device=self.device)
        if avail_actions.dim() == 2:
            avail_actions = avail_actions.unsqueeze(0)
        
        if self.agent_id:
            agent_ids = torch.eye(self.n_agents, device=self.device)
            agent_ids = agent_ids.unsqueeze(0).expand(states.size(0), -1, -1)
            states = torch.cat([states, agent_ids], dim=-1)
        
        if self.last_action:            
            states = torch.cat([states, self.last_actions], -1)
        
        with torch.no_grad():
            ps, hs_next = self.sys_agent.forward(states, avail_actions, self.hiddens)
        self.hiddens = hs_next
        
        # Reshape probabilities for sampling
        batch_size, n_agents, n_actions = ps.shape
        ps_reshaped = ps.view(-1, n_actions)  # Reshape to 2D for multinomial
        
        if explore:
            # Sample actions
            actions_flat = torch.multinomial(ps_reshaped, 1).squeeze(-1)
            actions = actions_flat.view(batch_size, n_agents)
        else:
            actions = torch.argmax(ps, dim=-1)
        
        # Update last actions for next step
        self.last_actions = self.one_hot(actions, self.n_actions).unsqueeze(0)
        
        # Return actions for the current timestep
        return actions[0].cpu().numpy()  # Remove batch dimension and convert to numpy
    def one_hot(self, tensor, n_classes):
        return F.one_hot(tensor.to(dtype=torch.int64), n_classes).to(dtype=torch.float32)



class Actor(nn.Module):
    def __init__(self, args):
        super(Actor, self).__init__()
        self.args = args

        self.input_dim = args.input_dim        
        self.n_actions = args.n_actions
        self.n_agents = args.n_agents
        self.rnn_hidden_dim = args.rnn_hidden_dim

        self.fc1 = nn.Linear(self.input_dim, self.rnn_hidden_dim)
        self.rnn = nn.GRUCell(self.rnn_hidden_dim, self.rnn_hidden_dim)
        self.fc2 = nn.Linear(self.rnn_hidden_dim, self.n_actions)

    def init_hidden(self, n_batch):
        # make hidden states on same device as model
        return self.fc1.weight.new_zeros(n_batch, self.rnn_hidden_dim)

    def forward(self, inputs, avail_actions, h_last):
        
        h = F.relu(self.fc1(inputs))        
        h = self.rnn(h, h_last)
        y = self.fc2(h)
        y[avail_actions == 0] = -float('inf')
        y = torch.softmax(y,-1)

        return y,h
    
class Actors(nn.Module):
    def __init__(self, args):
        super(Actors, self).__init__()
        self.n_agents = args.n_agents
        self.n_actions = args.n_actions
        self.agent = Actor(args)

    def init_hiddens(self, n_batch):
        hiddens = self.agent.init_hidden(n_batch*self.n_agents)
        hiddens = hiddens.reshape(n_batch,self.n_agents,-1)
        return hiddens

    def forward(self, states, avail_actions, hiddens):
        n_batch = states.shape[0]
        states = states.reshape(-1,states.shape[-1])
        hiddens = hiddens.reshape(-1,hiddens.shape[-1])
        avail_actions = avail_actions.reshape(-1,avail_actions.shape[-1])
        ys, hs_next = self.agent.forward(states, avail_actions, hiddens)
        ys = ys.reshape(n_batch,self.n_agents,-1)
        hs_next = hs_next.reshape(n_batch,self.n_agents,-1)
        
        return ys, hs_next

class Critic(nn.Module):
    def __init__(self, args):
        super(Critic, self).__init__()
        self.args = args

        self.input_dim = args.input_dim
        
        self.n_actions = args.n_actions
        self.n_agents = args.n_agents
        self.rnn_hidden_dim = args.rnn_hidden_dim

        self.fc1 = nn.Linear(self.input_dim, self.rnn_hidden_dim)
        self.rnn = nn.GRUCell(self.rnn_hidden_dim, self.rnn_hidden_dim)
        self.fc2 = nn.Linear(self.rnn_hidden_dim, self.n_actions)

    def init_hidden(self, n_batch):
        # make hidden states on same device as model
        return self.fc1.weight.new_zeros(n_batch, self.rnn_hidden_dim)

    def forward(self, inputs, avail_actions, h_last):
        # x = torch.cat([inputs, action],1)
        h = F.relu(self.fc1(inputs))
        h = self.rnn(h, h_last)
        y = self.fc2(h)
        y[avail_actions == 0] = -1e38
        return y, h

class Critics(nn.Module):
    def __init__(self, args):
        super(Critics, self).__init__()
        self.n_agents = args.n_agents
        self.n_actions = args.n_actions
        self.agent = Critic(args)



    def init_hiddens(self, n_batch):
        hiddens = self.agent.init_hidden(n_batch*self.n_agents)
        hiddens = hiddens.reshape(n_batch,self.n_agents,-1)
        return hiddens

    def forward(self, states, avail_actions, hiddens):

        n_batch = states.shape[0]
        states = states.reshape(-1,states.shape[-1])
        hiddens = hiddens.reshape(-1,hiddens.shape[-1])
        avail_actions = avail_actions.reshape(-1,avail_actions.shape[-1])
        ys, hs_next = self.agent.forward(states, avail_actions, hiddens)
        ys = ys.reshape(n_batch,self.n_agents,-1)
        hs_next = hs_next.reshape(n_batch,self.n_agents,-1)
        
        return ys, hs_next



class EpisodeBuffer:
    def __init__(self, scheme, args):
        self.scheme = scheme.copy()
        self.buffer_size = args.buffer_size
        self.max_seq_length = args.episode_limit
        # self.device = args.device
        self.device = 'cpu'
        self._setup_data()

    def _setup_data(self):
        self.index_st = 0
        self.n_sample = 0

        self.data = {}
        for k, v in self.scheme.items():
            shape = (self.buffer_size, self.max_seq_length) + v['shape']
            self.data[k] = torch.zeros(shape, dtype=v['dtype'],device=self.device)

    def sample(self, batch_size, top_n = 0):
        if self.n_sample < batch_size:
            return None

        def trans_ids(ep_id):
            ep_id += self.index_st
            ep_id %= self.buffer_size
            return ep_id

        ep_ids = np.random.choice(self.n_sample - top_n, batch_size - top_n, replace=False)
        ep_ids = list(ep_ids) + [self.n_sample-i-1 for i in range(top_n)]# [self.n_sample -1]
        ep_ids = list(map(trans_ids, ep_ids))

        ret = {}
        for k, v in self.data.items():
            ret[k] = v[ep_ids]

        return ret
    

    def add_episode(self, data):

        #len_ep = len
        if self.n_sample < self.buffer_size:
            self.n_sample += 1
        else:
            self.index_st += 1
            self.index_st %= self.buffer_size

        index_ep = (self.index_st + self.n_sample - 1) % self.buffer_size
        
        for k, v in data.items():

            ep_len = len(v)
            dtype = self.scheme[k]['dtype']
            self.data[k][index_ep].zero_()
            self.data[k][index_ep, 0:ep_len] = torch.as_tensor(v, dtype=dtype, device=self.device)

    def clear(self):
        self.index_st = 0
        self.n_sample = 0
        for item in self.data.values():
            item.zero_()
        

    def state_dict(self):
        buffer_state = {'index_st': self.index_st, 'n_sample': self.n_sample, 'data': self.data}
        return buffer_state
    
    def load_state_dict(self, state_dict):
        self.index_st = state_dict['index_st']
        self.n_sample = state_dict['n_sample']    
        self.data = state_dict['data']

class QMixNet(nn.Module):
    def __init__(self, args):
        super(QMixNet, self).__init__()
        self.args = args
        # 因为生成的hyper_w1需要是一个矩阵，而pytorch神经网络只能输出一个向量，
        # 所以就先输出长度为需要的 矩阵行*矩阵列 的向量，然后再转化成矩阵

        # args.n_agents是使用hyper_w1作为参数的网络的输入维度，args.qmix_hidden_dim是网络隐藏层参数个数
        # 从而经过hyper_w1得到(经验条数，args.n_agents * args.qmix_hidden_dim)的矩阵
        
        input_dim = args.state_dim
        
        self.input_dim = input_dim
        self.hyper_w1 = nn.Linear(input_dim, args.n_agents * args.qmix_hidden_dim)
        # 经过hyper_w2得到(经验条数, 1)的矩阵
        self.hyper_w2 = nn.Linear(input_dim, args.qmix_hidden_dim * 1)

        # hyper_w1得到的(经验条数，args.qmix_hidden_dim)矩阵需要同样维度的hyper_b1
        self.hyper_b1 = nn.Linear(input_dim, args.qmix_hidden_dim)
        # hyper_w2得到的(经验条数，1)的矩阵需要同样维度的hyper_b1
        self.hyper_b2 =nn.Sequential(nn.Linear(input_dim, args.qmix_hidden_dim),
                                     nn.ReLU(),
                                     nn.Linear(args.qmix_hidden_dim, 1)
                                     )

    def forward(self, q_values, states):  # states的shape为(episode_num, max_episode_len， state_dim)
        # 传入的q_values是三维的，shape为(episode_num, max_episode_len， n_agents)
        episode_num = q_values.size(0)
        q_values = q_values.view(-1, 1, self.args.n_agents)  # (episode_num * max_episode_len, 1, n_agents) = (1920,1,5)
        states = states.reshape(-1, self.input_dim)  # (episode_num * max_episode_len, state_dim)

        w1 = torch.abs(self.hyper_w1(states))  # (1920, 160)
        b1 = self.hyper_b1(states)  # (1920, 32)

        w1 = w1.view(-1, self.args.n_agents, self.args.qmix_hidden_dim)  # (1920, 5, 32)
        b1 = b1.view(-1, 1, self.args.qmix_hidden_dim)  # (1920, 1, 32)

        hidden = F.elu(torch.bmm(q_values, w1) + b1)  # (1920, 1, 32)

        w2 = torch.abs(self.hyper_w2(states))  # (1920, 32)
        b2 = self.hyper_b2(states)  # (1920, 1)

        w2 = w2.view(-1, self.args.qmix_hidden_dim, 1)  # (1920, 32, 1)
        b2 = b2.view(-1, 1, 1)  # (1920, 1， 1)

        q_total = torch.bmm(hidden, w2) + b2  # (1920, 1, 1)
        q_total = q_total.view(episode_num, -1, 1)  # (32, 60, 1)
        return q_total

class Learner:
    def __init__(self, w_util, args):
        
        self.w_util = w_util
        self.device = args.device
        self.critic_attn = args.critic_attn

        # if self.critic_attn:                        
        #     from .attn_critics import Critics
        # else:            
        #     from .critics import Critics

        self.sys_actor = Actors(args)
        self.sys_critic1 = Critics(args)
        self.sys_critic2 = Critics(args)
        self.sys_critic1_tar = Critics(args)
        self.sys_critic2_tar = Critics(args)
        #self.sys_critic1.train()
        #self.sys_critic2.train()
    
        self.mix_net1 = QMixNet(args)        
        self.mix_net2 = QMixNet(args)        
        self.mix_net1_tar = QMixNet(args)
        self.mix_net2_tar = QMixNet(args)
        
        if self.device != 'cpu':
            self.sys_actor.cuda(self.device)
            self.sys_critic1.cuda(self.device)
            self.sys_critic2.cuda(self.device)
            self.sys_critic1_tar.cuda(self.device)
            self.sys_critic2_tar.cuda(self.device)
            self.mix_net1.cuda(self.device)
            self.mix_net2.cuda(self.device)
            self.mix_net1_tar.cuda(self.device)
            self.mix_net2_tar.cuda(self.device)
        
        self.sys_critic1_tar.requires_grad_(False)
        self.sys_critic2_tar.requires_grad_(False)
        self.mix_net1_tar.requires_grad_(False)
        self.mix_net2_tar.requires_grad_(False)



        self._sync_target()

        
        self.n_agents = args.n_agents
        self.n_actions = args.n_actions
        self.gamma = args.gamma
        self.entropy_tar = args.entropy_tar
        self.lr = args.lr
        self.lr_actor = args.lr_actor
        self.lr_alpha = args.lr_alpha
        self.l2 = args.l2
        self.target_update = args.target_update
        self.step = 0                
        self.agent_id = args.agent_id
        self.last_action = args.last_action  
        self.log_alpha_st = args.log_alpha_st
        self.shared_alpha = args.shared_alpha
        self.maximum_entropy = args.maximum_entropy     
        self.args = args

        
        if self.shared_alpha:
            self.log_alpha = torch.tensor(args.log_alpha_st, dtype=torch.float32, requires_grad=True, device = self.device)
        else:
            self.log_alpha = torch.tensor([args.log_alpha_st]*self.n_agents, dtype=torch.float32, requires_grad=True, device = self.device)
        
        params_critic = list(self.sys_critic1.parameters()) + list(self.sys_critic2.parameters()) + list(self.mix_net1.parameters()) + list(self.mix_net2.parameters())
        
        self.params_critic = params_critic
        self.params_actor = list(self.sys_actor.parameters())

    
        self.optim_actor = torch.optim.Adam(self.sys_actor.parameters(), lr = self.lr_actor, weight_decay=self.l2)
        self.optim_critic = torch.optim.Adam(params_critic, lr = self.lr, weight_decay=self.l2)        
        self.optim_alpha = torch.optim.Adam([self.log_alpha], lr=self.lr_alpha)

    def train(self, data):

        self.step += 1
        w_util = self.w_util

        state = data['state'].to(device=self.device, non_blocking=True)
        obs = data['obs'].to(device=self.device, non_blocking=True)
        actions = data['actions'].to(device=self.device, non_blocking=True)
        reward = data['reward'].to(device=self.device, non_blocking=True)
        valid = data['valid'].to(device=self.device, non_blocking=True)
        avail_actions = data['avail_actions'].to(device=self.device, non_blocking=True)
        actions_onehot = self.one_hot(actions,self.n_actions)
 
        n_batch = obs.shape[0]
        T = obs.shape[1]
        alpha = torch.exp(self.log_alpha.detach())
        valid_rate = torch.mean(valid.float())

        if self.agent_id:
            agent_ids = torch.eye(self.n_agents,device=obs.device)
            agent_ids = agent_ids.reshape((1,)*(obs.ndim-2)+agent_ids.shape)            
            agent_ids = agent_ids.expand(obs.shape[:-2]+(-1,-1))
            obs = torch.cat([obs,agent_ids],-1)
        if self.last_action:
            last_actions = torch.zeros_like(actions_onehot)
            last_actions[:,1:] = actions_onehot[:,:-1]
            obs = torch.cat([obs,last_actions],-1)

        hiddens1 = self.sys_critic1.init_hiddens(n_batch)
        hiddens1_tar = self.sys_critic1_tar.init_hiddens(n_batch)
        hiddens2 = self.sys_critic2.init_hiddens(n_batch)
        hiddens2_tar = self.sys_critic2_tar.init_hiddens(n_batch)
        hiddens_actor = self.sys_actor.init_hiddens(n_batch)
        

        Q1s = []
        Q2s = []
        Q1s_tar = []
        Q2s_tar = []        
        ps = []
        
        

        for i in range(T):
            
            Q1, hiddens1 = self.sys_critic1.forward(obs[:,i], avail_actions[:,i], hiddens1)
            Q2, hiddens2 = self.sys_critic2.forward(obs[:,i], avail_actions[:,i], hiddens2)
            p, hiddens_actor = self.sys_actor.forward(obs[:,i], avail_actions[:,i], hiddens_actor)
            
            #with torch.no_grad():
                
            Q1_tar, hiddens1_tar = self.sys_critic1_tar.forward(obs[:,i], avail_actions[:,i], hiddens1_tar)
            Q2_tar, hiddens2_tar = self.sys_critic2_tar.forward(obs[:,i], avail_actions[:,i], hiddens2_tar)
            
            Q1s.append(Q1)
            Q2s.append(Q2)
            Q1s_tar.append(Q1_tar)
            Q2s_tar.append(Q2_tar)
            ps.append(p)

        Q1s = torch.stack(Q1s,1)
        Q2s = torch.stack(Q2s,1)
        Q1s_tar = torch.stack(Q1s_tar,1)
        Q2s_tar = torch.stack(Q2s_tar,1)

        ps = torch.stack(ps,1)
        ps[valid == 0] = 0
        
        log_ps = torch.log(ps + 1e-38)
        log_ps[valid == 0] = 0
        #log_ps[avail_actions == 0] = 0
        entropy = -torch.sum(ps*log_ps, -1)
        

        Q1s[valid == 0] = 0
        Q2s[valid == 0] = 0
        Q1s_tar[valid == 0] = 0
        Q2s_tar[valid == 0] = 0

        q1s = self.gather_end(Q1s,actions)
        q2s = self.gather_end(Q2s,actions)

        q1s_tot = self.mix_net1(q1s, state)
        q2s_tot = self.mix_net2(q2s, state)
        
        q1s_tot[valid == 0] = 0
        q2s_tot[valid == 0] = 0
        
        V1s = torch.sum(ps * Q1s.detach(), -1)
        V2s = torch.sum(ps * Q2s.detach(), -1)
        
        V1s_tar = torch.sum(ps.detach() * Q1s_tar, -1)
        V2s_tar = torch.sum(ps.detach() * Q2s_tar, -1)
        
        self.mix_net1.requires_grad_(False)
        self.mix_net2.requires_grad_(False)
        
        V1s_tot = self.mix_net1.forward(V1s, state)
        V2s_tot = self.mix_net2.forward(V2s, state)

        self.mix_net1.requires_grad_(True)
        self.mix_net2.requires_grad_(True)

        V1s_tot_tar = self.mix_net1_tar.forward(V1s_tar, state)
        V2s_tot_tar = self.mix_net2_tar.forward(V2s_tar, state)
        
        Vs_tot = torch.min(torch.stack([V1s_tot,V2s_tot],-1), -1)[0]
        Vs_tot_tar = torch.min(torch.stack([V1s_tot_tar,V2s_tot_tar],-1), -1)[0]

        Vs_tot[valid == 0] = 0
        Vs_tot_tar[valid == 0] = 0

        

        alpha_entropy = torch.sum(alpha * entropy, -1, keepdim=True)     
        Ves_tot = Vs_tot + alpha_entropy
        Ves_tot_tar = Vs_tot_tar + alpha_entropy.detach()
        
        # train actor        
        loss_actor = - torch.mean(Ves_tot)/valid_rate
        self.optim_actor.zero_grad()
        loss_actor.backward()
        torch.nn.utils.clip_grad_norm_(self.params_actor, self.args.grad_norm_clip)
        self.optim_actor.step()
               
        
                        
        qs_star = torch.zeros_like(q1s_tot)
        qs_star += reward.unsqueeze(-1)

        if self.maximum_entropy:
            sys_v_tar = Ves_tot_tar
        else:
            sys_v_tar = Vs_tot_tar

        qs_star[:,:-1] += self.gamma * (sys_v_tar[:,1:])
        
        loss1 = F.mse_loss(q1s_tot,qs_star)/valid_rate
        loss2 = F.mse_loss(q2s_tot,qs_star)/valid_rate        
        loss = loss1+loss2
        self.optim_critic.zero_grad()        
        loss.backward()  
        torch.nn.utils.clip_grad_norm_(self.params_critic, self.args.grad_norm_clip)      
        self.optim_critic.step()        
        self.update_target()
        
        loss_alpha = self.log_alpha*(entropy.detach()-self.entropy_tar)
        loss_alpha[valid ==0] = 0
        loss_alpha = torch.mean(loss_alpha)/valid_rate

        self.optim_alpha.zero_grad()
        loss_alpha.backward()
        self.optim_alpha.step()
        
        m_loss = loss/2
        m_alpha = alpha.mean()    
        m_v = torch.mean(V1s.detach())/valid_rate        
        m_v_total = torch.mean(Vs_tot.detach())/valid_rate
        m_entropy = torch.mean(entropy.detach())/valid_rate        
        m_max_p = torch.mean(torch.max(ps.detach(),-1)[0])/valid_rate
        
        w_util.WriteScalar('train/loss', m_loss.item())
        w_util.WriteScalar('train/v', m_v.item())
        w_util.WriteScalar('train/v_total', m_v_total.item())
        w_util.WriteScalar('train/entropy', m_entropy.item())
        w_util.WriteScalar('train/alpha', m_alpha.item())        
        w_util.WriteScalar('train/max_p', m_max_p.item())
        
        return m_loss.item()

    def state_dict(self):
        state_dict = {}
        state_dict['critic1'] = self.sys_critic1.state_dict()
        state_dict['critic2'] = self.sys_critic2.state_dict()
        state_dict['critic1_tar'] = self.sys_critic1_tar.state_dict()
        state_dict['critic2_tar'] = self.sys_critic2_tar.state_dict()
        state_dict['mix_net1'] = self.mix_net1.state_dict()
        state_dict['mix_net2'] = self.mix_net2.state_dict()
        state_dict['mix_net1_tar'] = self.mix_net1_tar.state_dict()
        state_dict['mix_net2_tar'] = self.mix_net2_tar.state_dict()
        state_dict['actor'] = self.sys_actor.state_dict()
        state_dict['log_alpha'] = self.log_alpha.detach()
        state_dict['optim_critic'] = self.optim_critic.state_dict()
        state_dict['optim_actor'] = self.optim_actor.state_dict()
        state_dict['optim_alpha'] = self.optim_alpha.state_dict()
        return state_dict        

    def load_state_dict(self, state_dict):
        self.sys_critic1.load_state_dict(state_dict['critic1'])
        self.sys_critic2.load_state_dict(state_dict['critic2'])
        self.sys_critic1_tar.load_state_dict(state_dict['critic1_tar'])
        self.sys_critic2_tar.load_state_dict(state_dict['critic2_tar'])
        self.mix_net1.load_state_dict(state_dict['mix_net1'])
        self.mix_net2.load_state_dict(state_dict['mix_net2'])
        self.mix_net1_tar.load_state_dict(state_dict['mix_net1_tar'])
        self.mix_net2_tar.load_state_dict(state_dict['mix_net2_tar'])
        self.sys_actor.load_state_dict(state_dict['actor'])
        with torch.no_grad():
            self.log_alpha.copy_(state_dict['log_alpha'])
        self.optim_critic.load_state_dict(state_dict['optim_critic'])
        self.optim_actor.load_state_dict(state_dict['optim_actor'])
        self.optim_alpha.load_state_dict(state_dict['optim_alpha'])

        
    def gather_end(self, input, index):
        index = torch.unsqueeze(index,-1).to(dtype=torch.int64)
        return torch.gather(input, input.ndim -1, index).squeeze(-1)

    def one_hot(self, tensor, n_classes):
        return F.one_hot(tensor.to(dtype=torch.int64), n_classes).to(dtype=torch.float32)

    def update_target(self):
        if self.target_update >=1:
            if self.step % self.target_update == 0:
                self._sync_target()
        else:
            def soft_update(src,tar):
                cur_state = src.state_dict()
                tar_state = tar.state_dict()
                for key in tar_state:                
                    v_tar = tar_state[key]
                    v_cur = cur_state[key]
                    v_tar += self.target_update*(v_cur-v_tar).detach()
            soft_update(self.sys_critic1,self.sys_critic1_tar)
            soft_update(self.sys_critic2,self.sys_critic2_tar)
            soft_update(self.mix_net1,self.mix_net1_tar)
            soft_update(self.mix_net2,self.mix_net2_tar)
    
    def _sync_target(self):
        self.sys_critic1_tar.load_state_dict(self.sys_critic1.state_dict())
        self.sys_critic2_tar.load_state_dict(self.sys_critic2.state_dict())
        self.mix_net1_tar.load_state_dict(self.mix_net1.state_dict())
        self.mix_net2_tar.load_state_dict(self.mix_net2.state_dict())
 
    def _valid_mask(self, input, valid):
        input *= valid.view(list(valid.shape) + [1] * (input.ndim - valid.ndim))
        return input
        
class Experiment:
    def __init__(self, args):        
        self.args = args


    def save(self):

        run_state = {}                
        run_state['episode'] = self.e
        run_state['step'] = self.step
        run_state['best_win_rate'] = self.best_win_rate
        run_state['learner'] = self.learner.state_dict()
        run_state['buffer'] = self.buffer.state_dict()
        torch.save(run_state, self.path_checkpt)        

    def load(self):
        run_state = torch.load(self.path_checkpt)
        self.e = run_state['episode']
        self.step = run_state['step']
        self.best_win_rate = run_state['best_win_rate']
        self.learner.load_state_dict(run_state['learner'])                
        self.buffer.load_state_dict(run_state['buffer'])
        self.result = np.load(self.path_result)

    def start(self):
        args = self.args

        path_checkpt = 'checkpoints'
        path_result = 'results'
        path_model = 'models'
        if not os.path.exists(path_checkpt):
            os.mkdir(path_checkpt)
        if not os.path.exists(path_result):
            os.mkdir(path_result)
        if not os.path.exists(path_model):
            os.mkdir(path_model)
        path_checkpt = os.path.join(path_checkpt, args.run_name + '.tar')
        path_result = os.path.join(path_result, args.run_name + '.npy')
        path_model = os.path.join(path_model, args.run_name + '.tar')
            
        # env = StarCraft2Env(map_name=args.map_name, window_size_x=640, window_size_y=480)
        env = simple_spread_v3.parallel_env(N=args.N, local_ratio=args.local_ratio, max_cycles=args.max_cycles, continuous_actions=args.continuous_actions)
        print(env)
        env.reset()

        env_info = {
            "n_agents": args.N,
            "n_actions": 5,  # no_action, move_left, move_right, move_down, move_up
            "obs_shape": 18,
            "state_shape": 54,
            "episode_limit": args.max_cycles
        }
        # env_info = env.get_env_info()

        args.n_agents = env_info["n_agents"]
        args.n_actions = env_info["n_actions"]
        args.obs_dim = env_info['obs_shape']
        args.input_dim = args.obs_dim
        if args.agent_id:
            args.input_dim += args.n_agents
        if args.last_action:        
            args.input_dim += args.n_actions        
        args.state_dim = env_info['state_shape']
        args.episode_limit = env_info['episode_limit']
        
        writter = SummaryWriter('runs/'+ args.run_name + '/' + datetime.datetime.now().strftime('%Y-%m-%d,%H%M%S'))
        w_util = WritterUtil(writter,args)
        learner = Learner(w_util,args)               
        ctrler = Controller(learner.sys_actor,args)
        runner = Runner(env,ctrler,args)
                
        scheme = {}
        n_agents = args.n_agents
        scheme['obs'] = {'shape':(n_agents, args.obs_dim), 'dtype': torch.float32}
        scheme['valid'] = {'shape':(), 'dtype': torch.int32}
        scheme['actions'] = {'shape':(n_agents,), 'dtype': torch.int32}
        scheme['avail_actions'] = {'shape':(n_agents, args.n_actions), 'dtype': torch.int32}
        scheme['reward'] = {'shape':(), 'dtype': torch.float32}
        scheme['state'] = {'shape':(args.state_dim,), 'dtype': torch.float32}

        buffer = EpisodeBuffer(scheme, args)
        result = np.zeros((3, args.n_steps // args.test_every_step))

        self.e = 0
        self.step = 0
        self.best_win_rate = 0                   
        self.path_checkpt = path_checkpt
        self.path_result = path_result
        self.path_model = path_model      
        self.env = env        
        self.writter = writter
        self.w_util = w_util
        self.ctrler = ctrler
        self.runner = runner
        self.learner = learner
        self.buffer = buffer
        self.result = result

        if args.continue_run:
            self.load()
                    
        
    def run(self):
        
        args = self.args
        buffer = self.buffer        
        runner = self.runner
        learner = self.learner
        w_util = self.w_util
        
        while self.step < args.n_steps:
        #for self.e in range(self.e, args.n_episodes+1):
            self.e += 1            
            data, episode_reward, win_tag, step =  runner.run()
            old_step = self.step
            self.step += step                   
            w_util.set_step(self.step)            
            w_util.WriteScalar('train/reward', episode_reward)
            print("Episode {}, step {}, win = {}, reward = {}".format(self.e, self.step, win_tag, episode_reward))
            buffer.add_episode(data)
            data = buffer.sample(args.n_batch, args.top_n)
            if data:
                loss = learner.train(data)                        
                        
            if self.step // args.test_every_step != old_step // args.test_every_step:
                self.test_model()            

            if args.save_every and self.e % args.save_every == 0:                
                self.save()

        self.env.close()

    def test_model(self):
        args = self.args
        w_util = self.w_util
        runner = self.runner
        result = self.result

        win_count = 0
        reward_avg = 0
        for i in range(args.test_count):
            _, episode_reward, win_tag, _ =  runner.run(test_mode=True)
            if win_tag:
                win_count += 1
            reward_avg += episode_reward                
        win_rate = win_count/args.test_count        
        reward_avg /= args.test_count
        w_util.WriteScalar('test/reward', reward_avg)
        w_util.WriteScalar('test/win_rate', win_rate)
        result[:, self.step // args.test_every_step - 1] = [self.e, self.step, win_rate]
        np.save(self.path_result, self.result)
        if win_rate >= self.best_win_rate:
            self.best_win_rate = win_rate
            torch.save(self.learner.sys_actor.state_dict(), self.path_model)            
        print('Test reward = {}, win_rate = {}'.format(reward_avg, win_rate))
        
class Runner:
    def __init__(self, env, controller, args):        
        self.controller = controller
        self.env = env
        self.args = args  # Store args for access to N (number of agents)

    def run(self, test_mode=False):
        observations, infos = self.env.reset()
        self.controller.new_episode()
        data = {'state': [], 'obs': [], 'valid': [], 'actions': [], 'avail_actions': [], 'reward': []}
        episode_reward = 0
        steps = 0
        done = False

        while not done:
            steps += 1
            state = self.env.state()
            
            # Convert observations dict to list in consistent order
            obs_list = []
            for agent_id in self.env.agents:
                obs_list.append(observations[agent_id])
            
            # All actions available for all agents (5 actions per agent)
            avail_actions_list = [[1] * 5 for _ in range(self.args.N)]
            
            explore = not test_mode
            
            # Get actions from controller for all agents
            actions_array = self.controller.get_actions(obs_list, avail_actions_list, explore)
            
            # Convert actions array to dict for PettingZoo environment
            actions_dict = {agent_id: action for agent_id, action in zip(self.env.agents, actions_array)}
            
            # Take step in environment
            observations, rewards, terminations, truncations, infos = self.env.step(actions_dict)
            
            # Check if episode is done
            done = all(terminations.values()) or all(truncations.values())
            
            # Calculate total reward for this step
            step_reward = sum(rewards.values())
            episode_reward += step_reward
            
            # Store transition data
            data['state'].append(state)
            data['obs'].append(obs_list)
            data['valid'].append(1)  # All steps are valid during episode
            data['actions'].append(actions_array)
            data['avail_actions'].append(avail_actions_list)
            data['reward'].append(step_reward)

        # For simple_spread, we could define win conditions based on final positions
        # For now, using a simple placeholder
        win_tag = episode_reward > 0  # Can be modified based on specific criteria
        
        return data, episode_reward, win_tag, steps
     
class Args:
    pass


if __name__ == "__main__":

    
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    config_path='config.json'
        
    with open(config_path, 'r') as f:
        config = json.load(f)
    args = Args()
    args.__dict__.update(config)

    args.continue_run = False
    argv = sys.argv
    if len(argv)>1:
        if argv[1] == '-c':  ##continue
            args.continue_run = True

    experiment = Experiment(args)
    experiment.start()
    experiment.run()
# Out:
# simple_spread_v3
# Episode 1, step 75, win = False, reward = -230.01637676057743
# Episode 2, step 150, win = False, reward = -389.7375091166875
# Episode 3, step 225, win = False, reward = -139.42271084498248
# Episode 4, step 300, win = False, reward = -330.6251879200455
# Episode 5, step 375, win = False, reward = -460.5474775615651
# Episode 6, step 450, win = False, reward = -370.2479574236366
# Episode 7, step 525, win = False, reward = -358.699501253611
# Episode 8, step 600, win = False, reward = -386.37002808666284
# Episode 9, step 675, win = False, reward = -497.1280928875263
# Episode 10, step 750, win = False, reward = -307.49060829728234
# Episode 11, step 825, win = False, reward = -341.7729653242907
# Episode 12, step 900, win = False, reward = -215.34487793444086
# Episode 13, step 975, win = False, reward = -287.5240822066192
# Episode 14, step 1050, win = False, reward = -256.8666663798154
# Episode 15, step 1125, win = False, reward = -295.2378481803373
# Episode 16, step 1200, win = False, reward = -217.93556329845623
# Episode 17, step 1275, win = False, reward = -349.87024803269117
# Episode 18, step 1350, win = False, reward = -295.9586613474155
# Episode 19, step 1425, win = False, reward = -276.1548988981157
# Episode 20, step 1500, win = False, reward = -254.37976614588212
# Episode 21, step 1575, win = False, reward = -339.3487044596442
# Episode 22, step 1650, win = False, reward = -228.58970587727825
# Episode 23, step 1725, win = False, reward = -302.60795155251833
# Episode 24, step 1800, win = False, reward = -360.5980685351876
# Episode 25, step 1875, win = False, reward = -301.54092177426634
# Episode 26, step 1950, win = False, reward = -159.5844596791391
# Episode 27, step 2025, win = False, reward = -449.44819050979925
# Episode 28, step 2100, win = False, reward = -230.9379134565668
# Episode 29, step 2175, win = False, reward = -310.30779446863465
# Episode 30, step 2250, win = False, reward = -350.98786480464304
# Episode 31, step 2325, win = False, reward = -221.21753313022748
# Episode 32, step 2400, win = False, reward = -260.5988065846483
# Episode 33, step 2475, win = False, reward = -287.623600044079
# Episode 34, step 2550, win = False, reward = -514.4249554326124
# Episode 35, step 2625, win = False, reward = -196.11572117806168
# Episode 36, step 2700, win = False, reward = -332.7785907948829
# Episode 37, step 2775, win = False, reward = -224.1184326352711
# Episode 38, step 2850, win = False, reward = -311.38054689278033
# Episode 39, step 2925, win = False, reward = -336.9240779652753
# Episode 40, step 3000, win = False, reward = -199.6727236929959
# Episode 41, step 3075, win = False, reward = -388.267342682954
# Episode 42, step 3150, win = False, reward = -212.04681476335801
# Episode 43, step 3225, win = False, reward = -309.6072360467345
# Episode 44, step 3300, win = False, reward = -195.9303667064993
# Episode 45, step 3375, win = False, reward = -328.5815342152483
# Episode 46, step 3450, win = False, reward = -284.00102122670006
# Episode 47, step 3525, win = False, reward = -230.6424289616595
# Episode 48, step 3600, win = False, reward = -443.70907007161594
# Episode 49, step 3675, win = False, reward = -288.79848010918994
# Episode 50, step 3750, win = False, reward = -275.38007796532486
# Episode 51, step 3825, win = False, reward = -304.78773454862676
# Episode 52, step 3900, win = False, reward = -227.93418584286138
# Episode 53, step 3975, win = False, reward = -250.3023654768843
# Episode 54, step 4050, win = False, reward = -330.28128192642356
# Episode 55, step 4125, win = False, reward = -338.72663576575945
# Episode 56, step 4200, win = False, reward = -243.6399792797005
# Episode 57, step 4275, win = False, reward = -282.7232573696847
# Episode 58, step 4350, win = False, reward = -205.0726375570098
# Episode 59, step 4425, win = False, reward = -184.03322024815245
# Episode 60, step 4500, win = False, reward = -196.05514973273034
# Episode 61, step 4575, win = False, reward = -213.88723672800919
# Episode 62, step 4650, win = False, reward = -250.998138503336
# Episode 63, step 4725, win = False, reward = -278.1410662906809
# Episode 64, step 4800, win = False, reward = -184.51687401959524
# Episode 65, step 4875, win = False, reward = -344.42568542656113
# Episode 66, step 4950, win = False, reward = -220.4290331063636
# Episode 67, step 5025, win = False, reward = -315.6069604240915
# Episode 68, step 5100, win = False, reward = -229.22402012631377
# Episode 69, step 5175, win = False, reward = -261.3817726632321
# Episode 70, step 5250, win = False, reward = -326.18801049082947
# Episode 71, step 5325, win = False, reward = -389.63572711938247
# Episode 72, step 5400, win = False, reward = -460.0731831472841
# Episode 73, step 5475, win = False, reward = -243.20088327699887
# Episode 74, step 5550, win = False, reward = -210.636987030242
# Episode 75, step 5625, win = False, reward = -382.66842819992036
# Episode 76, step 5700, win = False, reward = -281.7762326050626
# Episode 77, step 5775, win = False, reward = -295.1783667716622
# Episode 78, step 5850, win = False, reward = -370.9608157559927
# Episode 79, step 5925, win = False, reward = -214.5886770900189
# Episode 80, step 6000, win = False, reward = -225.69983655133595
# Episode 81, step 6075, win = False, reward = -325.3427040636781
# Episode 82, step 6150, win = False, reward = -316.89058649243236
# Episode 83, step 6225, win = False, reward = -446.45940287523905
# Episode 84, step 6300, win = False, reward = -293.90920277559786
# Episode 85, step 6375, win = False, reward = -239.48251897431348
# Episode 86, step 6450, win = False, reward = -360.64983632980386
# Episode 87, step 6525, win = False, reward = -179.16921904100522
# Episode 88, step 6600, win = False, reward = -279.25488156865765
# Episode 89, step 6675, win = False, reward = -256.02698572480773
# Episode 90, step 6750, win = False, reward = -187.65870319317213
# Episode 91, step 6825, win = False, reward = -316.8392780437727
# Episode 92, step 6900, win = False, reward = -434.43479462945396
# Episode 93, step 6975, win = False, reward = -358.81493894448306
# Episode 94, step 7050, win = False, reward = -366.0164305160071
# Episode 95, step 7125, win = False, reward = -261.52623305821396
# Episode 96, step 7200, win = False, reward = -291.4649004947174
# Episode 97, step 7275, win = False, reward = -246.90992442912537
# Episode 98, step 7350, win = False, reward = -387.05750087798907
# Episode 99, step 7425, win = False, reward = -347.56137924980925
# Episode 100, step 7500, win = False, reward = -334.70573009142913
# Episode 101, step 7575, win = False, reward = -245.0699176228855
# Episode 102, step 7650, win = False, reward = -266.7611093479478
# Episode 103, step 7725, win = False, reward = -391.8410664547925
# Episode 104, step 7800, win = False, reward = -403.2083216810303
# Episode 105, step 7875, win = False, reward = -258.674769751826
# Episode 106, step 7950, win = False, reward = -290.43319640563107
# Episode 107, step 8025, win = False, reward = -312.13463162571736
# Episode 108, step 8100, win = False, reward = -293.7646249726176
# Episode 109, step 8175, win = False, reward = -358.61778077030255
# Episode 110, step 8250, win = False, reward = -388.29587138826156
# Episode 111, step 8325, win = False, reward = -254.60654924795537
# Episode 112, step 8400, win = False, reward = -249.79314858691674
# Episode 113, step 8475, win = False, reward = -379.55902196202084
# Episode 114, step 8550, win = False, reward = -324.0685163374099
# Episode 115, step 8625, win = False, reward = -204.74125416077655
# Episode 116, step 8700, win = False, reward = -323.1033440808668
# Episode 117, step 8775, win = False, reward = -275.978905575726
# Episode 118, step 8850, win = False, reward = -230.59253420190205
# Episode 119, step 8925, win = False, reward = -456.98132293341865
# Episode 120, step 9000, win = False, reward = -254.6150152229696
# Episode 121, step 9075, win = False, reward = -227.9273234078465
# Episode 122, step 9150, win = False, reward = -194.64901688525438
# Episode 123, step 9225, win = False, reward = -268.6389440937794
# Episode 124, step 9300, win = False, reward = -295.60746792901773
# Episode 125, step 9375, win = False, reward = -281.46865737491197
# Episode 126, step 9450, win = False, reward = -228.99247393910298
# Episode 127, step 9525, win = False, reward = -318.33062460460235
# Episode 128, step 9600, win = False, reward = -192.03267739277533
# Episode 129, step 9675, win = False, reward = -432.38233687324526
# Episode 130, step 9750, win = False, reward = -269.4020172549983
# Episode 131, step 9825, win = False, reward = -707.7982248918797
# Episode 132, step 9900, win = False, reward = -407.9413579660857
# Episode 133, step 9975, win = False, reward = -284.24912308779295
# Episode 134, step 10050, win = False, reward = -383.2253348426711
# Test reward = -667.8588961767299, win_rate = 0.0
# Episode 135, step 10125, win = False, reward = -417.1535159877179
# Episode 136, step 10200, win = False, reward = -243.33313655980044
# Episode 137, step 10275, win = False, reward = -220.99144764131148
# Episode 138, step 10350, win = False, reward = -262.7977906977901
# Episode 139, step 10425, win = False, reward = -200.08052333780856
# Episode 140, step 10500, win = False, reward = -370.4895001192386
# Episode 141, step 10575, win = False, reward = -314.8683941442365
# Episode 142, step 10650, win = False, reward = -246.54938698861724
# Episode 143, step 10725, win = False, reward = -220.67113257539128
# Episode 144, step 10800, win = False, reward = -481.37457697262556
# Episode 145, step 10875, win = False, reward = -185.43870261937715
# Episode 146, step 10950, win = False, reward = -207.35609430504093
# Episode 147, step 11025, win = False, reward = -292.0068076048093
# Episode 148, step 11100, win = False, reward = -220.02852346722503
# Episode 149, step 11175, win = False, reward = -212.27513761337676
# Episode 150, step 11250, win = False, reward = -237.92349261473507
# Episode 151, step 11325, win = False, reward = -197.00760571513752
# Episode 152, step 11400, win = False, reward = -252.57843273250498
# Episode 153, step 11475, win = False, reward = -217.93243403372455
# Episode 154, step 11550, win = False, reward = -313.9772423036768
# Episode 155, step 11625, win = False, reward = -514.1381631177175
# Episode 156, step 11700, win = False, reward = -249.08526262786867
# Episode 157, step 11775, win = False, reward = -267.1067609311671
# Episode 158, step 11850, win = False, reward = -237.539829410322
# Episode 159, step 11925, win = False, reward = -324.1805564816176
# Episode 160, step 12000, win = False, reward = -297.39899839911965
# Episode 161, step 12075, win = False, reward = -163.05637704077347
# Episode 162, step 12150, win = False, reward = -413.7774448391137
# Episode 163, step 12225, win = False, reward = -320.1797267116794
# Episode 164, step 12300, win = False, reward = -258.28974895262047
# Episode 165, step 12375, win = False, reward = -335.730595901185
# Episode 166, step 12450, win = False, reward = -381.0822021196789
# Episode 167, step 12525, win = False, reward = -272.5555056218742
# Episode 168, step 12600, win = False, reward = -258.92032144216705
# Episode 169, step 12675, win = False, reward = -186.9158729073378
# Episode 170, step 12750, win = False, reward = -330.9793129047714
# Episode 171, step 12825, win = False, reward = -254.92963713151687
# Episode 172, step 12900, win = False, reward = -199.25565270934888
# Episode 173, step 12975, win = False, reward = -326.6542273724479
# Episode 174, step 13050, win = False, reward = -292.66702562038273
# Episode 175, step 13125, win = False, reward = -315.0201450000661
# Episode 176, step 13200, win = False, reward = -265.38610456464625
# Episode 177, step 13275, win = False, reward = -238.0789728890743
# Episode 178, step 13350, win = False, reward = -282.7798605827794
# Episode 179, step 13425, win = False, reward = -402.2137065559799
# Episode 180, step 13500, win = False, reward = -198.00927872463615
# Episode 181, step 13575, win = False, reward = -259.0953935089642
# Episode 182, step 13650, win = False, reward = -313.027534657332
# Episode 183, step 13725, win = False, reward = -281.244169397791
# Episode 184, step 13800, win = False, reward = -234.62433599525667
# Episode 185, step 13875, win = False, reward = -217.86397301903654
# Episode 186, step 13950, win = False, reward = -518.4690158912279
# Episode 187, step 14025, win = False, reward = -281.4018026943087
# Episode 188, step 14100, win = False, reward = -315.414501307284
# Episode 189, step 14175, win = False, reward = -292.7215019613544
# Episode 190, step 14250, win = False, reward = -274.9271556047723
# Episode 191, step 14325, win = False, reward = -293.0249777251878
# Episode 192, step 14400, win = False, reward = -195.4852492293576
# Episode 193, step 14475, win = False, reward = -121.56785606793504
# Episode 194, step 14550, win = False, reward = -361.0682855668304
# Episode 195, step 14625, win = False, reward = -337.24102533888055
# Episode 196, step 14700, win = False, reward = -231.90174392509695
# Episode 197, step 14775, win = False, reward = -227.59349975553812
# Episode 198, step 14850, win = False, reward = -250.07233061620946
# Episode 199, step 14925, win = False, reward = -321.5674775648398
# Episode 200, step 15000, win = False, reward = -318.8286994593994
# Episode 201, step 15075, win = False, reward = -296.42059854179104
# Episode 202, step 15150, win = False, reward = -215.1339612478875
# Episode 203, step 15225, win = False, reward = -310.05946381099847
# Episode 204, step 15300, win = False, reward = -344.15140147066666
# Episode 205, step 15375, win = False, reward = -209.66385193094632
# Episode 206, step 15450, win = False, reward = -472.3470599104859
# Episode 207, step 15525, win = False, reward = -407.12819726289393
# Episode 208, step 15600, win = False, reward = -374.2594050786292
# Episode 209, step 15675, win = False, reward = -448.653601158216
# Episode 210, step 15750, win = False, reward = -213.71738380665744
# Episode 211, step 15825, win = False, reward = -188.38524282195743
# Episode 212, step 15900, win = False, reward = -225.311395269609
# Episode 213, step 15975, win = False, reward = -174.47356845747882
# Episode 214, step 16050, win = False, reward = -191.57470683833756
# Episode 215, step 16125, win = False, reward = -248.80747710069716
# Episode 216, step 16200, win = False, reward = -334.743498629334
# Episode 217, step 16275, win = False, reward = -202.4527710058773
# Episode 218, step 16350, win = False, reward = -294.5703186740188
# Episode 219, step 16425, win = False, reward = -237.22639534206178
# Episode 220, step 16500, win = False, reward = -227.30060183921793
# Episode 221, step 16575, win = False, reward = -268.7471344385783
# Episode 222, step 16650, win = False, reward = -293.4932622925727
# Episode 223, step 16725, win = False, reward = -181.68638597916868
# Episode 224, step 16800, win = False, reward = -425.0862538539618
# Episode 225, step 16875, win = False, reward = -272.468269218866
# Episode 226, step 16950, win = False, reward = -178.1885348497809
# Episode 227, step 17025, win = False, reward = -255.7927365539045
# Episode 228, step 17100, win = False, reward = -224.4989686663224
# Episode 229, step 17175, win = False, reward = -260.5018466621433
# Episode 230, step 17250, win = False, reward = -247.84115881664664
# Episode 231, step 17325, win = False, reward = -346.6490016708125
# Episode 232, step 17400, win = False, reward = -299.22779025266
# Episode 233, step 17475, win = False, reward = -207.10338983231324
# Episode 234, step 17550, win = False, reward = -208.93005368494042
# Episode 235, step 17625, win = False, reward = -315.962937658787
# Episode 236, step 17700, win = False, reward = -222.27641357279015
# Episode 237, step 17775, win = False, reward = -161.74865578160626
# Episode 238, step 17850, win = False, reward = -307.0646681070406
# Episode 239, step 17925, win = False, reward = -216.4093978592076
# Episode 240, step 18000, win = False, reward = -283.0636075241206
# Episode 241, step 18075, win = False, reward = -428.6659143491173
# Episode 242, step 18150, win = False, reward = -323.7254992233608
# Episode 243, step 18225, win = False, reward = -265.6011866187814
# Episode 244, step 18300, win = False, reward = -212.43395487965265
# Episode 245, step 18375, win = False, reward = -316.17160249921847
# Episode 246, step 18450, win = False, reward = -282.1281100915367
# Episode 247, step 18525, win = False, reward = -361.01729552187084
# Episode 248, step 18600, win = False, reward = -423.3826076959996
# Episode 249, step 18675, win = False, reward = -275.4147443658475
# Episode 250, step 18750, win = False, reward = -415.7824688633478
# Episode 251, step 18825, win = False, reward = -385.44559227528805
# Episode 252, step 18900, win = False, reward = -487.63429095273597
# Episode 253, step 18975, win = False, reward = -558.2955791793339
# Episode 254, step 19050, win = False, reward = -246.2930656093195
# Episode 255, step 19125, win = False, reward = -287.70583340311794
# Episode 256, step 19200, win = False, reward = -287.9978975931848
# Episode 257, step 19275, win = False, reward = -318.43674070969837
# Episode 258, step 19350, win = False, reward = -522.1017351128747
# Episode 259, step 19425, win = False, reward = -346.13687101808284
# Episode 260, step 19500, win = False, reward = -256.0787312873463
# Episode 261, step 19575, win = False, reward = -251.0930589977487
# Episode 262, step 19650, win = False, reward = -409.63286599769447
# Episode 263, step 19725, win = False, reward = -392.042418439421
# Episode 264, step 19800, win = False, reward = -316.89742055430537
# Episode 265, step 19875, win = False, reward = -253.15631452760041
# Episode 266, step 19950, win = False, reward = -234.36075204578125
# Episode 267, step 20025, win = False, reward = -265.6137933143667
# Test reward = -1561.8870379767368, win_rate = 0.0
# Episode 268, step 20100, win = False, reward = -363.07323033738294
# Episode 269, step 20175, win = False, reward = -301.2285920858328
# Episode 270, step 20250, win = False, reward = -528.0813788006177
# Episode 271, step 20325, win = False, reward = -383.2507601648192
# Episode 272, step 20400, win = False, reward = -213.65515742181896
# Episode 273, step 20475, win = False, reward = -329.9306985440352
# Episode 274, step 20550, win = False, reward = -266.3433645917082
# Episode 275, step 20625, win = False, reward = -385.8509048752344
# Episode 276, step 20700, win = False, reward = -331.61558369901314
# Episode 277, step 20775, win = False, reward = -326.02333905469516
# Episode 278, step 20850, win = False, reward = -403.6379176802523
# Episode 279, step 20925, win = False, reward = -204.94482743396932
# Episode 280, step 21000, win = False, reward = -349.46951410814137
# Episode 281, step 21075, win = False, reward = -265.29134333690325
# Episode 282, step 21150, win = False, reward = -206.36752939637017
# Episode 283, step 21225, win = False, reward = -256.8574721792993
# Episode 284, step 21300, win = False, reward = -274.2764491710218
# Episode 285, step 21375, win = False, reward = -770.835492321204
# Episode 286, step 21450, win = False, reward = -322.66211700667475
# Episode 287, step 21525, win = False, reward = -282.36401553783907
# Episode 288, step 21600, win = False, reward = -248.70441070799856
# Episode 289, step 21675, win = False, reward = -327.7840791438411
# Episode 290, step 21750, win = False, reward = -228.2355936368196
# Episode 291, step 21825, win = False, reward = -272.5754768177248
# Episode 292, step 21900, win = False, reward = -430.441804723083
# Episode 293, step 21975, win = False, reward = -282.4404780015074
# Episode 294, step 22050, win = False, reward = -466.5137024844476
# Episode 295, step 22125, win = False, reward = -232.14691556465752
# Episode 296, step 22200, win = False, reward = -369.34825061466535
# Episode 297, step 22275, win = False, reward = -318.55446087913396
# Episode 298, step 22350, win = False, reward = -271.20691269242934
# Episode 299, step 22425, win = False, reward = -351.447688513019
# Episode 300, step 22500, win = False, reward = -410.59584706223137
# Episode 301, step 22575, win = False, reward = -180.0964337816225
# Episode 302, step 22650, win = False, reward = -275.34579310279395
# Episode 303, step 22725, win = False, reward = -263.43985386164445
# Episode 304, step 22800, win = False, reward = -474.0122983724013
# Episode 305, step 22875, win = False, reward = -621.2274513913908
# Episode 306, step 22950, win = False, reward = -178.15009657666144
# Episode 307, step 23025, win = False, reward = -622.9988302388679
# Episode 308, step 23100, win = False, reward = -248.5331712803908
# Episode 309, step 23175, win = False, reward = -166.97955347729172
# Episode 310, step 23250, win = False, reward = -507.46084640109524
# Episode 311, step 23325, win = False, reward = -768.2572488805524
# Episode 312, step 23400, win = False, reward = -240.12767917032775
# Episode 313, step 23475, win = False, reward = -263.2918183419594
# Episode 314, step 23550, win = False, reward = -588.8800819626033
# Episode 315, step 23625, win = False, reward = -184.08660171756844
# Episode 316, step 23700, win = False, reward = -223.23868368859627
# Episode 317, step 23775, win = False, reward = -448.4143304403666
# Episode 318, step 23850, win = False, reward = -231.5073106331821
# Episode 319, step 23925, win = False, reward = -463.50942489276656
# Episode 320, step 24000, win = False, reward = -380.57619735692896
# Episode 321, step 24075, win = False, reward = -266.3727139041164
# Episode 322, step 24150, win = False, reward = -213.9815693424391
# Episode 323, step 24225, win = False, reward = -410.5270915128572
# Episode 324, step 24300, win = False, reward = -322.1179342057607
# Episode 325, step 24375, win = False, reward = -256.27915667818513
# Episode 326, step 24450, win = False, reward = -277.2189366296003
# Episode 327, step 24525, win = False, reward = -280.336647525079
# Episode 328, step 24600, win = False, reward = -242.93703832003197
# Episode 329, step 24675, win = False, reward = -301.0148006473943
# Episode 330, step 24750, win = False, reward = -287.5171096103629
# Episode 331, step 24825, win = False, reward = -232.44172774779645
# Episode 332, step 24900, win = False, reward = -350.64141356589255
# Episode 333, step 24975, win = False, reward = -262.15547188485425
# Episode 334, step 25050, win = False, reward = -311.1847298559233
# Episode 335, step 25125, win = False, reward = -535.8445672122257
# Episode 336, step 25200, win = False, reward = -288.11657124324984
# Episode 337, step 25275, win = False, reward = -290.34687883657995
# Episode 338, step 25350, win = False, reward = -189.5647015515546
# Episode 339, step 25425, win = False, reward = -362.1161763924396
# Episode 340, step 25500, win = False, reward = -206.9408588569236
# Episode 341, step 25575, win = False, reward = -531.8304074231703
# Episode 342, step 25650, win = False, reward = -314.31067115666923
# Episode 343, step 25725, win = False, reward = -240.42521626349
# Episode 344, step 25800, win = False, reward = -483.28323521052573
# Episode 345, step 25875, win = False, reward = -263.56286258320836
# Episode 346, step 25950, win = False, reward = -222.3358827743599
# Episode 347, step 26025, win = False, reward = -277.93820610613346
# Episode 348, step 26100, win = False, reward = -305.5110692006505
# Episode 349, step 26175, win = False, reward = -372.7997012255843
# Episode 350, step 26250, win = False, reward = -239.0624809128387
# Episode 351, step 26325, win = False, reward = -389.6993682684594
# Episode 352, step 26400, win = False, reward = -452.75477817882614
# Episode 353, step 26475, win = False, reward = -192.59935011221364
# Episode 354, step 26550, win = False, reward = -235.3158605045968
# Episode 355, step 26625, win = False, reward = -251.3735491936782
# Episode 356, step 26700, win = False, reward = -278.63675571693824
# Episode 357, step 26775, win = False, reward = -714.2999366029676
# Episode 358, step 26850, win = False, reward = -291.20134709025024
# Episode 359, step 26925, win = False, reward = -335.9020363422819
# Episode 360, step 27000, win = False, reward = -294.94990624304523
# Episode 361, step 27075, win = False, reward = -352.7648946916474
# Episode 362, step 27150, win = False, reward = -187.32181720284436
# Episode 363, step 27225, win = False, reward = -260.1879901631398
# Episode 364, step 27300, win = False, reward = -303.74636189070605
# Episode 365, step 27375, win = False, reward = -386.4525246630323
# Episode 366, step 27450, win = False, reward = -397.8516901894646
# Episode 367, step 27525, win = False, reward = -286.77634133690606
# Episode 368, step 27600, win = False, reward = -379.3162961950624
# Episode 369, step 27675, win = False, reward = -253.44708376218455
# Episode 370, step 27750, win = False, reward = -383.04827545059766
# Episode 371, step 27825, win = False, reward = -275.32598882384343
# Episode 372, step 27900, win = False, reward = -797.7280962117009
# Episode 373, step 27975, win = False, reward = -263.31576087669765
# Episode 374, step 28050, win = False, reward = -537.3507195848762
# Episode 375, step 28125, win = False, reward = -302.9859875206803
# Episode 376, step 28200, win = False, reward = -227.91241765345413
# Episode 377, step 28275, win = False, reward = -222.67314909009045
# Episode 378, step 28350, win = False, reward = -907.5798023125797
# Episode 379, step 28425, win = False, reward = -185.97221001524224
# Episode 380, step 28500, win = False, reward = -255.54036392329616
# Episode 381, step 28575, win = False, reward = -439.28595092851845
# Episode 382, step 28650, win = False, reward = -1133.1970416197603
# Episode 383, step 28725, win = False, reward = -428.2085575153587
# Episode 384, step 28800, win = False, reward = -449.5240422380273
# Episode 385, step 28875, win = False, reward = -347.0881828846411
# Episode 386, step 28950, win = False, reward = -269.0615768174618
# Episode 387, step 29025, win = False, reward = -465.8752420431569
# Episode 388, step 29100, win = False, reward = -613.5275704011415
# Episode 389, step 29175, win = False, reward = -328.48223227086896
# Episode 390, step 29250, win = False, reward = -286.04251873209216
# Episode 391, step 29325, win = False, reward = -639.0822957208784
# Episode 392, step 29400, win = False, reward = -289.73099927717294
# Episode 393, step 29475, win = False, reward = -332.3919247528605
# Episode 394, step 29550, win = False, reward = -185.22615781161255
# Episode 395, step 29625, win = False, reward = -512.178093125154
# Episode 396, step 29700, win = False, reward = -548.6820145789379
# Episode 397, step 29775, win = False, reward = -213.09782619446293
# Episode 398, step 29850, win = False, reward = -358.4831062197799
# Episode 399, step 29925, win = False, reward = -234.11189038483246
# Episode 400, step 30000, win = False, reward = -463.99932349269767
# Test reward = -2135.941696775971, win_rate = 0.0
# Episode 401, step 30075, win = False, reward = -507.28520575926865
# Episode 402, step 30150, win = False, reward = -662.6866454012963
# Episode 403, step 30225, win = False, reward = -179.3721944418094
# Episode 404, step 30300, win = False, reward = -336.91105066440906
# Episode 405, step 30375, win = False, reward = -511.78412668900177
# Episode 406, step 30450, win = False, reward = -325.9285418144
# Episode 407, step 30525, win = False, reward = -232.8536627772575
# Episode 408, step 30600, win = False, reward = -431.6117048060261
# Episode 409, step 30675, win = False, reward = -1323.7080395663481
# Episode 410, step 30750, win = False, reward = -609.05104380211
# Episode 411, step 30825, win = False, reward = -243.08121491167944
# Episode 412, step 30900, win = False, reward = -510.46621033822385
# Episode 413, step 30975, win = False, reward = -564.3222784044733
# Episode 414, step 31050, win = False, reward = -621.3115993381352
# Episode 415, step 31125, win = False, reward = -721.3299209303974
# Episode 416, step 31200, win = False, reward = -175.59756735270346
# Episode 417, step 31275, win = False, reward = -795.7047917151125
# Episode 418, step 31350, win = False, reward = -759.8189690941024
# Episode 419, step 31425, win = False, reward = -421.376452731246
# Episode 420, step 31500, win = False, reward = -356.3312893595408
# Episode 421, step 31575, win = False, reward = -216.56242119690788
# Episode 422, step 31650, win = False, reward = -280.567383314359
# Episode 423, step 31725, win = False, reward = -427.2211621812305
# Episode 424, step 31800, win = False, reward = -492.6142053902004
# Episode 425, step 31875, win = False, reward = -249.95325368768488
# Episode 426, step 31950, win = False, reward = -371.2208833240852
# Episode 427, step 32025, win = False, reward = -388.8923837077003
# Episode 428, step 32100, win = False, reward = -919.1336176258837
# Episode 429, step 32175, win = False, reward = -963.3721179771911
# Episode 430, step 32250, win = False, reward = -314.23407626062414
# Episode 431, step 32325, win = False, reward = -295.9410035255375
# Episode 432, step 32400, win = False, reward = -348.32676355558476
# Episode 433, step 32475, win = False, reward = -730.768865278072
# Episode 434, step 32550, win = False, reward = -399.3632026092776
# Episode 435, step 32625, win = False, reward = -261.6282055771561
# Episode 436, step 32700, win = False, reward = -893.2936986273804
# Episode 437, step 32775, win = False, reward = -574.0976628392441
# Episode 438, step 32850, win = False, reward = -437.23449316413723
# Episode 439, step 32925, win = False, reward = -526.8062645188758
# Episode 440, step 33000, win = False, reward = -311.5779382820496
# Episode 441, step 33075, win = False, reward = -523.8506668170937
# Episode 442, step 33150, win = False, reward = -779.01050221889
# Episode 443, step 33225, win = False, reward = -226.3166863777493
# Episode 444, step 33300, win = False, reward = -452.78178363574597
# Episode 445, step 33375, win = False, reward = -416.2460380418494
# Episode 446, step 33450, win = False, reward = -309.48732320204067
# Episode 447, step 33525, win = False, reward = -335.98496507974914
# Episode 448, step 33600, win = False, reward = -429.12504384964706
# Episode 449, step 33675, win = False, reward = -722.1010945049811
# Episode 450, step 33750, win = False, reward = -343.56910924160997
# Episode 451, step 33825, win = False, reward = -1063.0472825642323
# Episode 452, step 33900, win = False, reward = -335.54278737873824
# Episode 453, step 33975, win = False, reward = -540.0441075358559
# Episode 454, step 34050, win = False, reward = -352.9521210459945
# Episode 455, step 34125, win = False, reward = -292.2750621129236
# Episode 456, step 34200, win = False, reward = -190.38118653764332
# Episode 457, step 34275, win = False, reward = -516.8703379361265
# Episode 458, step 34350, win = False, reward = -524.5729845754138
# Episode 459, step 34425, win = False, reward = -445.57512800773486
# Episode 460, step 34500, win = False, reward = -407.80316289985825
# Episode 461, step 34575, win = False, reward = -987.8861580426557
# Episode 462, step 34650, win = False, reward = -267.541903205081
# Episode 463, step 34725, win = False, reward = -262.50039221829167
# Episode 464, step 34800, win = False, reward = -268.0182355342051
# Episode 465, step 34875, win = False, reward = -359.04630252331094
# Episode 466, step 34950, win = False, reward = -521.8234965239147
# Episode 467, step 35025, win = False, reward = -346.9550310047266
# Episode 468, step 35100, win = False, reward = -420.1460258513658
# Episode 469, step 35175, win = False, reward = -404.3083116337133
# Episode 470, step 35250, win = False, reward = -710.1319580330164
# Episode 471, step 35325, win = False, reward = -530.1781929592303
# Episode 472, step 35400, win = False, reward = -445.9164821143873
# Episode 473, step 35475, win = False, reward = -328.56723623471487
# Episode 474, step 35550, win = False, reward = -571.8815455834828
# Episode 475, step 35625, win = False, reward = -343.21095289591364
# Episode 476, step 35700, win = False, reward = -568.2178780566812
# Episode 477, step 35775, win = False, reward = -271.96298843777527
# Episode 478, step 35850, win = False, reward = -324.00419684056413
# Episode 479, step 35925, win = False, reward = -615.9449495979379
# Episode 480, step 36000, win = False, reward = -393.56146946557703
# Episode 481, step 36075, win = False, reward = -455.4372247746594
# Episode 482, step 36150, win = False, reward = -279.04942999201677
# Episode 483, step 36225, win = False, reward = -387.775290294172
# Episode 484, step 36300, win = False, reward = -401.08119880656005
# Episode 485, step 36375, win = False, reward = -517.6188840988464
# Episode 486, step 36450, win = False, reward = -1390.444230537051
# Episode 487, step 36525, win = False, reward = -604.1548770137728
# Episode 488, step 36600, win = False, reward = -700.532222585142
# Episode 489, step 36675, win = False, reward = -522.1961217719378
# Episode 490, step 36750, win = False, reward = -499.7812423988747
# Episode 491, step 36825, win = False, reward = -305.0089439160316
# Episode 492, step 36900, win = False, reward = -343.83785001778887
# Episode 493, step 36975, win = False, reward = -312.6805673079258
# Episode 494, step 37050, win = False, reward = -413.9162221276522
# Episode 495, step 37125, win = False, reward = -412.5653077772507
# Episode 496, step 37200, win = False, reward = -683.5647519357688
# Episode 497, step 37275, win = False, reward = -734.6939782310843
# Episode 498, step 37350, win = False, reward = -341.11230663060576
# Episode 499, step 37425, win = False, reward = -260.76952720247556
# Episode 500, step 37500, win = False, reward = -319.97257983055334
# Episode 501, step 37575, win = False, reward = -361.0880216728654
# Episode 502, step 37650, win = False, reward = -242.2397757733679
# Episode 503, step 37725, win = False, reward = -303.54198405190334
# Episode 504, step 37800, win = False, reward = -177.21326054589045
# Episode 505, step 37875, win = False, reward = -346.2186572922907
# Episode 506, step 37950, win = False, reward = -223.69057736162733
# Episode 507, step 38025, win = False, reward = -319.45225900970837
# Episode 508, step 38100, win = False, reward = -405.1493348538693
# Episode 509, step 38175, win = False, reward = -227.77417860736472
# Episode 510, step 38250, win = False, reward = -844.0122368559944
# Episode 511, step 38325, win = False, reward = -396.0931049807486
# Episode 512, step 38400, win = False, reward = -264.822950856994
# Episode 513, step 38475, win = False, reward = -506.75412008682713
# Episode 514, step 38550, win = False, reward = -442.18163538975466
# Episode 515, step 38625, win = False, reward = -286.6205198867631
# Episode 516, step 38700, win = False, reward = -370.06385702567485
# Episode 517, step 38775, win = False, reward = -436.16431488413576
# Episode 518, step 38850, win = False, reward = -661.4557678665933
# Episode 519, step 38925, win = False, reward = -818.7887567201561
# Episode 520, step 39000, win = False, reward = -272.6700306082081
# Episode 521, step 39075, win = False, reward = -325.55839050786676
# Episode 522, step 39150, win = False, reward = -272.56078365558506
# Episode 523, step 39225, win = False, reward = -293.5106860296705
# Episode 524, step 39300, win = False, reward = -435.19243593410704
# Episode 525, step 39375, win = False, reward = -665.7863873445226
# Episode 526, step 39450, win = False, reward = -328.5378608323093
# Episode 527, step 39525, win = False, reward = -284.63301167047086
# Episode 528, step 39600, win = False, reward = -323.41301428695766
# Episode 529, step 39675, win = False, reward = -946.6623154968559
# Episode 530, step 39750, win = False, reward = -350.5100703169779
# Episode 531, step 39825, win = False, reward = -261.4097205793754
# Episode 532, step 39900, win = False, reward = -310.80616334139523
# Episode 533, step 39975, win = False, reward = -460.83424361091477
# Episode 534, step 40050, win = False, reward = -602.0706800187318
# Test reward = -2129.9384480418735, win_rate = 0.0
# Episode 535, step 40125, win = False, reward = -387.56987285783487
# Episode 536, step 40200, win = False, reward = -367.1291920308253
# Episode 537, step 40275, win = False, reward = -234.7878899905889
# Episode 538, step 40350, win = False, reward = -459.4906471864963
# Episode 539, step 40425, win = False, reward = -321.2046980631562
# Episode 540, step 40500, win = False, reward = -541.2061817621043
# Episode 541, step 40575, win = False, reward = -334.34399990022644
# Episode 542, step 40650, win = False, reward = -225.842476866908
# Episode 543, step 40725, win = False, reward = -269.17709113822
# Episode 544, step 40800, win = False, reward = -560.8654440864034
# Episode 545, step 40875, win = False, reward = -229.03208735568424
# Episode 546, step 40950, win = False, reward = -466.7883905521054
# Episode 547, step 41025, win = False, reward = -543.1199919895037
# Episode 548, step 41100, win = False, reward = -251.7371670661446
# Episode 549, step 41175, win = False, reward = -301.82487156585296
# Episode 550, step 41250, win = False, reward = -299.19925523457965
# Episode 551, step 41325, win = False, reward = -757.0323952036352
# Episode 552, step 41400, win = False, reward = -290.12359945552043
# Episode 553, step 41475, win = False, reward = -277.40909399822164
# Episode 554, step 41550, win = False, reward = -419.9550081881339
# Episode 555, step 41625, win = False, reward = -300.46004518115944
# Episode 556, step 41700, win = False, reward = -300.0391239695966
# Episode 557, step 41775, win = False, reward = -408.63480262515986
# Episode 558, step 41850, win = False, reward = -459.51033550170473
# Episode 559, step 41925, win = False, reward = -1211.8276073078912
# Episode 560, step 42000, win = False, reward = -371.6710425582952
# Episode 561, step 42075, win = False, reward = -306.64624775974346
# Episode 562, step 42150, win = False, reward = -433.52910064696187
# Episode 563, step 42225, win = False, reward = -212.83397166709403
# Episode 564, step 42300, win = False, reward = -279.6417473833736
# Episode 565, step 42375, win = False, reward = -215.2638601007576
# Episode 566, step 42450, win = False, reward = -328.20063779096773
# Episode 567, step 42525, win = False, reward = -294.0427000707286
# Episode 568, step 42600, win = False, reward = -409.40265417365373
# Episode 569, step 42675, win = False, reward = -330.0875549164135
# Episode 570, step 42750, win = False, reward = -267.6413902888401
# Episode 571, step 42825, win = False, reward = -344.689572694724
# Episode 572, step 42900, win = False, reward = -340.5901848962647
# Episode 573, step 42975, win = False, reward = -219.690577625985
# Episode 574, step 43050, win = False, reward = -212.77391182415533
# Episode 575, step 43125, win = False, reward = -351.6665540814276
# Episode 576, step 43200, win = False, reward = -649.5193775745536
# Episode 577, step 43275, win = False, reward = -418.3960586601951
# Episode 578, step 43350, win = False, reward = -247.88932062014314
# Episode 579, step 43425, win = False, reward = -523.8389034323699
# Episode 580, step 43500, win = False, reward = -459.332391269314
# Episode 581, step 43575, win = False, reward = -549.9688490725667
# Episode 582, step 43650, win = False, reward = -242.95642611339198
# Episode 583, step 43725, win = False, reward = -261.43549915977025
# Episode 584, step 43800, win = False, reward = -397.2965666342337
# Episode 585, step 43875, win = False, reward = -1180.334388794346
# Episode 586, step 43950, win = False, reward = -530.7661405746809
# Episode 587, step 44025, win = False, reward = -326.2470317721167
# Episode 588, step 44100, win = False, reward = -335.63145570756336
# Episode 589, step 44175, win = False, reward = -227.75351240197364
# Episode 590, step 44250, win = False, reward = -226.3417986501619
# Episode 591, step 44325, win = False, reward = -441.94888615920627
# Episode 592, step 44400, win = False, reward = -317.06103362445845
# Episode 593, step 44475, win = False, reward = -901.485828110348
# Episode 594, step 44550, win = False, reward = -508.3883615510225
# Episode 595, step 44625, win = False, reward = -241.27282126995738
# Episode 596, step 44700, win = False, reward = -268.60182959101087
# Episode 597, step 44775, win = False, reward = -365.01523492519584
# Episode 598, step 44850, win = False, reward = -566.7312540769825
# Episode 599, step 44925, win = False, reward = -380.74228966580455
# Episode 600, step 45000, win = False, reward = -272.08294940655696
# Episode 601, step 45075, win = False, reward = -536.9091876172628
# Episode 602, step 45150, win = False, reward = -182.72023169893075
# Episode 603, step 45225, win = False, reward = -565.9864861451473
# Episode 604, step 45300, win = False, reward = -241.30555441275735
# Episode 605, step 45375, win = False, reward = -287.7403409570242
# Episode 606, step 45450, win = False, reward = -349.05658375438776
# Episode 607, step 45525, win = False, reward = -413.06269865443426
# Episode 608, step 45600, win = False, reward = -341.3984393379913
# Episode 609, step 45675, win = False, reward = -374.2463271696228
# Episode 610, step 45750, win = False, reward = -512.1643101321375
# Episode 611, step 45825, win = False, reward = -279.5969487013667
# Episode 612, step 45900, win = False, reward = -178.06882724765455
# Episode 613, step 45975, win = False, reward = -399.30015598313463
# Episode 614, step 46050, win = False, reward = -205.75049093200755
# Episode 615, step 46125, win = False, reward = -297.002263690535
# Episode 616, step 46200, win = False, reward = -188.8984050958635
# Episode 617, step 46275, win = False, reward = -285.5711942727198
# Episode 618, step 46350, win = False, reward = -474.06465870707217
# Episode 619, step 46425, win = False, reward = -359.6774492916484
# Episode 620, step 46500, win = False, reward = -200.22703793932186
# Episode 621, step 46575, win = False, reward = -394.9408687471777
# Episode 622, step 46650, win = False, reward = -340.2555449202712
# Episode 623, step 46725, win = False, reward = -869.390255368341
# Episode 624, step 46800, win = False, reward = -998.4724534064444
# Episode 625, step 46875, win = False, reward = -376.13198749818434
# Episode 626, step 46950, win = False, reward = -386.4517754243659
# Episode 627, step 47025, win = False, reward = -311.33638239554415
# Episode 628, step 47100, win = False, reward = -623.4397873609348
# Episode 629, step 47175, win = False, reward = -525.5920218328624
# Episode 630, step 47250, win = False, reward = -226.76047060360105
# Episode 631, step 47325, win = False, reward = -309.53921683942957
# Episode 632, step 47400, win = False, reward = -401.25031891207163
# Episode 633, step 47475, win = False, reward = -325.3526907099962
# Episode 634, step 47550, win = False, reward = -233.35053827835793
# Episode 635, step 47625, win = False, reward = -401.75022099687726
# Episode 636, step 47700, win = False, reward = -213.11464059233433
# Episode 637, step 47775, win = False, reward = -356.4511596353686
# Episode 638, step 47850, win = False, reward = -316.69546728273247
# Episode 639, step 47925, win = False, reward = -518.0812648381101
# Episode 640, step 48000, win = False, reward = -228.82144352260485
# Episode 641, step 48075, win = False, reward = -244.8435404207158
# Episode 642, step 48150, win = False, reward = -255.78740923251956
# Episode 643, step 48225, win = False, reward = -673.9161661815476
# Episode 644, step 48300, win = False, reward = -476.81429397916645
# Episode 645, step 48375, win = False, reward = -280.99904653181324
# Episode 646, step 48450, win = False, reward = -306.9279088905225
# Episode 647, step 48525, win = False, reward = -286.70073457169434
# Episode 648, step 48600, win = False, reward = -375.09371287114203
# Episode 649, step 48675, win = False, reward = -288.552664578845
# Episode 650, step 48750, win = False, reward = -238.91562283383217
# Episode 651, step 48825, win = False, reward = -573.2473549260567
# Episode 652, step 48900, win = False, reward = -239.153798477417
# Episode 653, step 48975, win = False, reward = -192.74329962120234
# Episode 654, step 49050, win = False, reward = -216.68281761892038
# Episode 655, step 49125, win = False, reward = -347.6300984533599
# Episode 656, step 49200, win = False, reward = -277.4453637350735
# Episode 657, step 49275, win = False, reward = -181.92873132426254
# Episode 658, step 49350, win = False, reward = -188.8735732467755
# Episode 659, step 49425, win = False, reward = -253.25951463851777
# Episode 660, step 49500, win = False, reward = -327.52852877994417
# Episode 661, step 49575, win = False, reward = -245.63693936530424
# Episode 662, step 49650, win = False, reward = -289.56439080643423
# Episode 663, step 49725, win = False, reward = -269.0328509780175
# Episode 664, step 49800, win = False, reward = -290.7269972880951
# Episode 665, step 49875, win = False, reward = -248.08176304756535
# Episode 666, step 49950, win = False, reward = -301.2117026204512
# Episode 667, step 50025, win = False, reward = -710.9802586201658
# Test reward = -1277.9220203773427, win_rate = 0.0
# Episode 668, step 50100, win = False, reward = -275.9618795620161
# Episode 669, step 50175, win = False, reward = -291.7298391960498
# Episode 670, step 50250, win = False, reward = -358.95122581981536
# Episode 671, step 50325, win = False, reward = -170.0522312018008
# Episode 672, step 50400, win = False, reward = -342.1550516210979
# Episode 673, step 50475, win = False, reward = -268.439018141828
# Episode 674, step 50550, win = False, reward = -323.84978260504346
# Episode 675, step 50625, win = False, reward = -230.82113840583312
# Episode 676, step 50700, win = False, reward = -211.6887247783819
# Episode 677, step 50775, win = False, reward = -282.2674931587808
# Episode 678, step 50850, win = False, reward = -324.8258577459373
# Episode 679, step 50925, win = False, reward = -399.07561690996744
# Episode 680, step 51000, win = False, reward = -237.80569551537394
# Episode 681, step 51075, win = False, reward = -309.93644571037856
# Episode 682, step 51150, win = False, reward = -368.28638985620927
# Episode 683, step 51225, win = False, reward = -356.0043391982071
# Episode 684, step 51300, win = False, reward = -179.26858793777365
# Episode 685, step 51375, win = False, reward = -562.5743026753728
# Episode 686, step 51450, win = False, reward = -233.22187593760012
# Episode 687, step 51525, win = False, reward = -288.17647213880974
# Episode 688, step 51600, win = False, reward = -258.500261443958
# Episode 689, step 51675, win = False, reward = -373.3096189899341
# Episode 690, step 51750, win = False, reward = -265.6234280886191
# Episode 691, step 51825, win = False, reward = -309.2407263706489
# Episode 692, step 51900, win = False, reward = -311.02791832831537
# Episode 693, step 51975, win = False, reward = -558.536719195338
# Episode 694, step 52050, win = False, reward = -345.9291082246146
# Episode 695, step 52125, win = False, reward = -230.11095664710405
# Episode 696, step 52200, win = False, reward = -378.6410113336884
# Episode 697, step 52275, win = False, reward = -409.73806451437696
# Episode 698, step 52350, win = False, reward = -197.19558500816748
# Episode 699, step 52425, win = False, reward = -221.70310775899404
# Episode 700, step 52500, win = False, reward = -218.3509902789708
# Episode 701, step 52575, win = False, reward = -272.8746081757757
# Episode 702, step 52650, win = False, reward = -276.0076709911078
# Episode 703, step 52725, win = False, reward = -217.46190384763787
# Episode 704, step 52800, win = False, reward = -468.9485287646766
# Episode 705, step 52875, win = False, reward = -361.7852573631943
# Episode 706, step 52950, win = False, reward = -251.7543400759563
# Episode 707, step 53025, win = False, reward = -453.40443682347654
# Episode 708, step 53100, win = False, reward = -383.83860496296364
# Episode 709, step 53175, win = False, reward = -424.1509819859264
# Episode 710, step 53250, win = False, reward = -288.3619609710959
# Episode 711, step 53325, win = False, reward = -336.78737773454975
# Episode 712, step 53400, win = False, reward = -280.2501517323635
# Episode 713, step 53475, win = False, reward = -269.27681171484005
# Episode 714, step 53550, win = False, reward = -278.86298039005425
# Episode 715, step 53625, win = False, reward = -199.7461837275124
# Episode 716, step 53700, win = False, reward = -290.27468460875
# Episode 717, step 53775, win = False, reward = -196.68465955276986
# Episode 718, step 53850, win = False, reward = -401.9523926305532
# Episode 719, step 53925, win = False, reward = -291.2178839946403
# Episode 720, step 54000, win = False, reward = -536.4276489261617
# Episode 721, step 54075, win = False, reward = -344.2066041539527
# Episode 722, step 54150, win = False, reward = -286.5169910536848
# ...
# Episode 7820, step 586500, win = False, reward = -224.58816919166753
# Episode 7821, step 586575, win = False, reward = -196.76373784516275
# Episode 7822, step 586650, win = False, reward = -212.00480087320358
# Episode 7823, step 586725, win = False, reward = -164.54444821580336
# Episode 7824, step 586800, win = False, reward = -220.71403618134246
# Episode 7825, step 586875, win = False, reward = -194.36968788686954
# Episode 7826, step 586950, win = False, reward = -223.84913568922053
# Episode 7827, step 587025, win = False, reward = -141.16822915006796
# Episode 7828, step 587100, win = False, reward = -295.1182108239708
# Episode 7829, step 587175, win = False, reward = -186.42167081535703
# Episode 7830, step 587250, win = False, reward = -200.501322812585
# Episode 7831, step 587325, win = False, reward = -186.42608817994193
# Episode 7832, step 587400, win = False, reward = -178.83383881208124
# Episode 7833, step 587475, win = False, reward = -262.696358771063
# Episode 7834, step 587550, win = False, reward = -191.51242579635192
# Episode 7835, step 587625, win = False, reward = -185.26719457075075
# Episode 7836, step 587700, win = False, reward = -257.68101699612754
# Episode 7837, step 587775, win = False, reward = -166.31866981669555
# Episode 7838, step 587850, win = False, reward = -203.2064727993104
# Episode 7839, step 587925, win = False, reward = -255.60677680598408
# Episode 7840, step 588000, win = False, reward = -264.57050615147
# Episode 7841, step 588075, win = False, reward = -246.6982961974382
# Episode 7842, step 588150, win = False, reward = -291.2773833882168
# Episode 7843, step 588225, win = False, reward = -158.84784859075197
# Episode 7844, step 588300, win = False, reward = -230.56911039944896
# Episode 7845, step 588375, win = False, reward = -170.90947718577888
# Episode 7846, step 588450, win = False, reward = -297.700218362211
# Episode 7847, step 588525, win = False, reward = -223.37446158846137
# Episode 7848, step 588600, win = False, reward = -261.7274368474484
# Episode 7849, step 588675, win = False, reward = -156.75383390837808
# Episode 7850, step 588750, win = False, reward = -174.00217787942697
# Episode 7851, step 588825, win = False, reward = -201.8022091019579
# Episode 7852, step 588900, win = False, reward = -290.33903433653865
# Episode 7853, step 588975, win = False, reward = -261.96662896795425
# Episode 7854, step 589050, win = False, reward = -149.52890265223834
# Episode 7855, step 589125, win = False, reward = -168.88792397404225
# Episode 7856, step 589200, win = False, reward = -128.32353329012048
# Episode 7857, step 589275, win = False, reward = -174.80230395084365
# Episode 7858, step 589350, win = False, reward = -198.41524087690885
# Episode 7859, step 589425, win = False, reward = -303.74033659998656
# Episode 7860, step 589500, win = False, reward = -154.84179366120088
# Episode 7861, step 589575, win = False, reward = -228.9856899717436
# Episode 7862, step 589650, win = False, reward = -155.93178567707886
# Episode 7863, step 589725, win = False, reward = -226.95796168527727
# Episode 7864, step 589800, win = False, reward = -249.03326009359523
# Episode 7865, step 589875, win = False, reward = -213.08773875322686
# Episode 7866, step 589950, win = False, reward = -197.50404712383474
# Episode 7867, step 590025, win = False, reward = -160.47500149110797
# Test reward = -217.0815132272282, win_rate = 0.0
# Episode 7868, step 590100, win = False, reward = -288.3301163127824
# Episode 7869, step 590175, win = False, reward = -190.9007883062079
# Episode 7870, step 590250, win = False, reward = -210.07270767060444
# Episode 7871, step 590325, win = False, reward = -215.21969864472365
# Episode 7872, step 590400, win = False, reward = -218.79901026793317
# Episode 7873, step 590475, win = False, reward = -199.39536728965666
# Episode 7874, step 590550, win = False, reward = -140.83402548590726
# Episode 7875, step 590625, win = False, reward = -221.23727048538876
# Episode 7876, step 590700, win = False, reward = -246.71026385877596
# Episode 7877, step 590775, win = False, reward = -187.3183680942519
# Episode 7878, step 590850, win = False, reward = -180.65476856216827
# Episode 7879, step 590925, win = False, reward = -216.748146705115
# Episode 7880, step 591000, win = False, reward = -198.4340619971627
# Episode 7881, step 591075, win = False, reward = -217.26560121453812
# Episode 7882, step 591150, win = False, reward = -200.49925978391798
# Episode 7883, step 591225, win = False, reward = -243.0715936149454
# Episode 7884, step 591300, win = False, reward = -226.51180145568662
# Episode 7885, step 591375, win = False, reward = -166.71987533330804
# Episode 7886, step 591450, win = False, reward = -166.58015862172616
# Episode 7887, step 591525, win = False, reward = -212.28303191867997
# Episode 7888, step 591600, win = False, reward = -216.3777137758946
# Episode 7889, step 591675, win = False, reward = -238.47360964468595
# Episode 7890, step 591750, win = False, reward = -248.57239121526305
# Episode 7891, step 591825, win = False, reward = -229.0183913350403
# Episode 7892, step 591900, win = False, reward = -221.69411056676356
# Episode 7893, step 591975, win = False, reward = -181.32195674955835
# Episode 7894, step 592050, win = False, reward = -256.313687954456
# Episode 7895, step 592125, win = False, reward = -181.67768637472986
# Episode 7896, step 592200, win = False, reward = -250.42815857827472
# Episode 7897, step 592275, win = False, reward = -180.30680404183258
# Episode 7898, step 592350, win = False, reward = -142.53742434604055
# Episode 7899, step 592425, win = False, reward = -124.12866565607685
# Episode 7900, step 592500, win = False, reward = -174.38465230935122
# Episode 7901, step 592575, win = False, reward = -209.16650552043922
# Episode 7902, step 592650, win = False, reward = -212.6942829442323
# Episode 7903, step 592725, win = False, reward = -202.3005786435769
# Episode 7904, step 592800, win = False, reward = -180.02323913415944
# Episode 7905, step 592875, win = False, reward = -190.95984885791933
# Episode 7906, step 592950, win = False, reward = -254.82717254637294
# Episode 7907, step 593025, win = False, reward = -175.93318888454937
# Episode 7908, step 593100, win = False, reward = -144.70423549540732
# Episode 7909, step 593175, win = False, reward = -219.8809743672402
# Episode 7910, step 593250, win = False, reward = -159.11344189178658
# Episode 7911, step 593325, win = False, reward = -195.57015329255526
# Episode 7912, step 593400, win = False, reward = -237.26925744288394
# Episode 7913, step 593475, win = False, reward = -223.55332330379315
# Episode 7914, step 593550, win = False, reward = -136.0161097906324
# Episode 7915, step 593625, win = False, reward = -242.3840242126768
# Episode 7916, step 593700, win = False, reward = -251.57746852719515
# Episode 7917, step 593775, win = False, reward = -171.25128690228425
# Episode 7918, step 593850, win = False, reward = -236.77366432901195
# Episode 7919, step 593925, win = False, reward = -179.79375625027888
# Episode 7920, step 594000, win = False, reward = -307.71521432057875
# Episode 7921, step 594075, win = False, reward = -228.8274909571486
# Episode 7922, step 594150, win = False, reward = -284.44392156874306
# Episode 7923, step 594225, win = False, reward = -301.28186942445126
# Episode 7924, step 594300, win = False, reward = -216.8220569124257
# Episode 7925, step 594375, win = False, reward = -183.69153142809094
# Episode 7926, step 594450, win = False, reward = -196.80542940005137
# Episode 7927, step 594525, win = False, reward = -152.9418191172417
# Episode 7928, step 594600, win = False, reward = -233.289261635766
# Episode 7929, step 594675, win = False, reward = -184.4741168638732
# Episode 7930, step 594750, win = False, reward = -214.27755837040635
# Episode 7931, step 594825, win = False, reward = -202.79321477237838
# Episode 7932, step 594900, win = False, reward = -264.86862521703614
# Episode 7933, step 594975, win = False, reward = -162.43968611535144
# Episode 7934, step 595050, win = False, reward = -194.81216728317267
# Episode 7935, step 595125, win = False, reward = -230.87060681151357
# Episode 7936, step 595200, win = False, reward = -193.39985663634118
# Episode 7937, step 595275, win = False, reward = -236.8032430996537
# Episode 7938, step 595350, win = False, reward = -170.65117157724146
# Episode 7939, step 595425, win = False, reward = -295.7598111499095
# Episode 7940, step 595500, win = False, reward = -143.21587187438016
# Episode 7941, step 595575, win = False, reward = -189.23670542029947
# Episode 7942, step 595650, win = False, reward = -255.4457672216795
# Episode 7943, step 595725, win = False, reward = -285.43342862294963
# Episode 7944, step 595800, win = False, reward = -203.64305756605137
# Episode 7945, step 595875, win = False, reward = -213.41533858575187
# Episode 7946, step 595950, win = False, reward = -235.76420895776252
# Episode 7947, step 596025, win = False, reward = -203.8967832366114
# Episode 7948, step 596100, win = False, reward = -157.75487707526804
# Episode 7949, step 596175, win = False, reward = -224.20713453830552
# Episode 7950, step 596250, win = False, reward = -246.23281327790957
# Episode 7951, step 596325, win = False, reward = -209.4422930217876
# Episode 7952, step 596400, win = False, reward = -217.5174662796052
# Episode 7953, step 596475, win = False, reward = -231.94793868504965
# Episode 7954, step 596550, win = False, reward = -199.30704686322295
# Episode 7955, step 596625, win = False, reward = -258.22153046094456
# Episode 7956, step 596700, win = False, reward = -196.93424641190094
# Episode 7957, step 596775, win = False, reward = -236.21261748426548
# Episode 7958, step 596850, win = False, reward = -270.9745400486939
# Episode 7959, step 596925, win = False, reward = -141.07964530557146
# Episode 7960, step 597000, win = False, reward = -202.33233947895187
# Episode 7961, step 597075, win = False, reward = -186.619907190704
# Episode 7962, step 597150, win = False, reward = -238.4254423418705
# Episode 7963, step 597225, win = False, reward = -167.92795263917426
# Episode 7964, step 597300, win = False, reward = -195.42982274872512
# Episode 7965, step 597375, win = False, reward = -196.43255130447494
# Episode 7966, step 597450, win = False, reward = -177.35149129999454
# Episode 7967, step 597525, win = False, reward = -298.5305685297615
# Episode 7968, step 597600, win = False, reward = -236.44929020766506
# Episode 7969, step 597675, win = False, reward = -197.43237543822198
# Episode 7970, step 597750, win = False, reward = -140.1984935626266
# Episode 7971, step 597825, win = False, reward = -184.88062479271312
# Episode 7972, step 597900, win = False, reward = -302.49170491200505
# Episode 7973, step 597975, win = False, reward = -201.7234507857266
# Episode 7974, step 598050, win = False, reward = -244.0039861379013
# Episode 7975, step 598125, win = False, reward = -202.2307435626367
# Episode 7976, step 598200, win = False, reward = -317.80250085254477
# Episode 7977, step 598275, win = False, reward = -187.97170429015821
# Episode 7978, step 598350, win = False, reward = -171.17351201863812
# Episode 7979, step 598425, win = False, reward = -202.73351970877582
# Episode 7980, step 598500, win = False, reward = -139.69958951809306
# Episode 7981, step 598575, win = False, reward = -263.95778977997
# Episode 7982, step 598650, win = False, reward = -246.59566193960652
# Episode 7983, step 598725, win = False, reward = -224.88570415363975
# Episode 7984, step 598800, win = False, reward = -196.68416576700386
# Episode 7985, step 598875, win = False, reward = -226.19093968195813
# Episode 7986, step 598950, win = False, reward = -229.732565723595
# Episode 7987, step 599025, win = False, reward = -239.99197140068253
# Episode 7988, step 599100, win = False, reward = -176.66753057204141
# Episode 7989, step 599175, win = False, reward = -151.6000861420778
# Episode 7990, step 599250, win = False, reward = -209.50829140225127
# Episode 7991, step 599325, win = False, reward = -239.43982749962365
# Episode 7992, step 599400, win = False, reward = -265.0531315426191
# Episode 7993, step 599475, win = False, reward = -223.98951208268426
# Episode 7994, step 599550, win = False, reward = -172.4973341375638
# Episode 7995, step 599625, win = False, reward = -175.0538936982908
# Episode 7996, step 599700, win = False, reward = -201.44640026760496
# Episode 7997, step 599775, win = False, reward = -171.27590171834618
# Episode 7998, step 599850, win = False, reward = -196.21866031761405
# Episode 7999, step 599925, win = False, reward = -272.84647361990886
# Episode 8000, step 600000, win = False, reward = -206.37298053462425
# Test reward = -221.79303273793064, win_rate = 0.0
# Episode 8001, step 600075, win = False, reward = -201.4321368793364
# Episode 8002, step 600150, win = False, reward = -193.7326644282998
# Episode 8003, step 600225, win = False, reward = -221.05630241611294
# Episode 8004, step 600300, win = False, reward = -204.83072767184552
# Episode 8005, step 600375, win = False, reward = -220.24750719433254
# Episode 8006, step 600450, win = False, reward = -164.7680596615885
# Episode 8007, step 600525, win = False, reward = -269.4561308648646
# Episode 8008, step 600600, win = False, reward = -122.88417330958728
# Episode 8009, step 600675, win = False, reward = -218.36912915781733
# Episode 8010, step 600750, win = False, reward = -287.7652357300075
# Episode 8011, step 600825, win = False, reward = -236.0829459118398
# Episode 8012, step 600900, win = False, reward = -270.5497451409728
# Episode 8013, step 600975, win = False, reward = -221.98659214312855
# Episode 8014, step 601050, win = False, reward = -301.1707855561283
# Episode 8015, step 601125, win = False, reward = -251.65627856471332
# Episode 8016, step 601200, win = False, reward = -190.85604715197724
# Episode 8017, step 601275, win = False, reward = -259.53510107770023
# Episode 8018, step 601350, win = False, reward = -237.92862734886685
# Episode 8019, step 601425, win = False, reward = -196.78794568253755
# Episode 8020, step 601500, win = False, reward = -200.79069425104973
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 969
#     967 experiment = Experiment(args)
#     968 experiment.start()
# --> 969 experiment.run()
#
# Cell In[31], line 812, in Experiment.run(self)
#     810 data = buffer.sample(args.n_batch, args.top_n)
#     811 if data:
# --> 812     loss = learner.train(data)
#     814 if self.step // args.test_every_step != old_step // args.test_every_step:
#     815     self.test_model()
#
# Cell In[31], line 593, in Learner.train(self, data)
#     591 loss = loss1+loss2
#     592 self.optim_critic.zero_grad()
# --> 593 loss.backward()
#     594 torch.nn.utils.clip_grad_norm_(self.params_critic, self.args.grad_norm_clip)
#     595 self.optim_critic.step()
#
# File ~/miniconda/envs/drlzh/lib/python3.11/site-packages/torch/_tensor.py:522, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     512 if has_torch_function_unary(self):
#     513     return handle_torch_function(
#     514         Tensor.backward,
#     515         (self,),
#    (...)
#     520         inputs=inputs,
#     521     )
# --> 522 torch.autograd.backward(
#     523     self, gradient, retain_graph, create_graph, inputs=inputs
#     524 )
#
# File ~/miniconda/envs/drlzh/lib/python3.11/site-packages/torch/autograd/__init__.py:266, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     261     retain_graph = create_graph
#     263 # The reason we repeat the same comment below is that
#     264 # some Python versions print out the first line of a multi-line function
#     265 # calls in the traceback and some print out the last line
# --> 266 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267     tensors,
#     268     grad_tensors_,
#     269     retain_graph,
#     270     create_graph,
#     271     inputs,
#     272     allow_unreachable=True,
#     273     accumulate_grad=True,
#     274 )
#
# KeyboardInterrupt:
