# %%
# %pip install stable-baselines3 numpy torch supersuit pettingzoo pymunk scipy gymnasium matplotlib einops tensorboard wandb imageio
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
import datetime
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import random
from collections import deque
from typing import List, Dict, NamedTuple
import gymnasium as gym
from pettingzoo.mpe import simple_reference_v3
import os
from torch.utils.tensorboard import SummaryWriter
from argparse import Namespace
import time
import sys
import json


class WritterUtil:
    def __init__(self, writter: SummaryWriter, args):
        self.writter = writter
        self.log_every = args.log_every
        self.scalars = {}
        self.step = 0
        self.log_step = 0

    def set_step(self, step):
        self.step += 1
        self.log_step = step

    def WriteScalar(self, tag, value):
        
        step = self.step
        log_step = self.log_step
        self.writter.add_scalar('raw/'+tag, value, log_step)

        if tag not in self.scalars:
            self.scalars[tag] = [0, step-1, torch.zeros(self.log_every)]
        
        n, last_step, buffer = self.scalars[tag]
        
        buffer[n] = value
        n += 1
        if step - last_step >= self.log_every:
            mean = torch.mean(buffer[0:n])
            self.writter.add_scalar('mean/'+tag, mean, log_step)
            self.writter.add_histogram(tag, buffer[0:n], log_step)
            
            last_step = step
            n=0


        self.scalars[tag] = [n,last_step,buffer]

class Controller:
    def __init__(self, sys_agent, args):
        self.n_agents = args.n_agents
        self.n_actions = args.n_actions        
        self.agent_id = args.agent_id
        self.last_action = args.last_action
        self.device = args.device    
        self.sys_agent_src = sys_agent
        self.sys_agent = type(sys_agent)(args)        
        self.sys_agent.requires_grad_(False)        
        self.episode = 0

    def new_episode(self):
        state_dict = self.sys_agent_src.state_dict()
        self.sys_agent.load_state_dict(state_dict)        
        self.hiddens = self.sys_agent.init_hiddens(1)
        self.last_actions = torch.zeros(1, self.n_agents, self.n_actions)      
        self.episode += 1

    def get_actions(self, states, avail_actions, explore=False):
        # Explicit tensor conversion with device and dtype
        states = torch.tensor(states, dtype=torch.float32, device=self.device)
        if states.dim() == 2:
            states = states.unsqueeze(0)
                
        avail_actions = torch.tensor(avail_actions, dtype=torch.float32, device=self.device)
        if avail_actions.dim() == 2:
            avail_actions = avail_actions.unsqueeze(0)
            
        if self.agent_id:
            agent_ids = torch.eye(self.n_agents, device=self.device)
            agent_ids = agent_ids.unsqueeze(0).expand(states.size(0), -1, -1)
            states = torch.cat([states, agent_ids], dim=-1)
        
        if self.last_action:            
            states = torch.cat([states, self.last_actions], -1)
        
        with torch.no_grad():
            ps, hs_next = self.sys_agent.forward(states, avail_actions, self.hiddens)
        self.hiddens = hs_next
        
        # Action selection with validation
        if explore:
            while True:
                actions = torch.multinomial(ps[0], 1).squeeze(-1)
                selected_avails = avail_actions[0][torch.arange(self.n_agents), actions]
                if not (selected_avails == 0).sum().item():
                    break
        else:
            actions = torch.argmax(ps[0], -1)
        
        self.last_actions = self.one_hot(actions, self.n_actions).unsqueeze(0)
        return actions.cpu().numpy()

    def one_hot(self, tensor, n_classes):
        return F.one_hot(tensor.to(dtype=torch.int64), n_classes).to(dtype=torch.float32)



class Actor(nn.Module):
    def __init__(self, args):
        super(Actor, self).__init__()
        self.args = args

        self.input_dim = args.input_dim        
        self.n_actions = args.n_actions
        self.n_agents = args.n_agents
        self.rnn_hidden_dim = args.rnn_hidden_dim

        self.fc1 = nn.Linear(self.input_dim, self.rnn_hidden_dim)
        self.rnn = nn.GRUCell(self.rnn_hidden_dim, self.rnn_hidden_dim)
        self.fc2 = nn.Linear(self.rnn_hidden_dim, self.n_actions)

    def init_hidden(self, n_batch):
        # make hidden states on same device as model
        return self.fc1.weight.new_zeros(n_batch, self.rnn_hidden_dim)

    def forward(self, inputs, avail_actions, h_last):
        
        h = F.relu(self.fc1(inputs))        
        h = self.rnn(h, h_last)
        y = self.fc2(h)
        y[avail_actions == 0] = -float('inf')
        y = torch.softmax(y,-1)

        return y,h
    
class Actors(nn.Module):
    def __init__(self, args):
        super(Actors, self).__init__()
        self.n_agents = args.n_agents
        self.n_actions = args.n_actions
        self.agent = Actor(args)

    def init_hiddens(self, n_batch):
        hiddens = self.agent.init_hidden(n_batch*self.n_agents)
        hiddens = hiddens.reshape(n_batch,self.n_agents,-1)
        return hiddens

    def forward(self, states, avail_actions, hiddens):
        n_batch = states.shape[0]
        states = states.reshape(-1,states.shape[-1])
        hiddens = hiddens.reshape(-1,hiddens.shape[-1])
        avail_actions = avail_actions.reshape(-1,avail_actions.shape[-1])
        ys, hs_next = self.agent.forward(states, avail_actions, hiddens)
        ys = ys.reshape(n_batch,self.n_agents,-1)
        hs_next = hs_next.reshape(n_batch,self.n_agents,-1)
        
        return ys, hs_next

class Critic(nn.Module):
    def __init__(self, args):
        super(Critic, self).__init__()
        self.args = args

        self.input_dim = args.input_dim
        
        self.n_actions = args.n_actions
        self.n_agents = args.n_agents
        self.rnn_hidden_dim = args.rnn_hidden_dim

        self.fc1 = nn.Linear(self.input_dim, self.rnn_hidden_dim)
        self.rnn = nn.GRUCell(self.rnn_hidden_dim, self.rnn_hidden_dim)
        self.fc2 = nn.Linear(self.rnn_hidden_dim, self.n_actions)

    def init_hidden(self, n_batch):
        # make hidden states on same device as model
        return self.fc1.weight.new_zeros(n_batch, self.rnn_hidden_dim)

    def forward(self, inputs, avail_actions, h_last):
        # x = torch.cat([inputs, action],1)
        h = F.relu(self.fc1(inputs))
        h = self.rnn(h, h_last)
        y = self.fc2(h)
        y[avail_actions == 0] = -1e38
        return y, h

class Critics(nn.Module):
    def __init__(self, args):
        super(Critics, self).__init__()
        self.n_agents = args.n_agents
        self.n_actions = args.n_actions
        self.agent = Critic(args)



    def init_hiddens(self, n_batch):
        hiddens = self.agent.init_hidden(n_batch*self.n_agents)
        hiddens = hiddens.reshape(n_batch,self.n_agents,-1)
        return hiddens

    def forward(self, states, avail_actions, hiddens):

        n_batch = states.shape[0]
        states = states.reshape(-1,states.shape[-1])
        hiddens = hiddens.reshape(-1,hiddens.shape[-1])
        avail_actions = avail_actions.reshape(-1,avail_actions.shape[-1])
        ys, hs_next = self.agent.forward(states, avail_actions, hiddens)
        ys = ys.reshape(n_batch,self.n_agents,-1)
        hs_next = hs_next.reshape(n_batch,self.n_agents,-1)
        
        return ys, hs_next



class EpisodeBuffer:
    def __init__(self, scheme, args):
        self.scheme = scheme.copy()
        self.buffer_size = args.buffer_size
        self.max_seq_length = args.episode_limit
        # self.device = args.device
        self.device = 'cpu'
        self._setup_data()

    def _setup_data(self):
        self.index_st = 0
        self.n_sample = 0

        self.data = {}
        for k, v in self.scheme.items():
            shape = (self.buffer_size, self.max_seq_length) + v['shape']
            self.data[k] = torch.zeros(shape, dtype=v['dtype'],device=self.device)

    def sample(self, batch_size, top_n = 0):
        if self.n_sample < batch_size:
            return None

        def trans_ids(ep_id):
            ep_id += self.index_st
            ep_id %= self.buffer_size
            return ep_id

        ep_ids = np.random.choice(self.n_sample - top_n, batch_size - top_n, replace=False)
        ep_ids = list(ep_ids) + [self.n_sample-i-1 for i in range(top_n)]# [self.n_sample -1]
        ep_ids = list(map(trans_ids, ep_ids))

        ret = {}
        for k, v in self.data.items():
            ret[k] = v[ep_ids]

        return ret
    

    def add_episode(self, data):

        #len_ep = len
        if self.n_sample < self.buffer_size:
            self.n_sample += 1
        else:
            self.index_st += 1
            self.index_st %= self.buffer_size

        index_ep = (self.index_st + self.n_sample - 1) % self.buffer_size
        
        for k, v in data.items():

            ep_len = len(v)
            dtype = self.scheme[k]['dtype']
            self.data[k][index_ep].zero_()
            self.data[k][index_ep, 0:ep_len] = torch.as_tensor(v, dtype=dtype, device=self.device)

    def clear(self):
        self.index_st = 0
        self.n_sample = 0
        for item in self.data.values():
            item.zero_()
        

    def state_dict(self):
        buffer_state = {'index_st': self.index_st, 'n_sample': self.n_sample, 'data': self.data}
        return buffer_state
    
    def load_state_dict(self, state_dict):
        self.index_st = state_dict['index_st']
        self.n_sample = state_dict['n_sample']    
        self.data = state_dict['data']

class QMixNet(nn.Module):
    def __init__(self, args):
        super(QMixNet, self).__init__()
        self.args = args
        # 因为生成的hyper_w1需要是一个矩阵，而pytorch神经网络只能输出一个向量，
        # 所以就先输出长度为需要的 矩阵行*矩阵列 的向量，然后再转化成矩阵

        # args.n_agents是使用hyper_w1作为参数的网络的输入维度，args.qmix_hidden_dim是网络隐藏层参数个数
        # 从而经过hyper_w1得到(经验条数，args.n_agents * args.qmix_hidden_dim)的矩阵
        
        input_dim = args.state_dim
        
        self.input_dim = input_dim
        self.hyper_w1 = nn.Linear(input_dim, args.n_agents * args.qmix_hidden_dim)
        # 经过hyper_w2得到(经验条数, 1)的矩阵
        self.hyper_w2 = nn.Linear(input_dim, args.qmix_hidden_dim * 1)

        # hyper_w1得到的(经验条数，args.qmix_hidden_dim)矩阵需要同样维度的hyper_b1
        self.hyper_b1 = nn.Linear(input_dim, args.qmix_hidden_dim)
        # hyper_w2得到的(经验条数，1)的矩阵需要同样维度的hyper_b1
        self.hyper_b2 =nn.Sequential(nn.Linear(input_dim, args.qmix_hidden_dim),
                                     nn.ReLU(),
                                     nn.Linear(args.qmix_hidden_dim, 1)
                                     )

    def forward(self, q_values, states):  # states的shape为(episode_num, max_episode_len， state_dim)
        # 传入的q_values是三维的，shape为(episode_num, max_episode_len， n_agents)
        episode_num = q_values.size(0)
        q_values = q_values.view(-1, 1, self.args.n_agents)  # (episode_num * max_episode_len, 1, n_agents) = (1920,1,5)
        states = states.reshape(-1, self.input_dim)  # (episode_num * max_episode_len, state_dim)

        w1 = torch.abs(self.hyper_w1(states))  # (1920, 160)
        b1 = self.hyper_b1(states)  # (1920, 32)

        w1 = w1.view(-1, self.args.n_agents, self.args.qmix_hidden_dim)  # (1920, 5, 32)
        b1 = b1.view(-1, 1, self.args.qmix_hidden_dim)  # (1920, 1, 32)

        hidden = F.elu(torch.bmm(q_values, w1) + b1)  # (1920, 1, 32)

        w2 = torch.abs(self.hyper_w2(states))  # (1920, 32)
        b2 = self.hyper_b2(states)  # (1920, 1)

        w2 = w2.view(-1, self.args.qmix_hidden_dim, 1)  # (1920, 32, 1)
        b2 = b2.view(-1, 1, 1)  # (1920, 1， 1)

        q_total = torch.bmm(hidden, w2) + b2  # (1920, 1, 1)
        q_total = q_total.view(episode_num, -1, 1)  # (32, 60, 1)
        return q_total

class Learner:
    def __init__(self, w_util, args):
        
        self.w_util = w_util
        self.device = args.device
        self.critic_attn = args.critic_attn

        # if self.critic_attn:                        
        #     from .attn_critics import Critics
        # else:            
        #     from .critics import Critics

        self.sys_actor = Actors(args)
        self.sys_critic1 = Critics(args)
        self.sys_critic2 = Critics(args)
        self.sys_critic1_tar = Critics(args)
        self.sys_critic2_tar = Critics(args)
        #self.sys_critic1.train()
        #self.sys_critic2.train()
    
        self.mix_net1 = QMixNet(args)        
        self.mix_net2 = QMixNet(args)        
        self.mix_net1_tar = QMixNet(args)
        self.mix_net2_tar = QMixNet(args)
        
        if self.device != 'cpu':
            self.sys_actor.cuda(self.device)
            self.sys_critic1.cuda(self.device)
            self.sys_critic2.cuda(self.device)
            self.sys_critic1_tar.cuda(self.device)
            self.sys_critic2_tar.cuda(self.device)
            self.mix_net1.cuda(self.device)
            self.mix_net2.cuda(self.device)
            self.mix_net1_tar.cuda(self.device)
            self.mix_net2_tar.cuda(self.device)
        
        self.sys_critic1_tar.requires_grad_(False)
        self.sys_critic2_tar.requires_grad_(False)
        self.mix_net1_tar.requires_grad_(False)
        self.mix_net2_tar.requires_grad_(False)



        self._sync_target()

        
        self.n_agents = args.n_agents
        self.n_actions = args.n_actions
        self.gamma = args.gamma
        self.entropy_tar = args.entropy_tar
        self.lr = args.lr
        self.lr_actor = args.lr_actor
        self.lr_alpha = args.lr_alpha
        self.l2 = args.l2
        self.target_update = args.target_update
        self.step = 0                
        self.agent_id = args.agent_id
        self.last_action = args.last_action  
        self.log_alpha_st = args.log_alpha_st
        self.shared_alpha = args.shared_alpha
        self.maximum_entropy = args.maximum_entropy     
        self.args = args

        
        if self.shared_alpha:
            self.log_alpha = torch.tensor(args.log_alpha_st, dtype=torch.float32, requires_grad=True, device = self.device)
        else:
            self.log_alpha = torch.tensor([args.log_alpha_st]*self.n_agents, dtype=torch.float32, requires_grad=True, device = self.device)
        
        params_critic = list(self.sys_critic1.parameters()) + list(self.sys_critic2.parameters()) + list(self.mix_net1.parameters()) + list(self.mix_net2.parameters())
        
        self.params_critic = params_critic
        self.params_actor = list(self.sys_actor.parameters())

    
        self.optim_actor = torch.optim.Adam(self.sys_actor.parameters(), lr = self.lr_actor, weight_decay=self.l2)
        self.optim_critic = torch.optim.Adam(params_critic, lr = self.lr, weight_decay=self.l2)        
        self.optim_alpha = torch.optim.Adam([self.log_alpha], lr=self.lr_alpha)

    def train(self, data):

        self.step += 1
        w_util = self.w_util

        state = data['state'].to(device=self.device, non_blocking=True)
        obs = data['obs'].to(device=self.device, non_blocking=True)
        actions = data['actions'].to(device=self.device, non_blocking=True)
        reward = data['reward'].to(device=self.device, non_blocking=True)
        valid = data['valid'].to(device=self.device, non_blocking=True)
        avail_actions = data['avail_actions'].to(device=self.device, non_blocking=True)
        actions_onehot = self.one_hot(actions,self.n_actions)
 
        n_batch = obs.shape[0]
        T = obs.shape[1]
        alpha = torch.exp(self.log_alpha.detach())
        valid_rate = torch.mean(valid.float())

        if self.agent_id:
            agent_ids = torch.eye(self.n_agents,device=obs.device)
            agent_ids = agent_ids.reshape((1,)*(obs.ndim-2)+agent_ids.shape)            
            agent_ids = agent_ids.expand(obs.shape[:-2]+(-1,-1))
            obs = torch.cat([obs,agent_ids],-1)
        if self.last_action:
            last_actions = torch.zeros_like(actions_onehot)
            last_actions[:,1:] = actions_onehot[:,:-1]
            obs = torch.cat([obs,last_actions],-1)

        hiddens1 = self.sys_critic1.init_hiddens(n_batch)
        hiddens1_tar = self.sys_critic1_tar.init_hiddens(n_batch)
        hiddens2 = self.sys_critic2.init_hiddens(n_batch)
        hiddens2_tar = self.sys_critic2_tar.init_hiddens(n_batch)
        hiddens_actor = self.sys_actor.init_hiddens(n_batch)
        

        Q1s = []
        Q2s = []
        Q1s_tar = []
        Q2s_tar = []        
        ps = []
        
        

        for i in range(T):
            
            Q1, hiddens1 = self.sys_critic1.forward(obs[:,i], avail_actions[:,i], hiddens1)
            Q2, hiddens2 = self.sys_critic2.forward(obs[:,i], avail_actions[:,i], hiddens2)
            p, hiddens_actor = self.sys_actor.forward(obs[:,i], avail_actions[:,i], hiddens_actor)
            
            #with torch.no_grad():
                
            Q1_tar, hiddens1_tar = self.sys_critic1_tar.forward(obs[:,i], avail_actions[:,i], hiddens1_tar)
            Q2_tar, hiddens2_tar = self.sys_critic2_tar.forward(obs[:,i], avail_actions[:,i], hiddens2_tar)
            
            Q1s.append(Q1)
            Q2s.append(Q2)
            Q1s_tar.append(Q1_tar)
            Q2s_tar.append(Q2_tar)
            ps.append(p)

        Q1s = torch.stack(Q1s,1)
        Q2s = torch.stack(Q2s,1)
        Q1s_tar = torch.stack(Q1s_tar,1)
        Q2s_tar = torch.stack(Q2s_tar,1)

        ps = torch.stack(ps,1)
        ps[valid == 0] = 0
        
        log_ps = torch.log(ps + 1e-38)
        log_ps[valid == 0] = 0
        #log_ps[avail_actions == 0] = 0
        entropy = -torch.sum(ps*log_ps, -1)
        

        Q1s[valid == 0] = 0
        Q2s[valid == 0] = 0
        Q1s_tar[valid == 0] = 0
        Q2s_tar[valid == 0] = 0

        q1s = self.gather_end(Q1s,actions)
        q2s = self.gather_end(Q2s,actions)

        q1s_tot = self.mix_net1(q1s, state)
        q2s_tot = self.mix_net2(q2s, state)
        
        q1s_tot[valid == 0] = 0
        q2s_tot[valid == 0] = 0
        
        V1s = torch.sum(ps * Q1s.detach(), -1)
        V2s = torch.sum(ps * Q2s.detach(), -1)
        
        V1s_tar = torch.sum(ps.detach() * Q1s_tar, -1)
        V2s_tar = torch.sum(ps.detach() * Q2s_tar, -1)
        
        self.mix_net1.requires_grad_(False)
        self.mix_net2.requires_grad_(False)
        
        V1s_tot = self.mix_net1.forward(V1s, state)
        V2s_tot = self.mix_net2.forward(V2s, state)

        self.mix_net1.requires_grad_(True)
        self.mix_net2.requires_grad_(True)

        V1s_tot_tar = self.mix_net1_tar.forward(V1s_tar, state)
        V2s_tot_tar = self.mix_net2_tar.forward(V2s_tar, state)
        
        Vs_tot = torch.min(torch.stack([V1s_tot,V2s_tot],-1), -1)[0]
        Vs_tot_tar = torch.min(torch.stack([V1s_tot_tar,V2s_tot_tar],-1), -1)[0]

        Vs_tot[valid == 0] = 0
        Vs_tot_tar[valid == 0] = 0

        

        alpha_entropy = torch.sum(alpha * entropy, -1, keepdim=True)     
        Ves_tot = Vs_tot + alpha_entropy
        Ves_tot_tar = Vs_tot_tar + alpha_entropy.detach()
        
        # train actor        
        loss_actor = - torch.mean(Ves_tot)/valid_rate
        self.optim_actor.zero_grad()
        loss_actor.backward()
        torch.nn.utils.clip_grad_norm_(self.params_actor, self.args.grad_norm_clip)
        self.optim_actor.step()
               
        
                        
        qs_star = torch.zeros_like(q1s_tot)
        qs_star += reward.unsqueeze(-1)

        if self.maximum_entropy:
            sys_v_tar = Ves_tot_tar
        else:
            sys_v_tar = Vs_tot_tar

        qs_star[:,:-1] += self.gamma * (sys_v_tar[:,1:])
        
        loss1 = F.mse_loss(q1s_tot,qs_star)/valid_rate
        loss2 = F.mse_loss(q2s_tot,qs_star)/valid_rate        
        loss = loss1+loss2
        self.optim_critic.zero_grad()        
        loss.backward()  
        torch.nn.utils.clip_grad_norm_(self.params_critic, self.args.grad_norm_clip)      
        self.optim_critic.step()        
        self.update_target()
        
        loss_alpha = self.log_alpha*(entropy.detach()-self.entropy_tar)
        loss_alpha[valid ==0] = 0
        loss_alpha = torch.mean(loss_alpha)/valid_rate

        self.optim_alpha.zero_grad()
        loss_alpha.backward()
        self.optim_alpha.step()
        
        m_loss = loss/2
        m_alpha = alpha.mean()    
        m_v = torch.mean(V1s.detach())/valid_rate        
        m_v_total = torch.mean(Vs_tot.detach())/valid_rate
        m_entropy = torch.mean(entropy.detach())/valid_rate        
        m_max_p = torch.mean(torch.max(ps.detach(),-1)[0])/valid_rate
        
        w_util.WriteScalar('train/loss', m_loss.item())
        w_util.WriteScalar('train/v', m_v.item())
        w_util.WriteScalar('train/v_total', m_v_total.item())
        w_util.WriteScalar('train/entropy', m_entropy.item())
        w_util.WriteScalar('train/alpha', m_alpha.item())        
        w_util.WriteScalar('train/max_p', m_max_p.item())
        
        return m_loss.item()

    def state_dict(self):
        state_dict = {}
        state_dict['critic1'] = self.sys_critic1.state_dict()
        state_dict['critic2'] = self.sys_critic2.state_dict()
        state_dict['critic1_tar'] = self.sys_critic1_tar.state_dict()
        state_dict['critic2_tar'] = self.sys_critic2_tar.state_dict()
        state_dict['mix_net1'] = self.mix_net1.state_dict()
        state_dict['mix_net2'] = self.mix_net2.state_dict()
        state_dict['mix_net1_tar'] = self.mix_net1_tar.state_dict()
        state_dict['mix_net2_tar'] = self.mix_net2_tar.state_dict()
        state_dict['actor'] = self.sys_actor.state_dict()
        state_dict['log_alpha'] = self.log_alpha.detach()
        state_dict['optim_critic'] = self.optim_critic.state_dict()
        state_dict['optim_actor'] = self.optim_actor.state_dict()
        state_dict['optim_alpha'] = self.optim_alpha.state_dict()
        return state_dict        

    def load_state_dict(self, state_dict):
        self.sys_critic1.load_state_dict(state_dict['critic1'])
        self.sys_critic2.load_state_dict(state_dict['critic2'])
        self.sys_critic1_tar.load_state_dict(state_dict['critic1_tar'])
        self.sys_critic2_tar.load_state_dict(state_dict['critic2_tar'])
        self.mix_net1.load_state_dict(state_dict['mix_net1'])
        self.mix_net2.load_state_dict(state_dict['mix_net2'])
        self.mix_net1_tar.load_state_dict(state_dict['mix_net1_tar'])
        self.mix_net2_tar.load_state_dict(state_dict['mix_net2_tar'])
        self.sys_actor.load_state_dict(state_dict['actor'])
        with torch.no_grad():
            self.log_alpha.copy_(state_dict['log_alpha'])
        self.optim_critic.load_state_dict(state_dict['optim_critic'])
        self.optim_actor.load_state_dict(state_dict['optim_actor'])
        self.optim_alpha.load_state_dict(state_dict['optim_alpha'])

        
    def gather_end(self, input, index):
        index = torch.unsqueeze(index,-1).to(dtype=torch.int64)
        return torch.gather(input, input.ndim -1, index).squeeze(-1)

    def one_hot(self, tensor, n_classes):
        return F.one_hot(tensor.to(dtype=torch.int64), n_classes).to(dtype=torch.float32)

    def update_target(self):
        if self.target_update >=1:
            if self.step % self.target_update == 0:
                self._sync_target()
        else:
            def soft_update(src,tar):
                cur_state = src.state_dict()
                tar_state = tar.state_dict()
                for key in tar_state:                
                    v_tar = tar_state[key]
                    v_cur = cur_state[key]
                    v_tar += self.target_update*(v_cur-v_tar).detach()
            soft_update(self.sys_critic1,self.sys_critic1_tar)
            soft_update(self.sys_critic2,self.sys_critic2_tar)
            soft_update(self.mix_net1,self.mix_net1_tar)
            soft_update(self.mix_net2,self.mix_net2_tar)
    
    def _sync_target(self):
        self.sys_critic1_tar.load_state_dict(self.sys_critic1.state_dict())
        self.sys_critic2_tar.load_state_dict(self.sys_critic2.state_dict())
        self.mix_net1_tar.load_state_dict(self.mix_net1.state_dict())
        self.mix_net2_tar.load_state_dict(self.mix_net2.state_dict())
 
    def _valid_mask(self, input, valid):
        input *= valid.view(list(valid.shape) + [1] * (input.ndim - valid.ndim))
        return input
        
class Experiment:
    def __init__(self, args):        
        self.args = args


    def save(self):

        run_state = {}                
        run_state['episode'] = self.e
        run_state['step'] = self.step
        run_state['best_win_rate'] = self.best_win_rate
        run_state['learner'] = self.learner.state_dict()
        run_state['buffer'] = self.buffer.state_dict()
        torch.save(run_state, self.path_checkpt)        

    def load(self):
        run_state = torch.load(self.path_checkpt)
        self.e = run_state['episode']
        self.step = run_state['step']
        self.best_win_rate = run_state['best_win_rate']
        self.learner.load_state_dict(run_state['learner'])                
        self.buffer.load_state_dict(run_state['buffer'])
        self.result = np.load(self.path_result)

    def start(self):
        args = self.args

        path_checkpt = 'checkpoints'
        path_result = 'results'
        path_model = 'models'
        if not os.path.exists(path_checkpt):
            os.mkdir(path_checkpt)
        if not os.path.exists(path_result):
            os.mkdir(path_result)
        if not os.path.exists(path_model):
            os.mkdir(path_model)
        path_checkpt = os.path.join(path_checkpt, args.run_name + '.tar')
        path_result = os.path.join(path_result, args.run_name + '.npy')
        path_model = os.path.join(path_model, args.run_name + '.tar')
            
        # env = StarCraft2Env(map_name=args.map_name, window_size_x=640, window_size_y=480)
        env = simple_reference_v3.parallel_env( local_ratio=args.local_ratio, max_cycles=args.max_cycles, continuous_actions=args.continuous_actions)
        print(env)
        env.reset()

        env_info = {
            "n_agents": args.N,
            "n_actions": 5,  # no_action, move_left, move_right, move_down, move_up
            "obs_shape": 21,
            "state_shape": 42,
            "episode_limit": args.max_cycles
        }
        # env_info = env.get_env_info()

        args.n_agents = env_info["n_agents"]
        args.n_actions = env_info["n_actions"]
        args.obs_dim = env_info['obs_shape']
        args.input_dim = args.obs_dim
        if args.agent_id:
            args.input_dim += args.n_agents
        if args.last_action:        
            args.input_dim += args.n_actions        
        args.state_dim = env_info['state_shape']
        args.episode_limit = env_info['episode_limit']
        print(f"Calculated input_dim: {args.input_dim}")

        
        writter = SummaryWriter('runs/'+ args.run_name + '/' + datetime.datetime.now().strftime('%Y-%m-%d,%H%M%S'))
        w_util = WritterUtil(writter,args)
        learner = Learner(w_util,args)               
        ctrler = Controller(learner.sys_actor,args)
        runner = Runner(env,ctrler,args)
                
        scheme = {}
        n_agents = args.n_agents
        scheme['obs'] = {'shape':(n_agents, args.obs_dim), 'dtype': torch.float32}
        scheme['valid'] = {'shape':(), 'dtype': torch.int32}
        scheme['actions'] = {'shape':(n_agents,), 'dtype': torch.int32}
        scheme['avail_actions'] = {'shape':(n_agents, args.n_actions), 'dtype': torch.int32}
        scheme['reward'] = {'shape':(), 'dtype': torch.float32}
        scheme['state'] = {'shape':(args.state_dim,), 'dtype': torch.float32}

        buffer = EpisodeBuffer(scheme, args)
        result = np.zeros((3, args.n_steps // args.test_every_step))

        self.e = 0
        self.step = 0
        self.best_win_rate = 0                   
        self.path_checkpt = path_checkpt
        self.path_result = path_result
        self.path_model = path_model      
        self.env = env        
        self.writter = writter
        self.w_util = w_util
        self.ctrler = ctrler
        self.runner = runner
        self.learner = learner
        self.buffer = buffer
        self.result = result

        if args.continue_run:
            self.load()
                    
        
    def run(self):
        
        args = self.args
        buffer = self.buffer        
        runner = self.runner
        learner = self.learner
        w_util = self.w_util
        
        while self.step < args.n_steps:
        #for self.e in range(self.e, args.n_episodes+1):
            self.e += 1            
            data, episode_reward, win_tag, step =  runner.run()
            old_step = self.step
            self.step += step                   
            w_util.set_step(self.step)            
            w_util.WriteScalar('train/reward', episode_reward)
            print("Episode {}, step {}, win = {}, reward = {}".format(self.e, self.step, win_tag, episode_reward))
            buffer.add_episode(data)
            data = buffer.sample(args.n_batch, args.top_n)
            if data:
                loss = learner.train(data)                        
                        
            if self.step // args.test_every_step != old_step // args.test_every_step:
                self.test_model()            

            if args.save_every and self.e % args.save_every == 0:                
                self.save()

        self.env.close()

    def test_model(self):
        args = self.args
        w_util = self.w_util
        runner = self.runner
        result = self.result

        win_count = 0
        reward_avg = 0
        for i in range(args.test_count):
            _, episode_reward, win_tag, _ =  runner.run(test_mode=True)
            if win_tag:
                win_count += 1
            reward_avg += episode_reward                
        win_rate = win_count/args.test_count        
        reward_avg /= args.test_count
        w_util.WriteScalar('test/reward', reward_avg)
        w_util.WriteScalar('test/win_rate', win_rate)
        result[:, self.step // args.test_every_step - 1] = [self.e, self.step, win_rate]
        np.save(self.path_result, self.result)
        if win_rate >= self.best_win_rate:
            self.best_win_rate = win_rate
            torch.save(self.learner.sys_actor.state_dict(), self.path_model)            
        print('Test reward = {}, win_rate = {}'.format(reward_avg, win_rate))
        
class Runner:
    def __init__(self, env, controller, args):
        """
        Initialize the Runner.
        Args:
            env: The PettingZoo environment.
            controller: The controller that decides agent actions.
            args: Additional arguments, including max_cycles and number of agents (N).
        """
        self.controller = controller
        self.env = env
        self.args = args

    def run(self, test_mode=False):
        """
        Run a single episode in the PettingZoo environment.

        Args:
            test_mode (bool): If True, disables exploration. Defaults to False.

        Returns:
            tuple: (data, episode_reward, win_tag, steps)
        """
        print("Resetting environment...")
        observations, infos = self.env.reset()

        self.controller.new_episode()
        data = {
            'state': [],
            'obs': [],
            'valid': [],
            'actions': [],
            'avail_actions': [],
            'reward': []
        }
        episode_reward = 0
        steps = 0

        while steps < self.args.max_cycles:
            steps += 1
            
            # Ensure environment state is valid
            assert hasattr(self.env, 'state'), "Environment does not have a 'state()' method."
            state = self.env.state()

            # Validate observations dictionary
            assert isinstance(observations, dict), "Observations must be a dictionary."
            assert len(observations) == len(self.env.agents), "Mismatch between agents and observations."

            # Convert observations dict to list in consistent order
            obs_list = [observations[agent_id] for agent_id in self.env.agents]

            # Validate available actions
            avail_actions_list = [[1] * 5 for _ in range(self.args.N)]  # Example: 5 actions per agent
            assert len(avail_actions_list) == self.args.N, "Available actions list size mismatch."

            explore = not test_mode

            # Get actions from controller
            actions_array = self.controller.get_actions(obs_list, avail_actions_list, explore)
            assert len(actions_array) == len(self.env.agents), "Mismatch between actions and agents."

            # Convert actions array to dict for PettingZoo environment
            actions_dict = {agent_id: action for agent_id, action in zip(self.env.agents, actions_array)}

            # Step the environment
            try:
                observations, rewards, terminations, truncations, infos = self.env.step(actions_dict)
            except Exception as e:
                print(f"Error during environment step: {e}")
                break

            # Validate rewards dictionary
            assert isinstance(rewards, dict), "Rewards must be a dictionary."

            # Calculate total reward for this step
            step_reward = sum(rewards.values())
            episode_reward += step_reward

            # Store transition data
            data['state'].append(state)
            data['obs'].append(obs_list)
            data['valid'].append(1)  # Assume all steps are valid
            data['actions'].append(actions_array)
            data['avail_actions'].append(avail_actions_list)
            data['reward'].append(step_reward)

            # Check if all agents are done
            if all(terminations.values()) or all(truncations.values()):
                break

        # Define win condition placeholder
        win_tag = episode_reward > 0  # Modify based on environment-specific criteria

        return data, episode_reward, win_tag, steps

class Args:
    pass


if __name__ == "__main__":

    
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    config_path='config_reference.json'
        
    with open(config_path, 'r') as f:
        config = json.load(f)
    args = Args()
    args.__dict__.update(config)

    args.continue_run = False
    argv = sys.argv
    if len(argv)>1:
        if argv[1] == '-c':  ##continue
            args.continue_run = True

    experiment = Experiment(args)
    experiment.start()
    experiment.run()
# Out:
# simple_reference_v3
# Calculated input_dim: 23
# Resetting environment...
# Episode 1, step 75, win = False, reward = -288.01432849850306
# Resetting environment...
# Episode 2, step 150, win = False, reward = -142.1535379728103
# Resetting environment...
# Episode 3, step 225, win = False, reward = -135.1270850043955
# Resetting environment...
# Episode 4, step 300, win = False, reward = -145.24494312781715
# Resetting environment...
# Episode 5, step 375, win = False, reward = -190.4201828004041
# Resetting environment...
# Episode 6, step 450, win = False, reward = -302.21583289685685
# Resetting environment...
# Episode 7, step 525, win = False, reward = -218.045845509648
# Resetting environment...
# Episode 8, step 600, win = False, reward = -206.38626844102592
# Resetting environment...
# Episode 9, step 675, win = False, reward = -180.96033648925334
# Resetting environment...
# Episode 10, step 750, win = False, reward = -214.77717370651763
# Resetting environment...
# Episode 11, step 825, win = False, reward = -249.8148485365276
# Resetting environment...
# Episode 12, step 900, win = False, reward = -163.00237465084442
# Resetting environment...
# Episode 13, step 975, win = False, reward = -133.90784394069635
# Resetting environment...
# Episode 14, step 1050, win = False, reward = -92.17497633295781
# Resetting environment...
# Episode 15, step 1125, win = False, reward = -188.21718018871974
# Resetting environment...
# Episode 16, step 1200, win = False, reward = -270.9270849978556
# Resetting environment...
# Episode 17, step 1275, win = False, reward = -86.8454574950573
# Resetting environment...
# Episode 18, step 1350, win = False, reward = -187.30552835397208
# Resetting environment...
# Episode 19, step 1425, win = False, reward = -241.9008325407416
# Resetting environment...
# Episode 20, step 1500, win = False, reward = -271.9155017793476
# Resetting environment...
# Episode 21, step 1575, win = False, reward = -183.95427634466415
# Resetting environment...
# Episode 22, step 1650, win = False, reward = -289.3874498102206
# Resetting environment...
# Episode 23, step 1725, win = False, reward = -174.9650754081334
# Resetting environment...
# Episode 24, step 1800, win = False, reward = -180.4087694441102
# Resetting environment...
# Episode 25, step 1875, win = False, reward = -185.50709332400635
# Resetting environment...
# Episode 26, step 1950, win = False, reward = -176.4697803371692
# Resetting environment...
# Episode 27, step 2025, win = False, reward = -102.63427318551985
# Resetting environment...
# Episode 28, step 2100, win = False, reward = -84.1130014134242
# Resetting environment...
# Episode 29, step 2175, win = False, reward = -170.9466526553524
# Resetting environment...
# Episode 30, step 2250, win = False, reward = -145.68752355473598
# Resetting environment...
# Episode 31, step 2325, win = False, reward = -142.79507710801775
# Resetting environment...
# Episode 32, step 2400, win = False, reward = -261.56976465659693
# Resetting environment...
# Episode 33, step 2475, win = False, reward = -257.90367299236624
# Resetting environment...
# Episode 34, step 2550, win = False, reward = -260.71589640757327
# Resetting environment...
# Episode 35, step 2625, win = False, reward = -118.21145145840882
# Resetting environment...
# Episode 36, step 2700, win = False, reward = -302.3945905936961
# Resetting environment...
# Episode 37, step 2775, win = False, reward = -110.74215259239588
# Resetting environment...
# Episode 38, step 2850, win = False, reward = -157.0011762294849
# Resetting environment...
# Episode 39, step 2925, win = False, reward = -271.08099917813297
# Resetting environment...
# Episode 40, step 3000, win = False, reward = -165.78833583696345
# Resetting environment...
# Episode 41, step 3075, win = False, reward = -182.3505924314572
# Resetting environment...
# Episode 42, step 3150, win = False, reward = -231.10974242019003
# Resetting environment...
# Episode 43, step 3225, win = False, reward = -261.39618199039444
# Resetting environment...
# Episode 44, step 3300, win = False, reward = -130.7014885103113
# Resetting environment...
# Episode 45, step 3375, win = False, reward = -340.143714237853
# Resetting environment...
# Episode 46, step 3450, win = False, reward = -221.74894614677717
# Resetting environment...
# Episode 47, step 3525, win = False, reward = -200.15012922111828
# Resetting environment...
# Episode 48, step 3600, win = False, reward = -140.5393671754851
# Resetting environment...
# Episode 49, step 3675, win = False, reward = -153.61431545228356
# Resetting environment...
# Episode 50, step 3750, win = False, reward = -242.38270319890268
# Resetting environment...
# Episode 51, step 3825, win = False, reward = -166.02035960238572
# Resetting environment...
# Episode 52, step 3900, win = False, reward = -217.4427194491018
# Resetting environment...
# Episode 53, step 3975, win = False, reward = -306.1748242830048
# Resetting environment...
# Episode 54, step 4050, win = False, reward = -255.3492758935814
# Resetting environment...
# Episode 55, step 4125, win = False, reward = -84.53667697760632
# Resetting environment...
# Episode 56, step 4200, win = False, reward = -148.93721413684
# Resetting environment...
# Episode 57, step 4275, win = False, reward = -363.14356981256896
# Resetting environment...
# Episode 58, step 4350, win = False, reward = -308.47416198150586
# Resetting environment...
# Episode 59, step 4425, win = False, reward = -222.25275487917253
# Resetting environment...
# Episode 60, step 4500, win = False, reward = -267.7017206155782
# Resetting environment...
# Episode 61, step 4575, win = False, reward = -161.55106062619814
# Resetting environment...
# Episode 62, step 4650, win = False, reward = -156.95893812723583
# Resetting environment...
# Episode 63, step 4725, win = False, reward = -119.0124987428911
# Resetting environment...
# Episode 64, step 4800, win = False, reward = -346.8645326120546
# Resetting environment...
# Episode 65, step 4875, win = False, reward = -118.59308264881766
# Resetting environment...
# Episode 66, step 4950, win = False, reward = -305.62161029771585
# Resetting environment...
# Episode 67, step 5025, win = False, reward = -300.51480604132064
# Resetting environment...
# Episode 68, step 5100, win = False, reward = -289.2580130739051
# Resetting environment...
# Episode 69, step 5175, win = False, reward = -292.13202918185976
# Resetting environment...
# Episode 70, step 5250, win = False, reward = -183.4500481871925
# Resetting environment...
# Episode 71, step 5325, win = False, reward = -213.92699613414493
# Resetting environment...
# Episode 72, step 5400, win = False, reward = -163.68671812170302
# Resetting environment...
# Episode 73, step 5475, win = False, reward = -243.95090248043948
# Resetting environment...
# Episode 74, step 5550, win = False, reward = -234.6941364861843
# Resetting environment...
# Episode 75, step 5625, win = False, reward = -102.34096789741893
# Resetting environment...
# Episode 76, step 5700, win = False, reward = -170.74615570764286
# Resetting environment...
# Episode 77, step 5775, win = False, reward = -126.51614937462686
# Resetting environment...
# Episode 78, step 5850, win = False, reward = -155.32436189158628
# Resetting environment...
# Episode 79, step 5925, win = False, reward = -370.43029604163075
# Resetting environment...
# Episode 80, step 6000, win = False, reward = -142.7051849135162
# Resetting environment...
# Episode 81, step 6075, win = False, reward = -249.91636141401253
# Resetting environment...
# Episode 82, step 6150, win = False, reward = -206.4759634687904
# Resetting environment...
# Episode 83, step 6225, win = False, reward = -144.47318784319882
# Resetting environment...
# Episode 84, step 6300, win = False, reward = -217.7139274282373
# Resetting environment...
# Episode 85, step 6375, win = False, reward = -158.97062985130702
# Resetting environment...
# Episode 86, step 6450, win = False, reward = -186.25654699996494
# Resetting environment...
# Episode 87, step 6525, win = False, reward = -218.92532805170632
# Resetting environment...
# Episode 88, step 6600, win = False, reward = -190.25753992538185
# Resetting environment...
# Episode 89, step 6675, win = False, reward = -180.9013378909226
# Resetting environment...
# Episode 90, step 6750, win = False, reward = -228.44892170184343
# Resetting environment...
# Episode 91, step 6825, win = False, reward = -188.20889007405012
# Resetting environment...
# Episode 92, step 6900, win = False, reward = -207.46256810580294
# Resetting environment...
# Episode 93, step 6975, win = False, reward = -141.71446718478907
# Resetting environment...
# Episode 94, step 7050, win = False, reward = -262.3289116383777
# Resetting environment...
# Episode 95, step 7125, win = False, reward = -138.02103665707477
# Resetting environment...
# Episode 96, step 7200, win = False, reward = -377.55083825627315
# Resetting environment...
# Episode 97, step 7275, win = False, reward = -306.92072043826715
# Resetting environment...
# Episode 98, step 7350, win = False, reward = -193.28350255854758
# Resetting environment...
# Episode 99, step 7425, win = False, reward = -212.43170376666168
# Resetting environment...
# Episode 100, step 7500, win = False, reward = -363.65120310132596
# Resetting environment...
# Episode 101, step 7575, win = False, reward = -175.4716820131153
# Resetting environment...
# Episode 102, step 7650, win = False, reward = -529.1405006374782
# Resetting environment...
# Episode 103, step 7725, win = False, reward = -225.32430701317915
# Resetting environment...
# Episode 104, step 7800, win = False, reward = -163.20135441471004
# Resetting environment...
# Episode 105, step 7875, win = False, reward = -327.0101632789752
# Resetting environment...
# Episode 106, step 7950, win = False, reward = -353.2766311023712
# Resetting environment...
# Episode 107, step 8025, win = False, reward = -180.71508368080055
# Resetting environment...
# Episode 108, step 8100, win = False, reward = -199.2057316378451
# Resetting environment...
# Episode 109, step 8175, win = False, reward = -257.22364638201515
# Resetting environment...
# Episode 110, step 8250, win = False, reward = -312.31891933494603
# Resetting environment...
# Episode 111, step 8325, win = False, reward = -167.49527587881485
# Resetting environment...
# Episode 112, step 8400, win = False, reward = -245.3276631443647
# Resetting environment...
# Episode 113, step 8475, win = False, reward = -201.04838683773136
# Resetting environment...
# Episode 114, step 8550, win = False, reward = -352.4778278676678
# Resetting environment...
# Episode 115, step 8625, win = False, reward = -250.03329889187955
# Resetting environment...
# Episode 116, step 8700, win = False, reward = -171.24133548159838
# Resetting environment...
# Episode 117, step 8775, win = False, reward = -250.29236433842644
# Resetting environment...
# Episode 118, step 8850, win = False, reward = -253.15220632866655
# Resetting environment...
# Episode 119, step 8925, win = False, reward = -194.46044060835723
# Resetting environment...
# Episode 120, step 9000, win = False, reward = -216.98380985585231
# Resetting environment...
# Episode 121, step 9075, win = False, reward = -207.792847415633
# Resetting environment...
# Episode 122, step 9150, win = False, reward = -248.8650465632077
# Resetting environment...
# Episode 123, step 9225, win = False, reward = -522.5853538247142
# Resetting environment...
# Episode 124, step 9300, win = False, reward = -219.69869762192917
# Resetting environment...
# Episode 125, step 9375, win = False, reward = -266.4250935401288
# Resetting environment...
# Episode 126, step 9450, win = False, reward = -537.6245557211016
# Resetting environment...
# Episode 127, step 9525, win = False, reward = -378.1600609320415
# Resetting environment...
# Episode 128, step 9600, win = False, reward = -361.7329689248057
# Resetting environment...
# Episode 129, step 9675, win = False, reward = -256.1611039206105
# Resetting environment...
# Episode 130, step 9750, win = False, reward = -208.65199744559501
# Resetting environment...
# Episode 131, step 9825, win = False, reward = -129.00076818176555
# Resetting environment...
# Episode 132, step 9900, win = False, reward = -271.76111034686613
# Resetting environment...
# Episode 133, step 9975, win = False, reward = -637.2993134309768
# Resetting environment...
# Episode 134, step 10050, win = False, reward = -314.1438999325804
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Test reward = -959.8181062429196, win_rate = 0.0
# Resetting environment...
# Episode 135, step 10125, win = False, reward = -184.76009778514538
# Resetting environment...
# Episode 136, step 10200, win = False, reward = -443.3054760301542
# Resetting environment...
# Episode 137, step 10275, win = False, reward = -144.4216539164649
# Resetting environment...
# Episode 138, step 10350, win = False, reward = -217.78580394843752
# Resetting environment...
# Episode 139, step 10425, win = False, reward = -445.46723437488885
# Resetting environment...
# Episode 140, step 10500, win = False, reward = -315.901724724789
# Resetting environment...
# Episode 141, step 10575, win = False, reward = -278.13923022654996
# Resetting environment...
# Episode 142, step 10650, win = False, reward = -143.1134544888994
# Resetting environment...
# Episode 143, step 10725, win = False, reward = -208.89896317831764
# Resetting environment...
# Episode 144, step 10800, win = False, reward = -338.52546177271176
# Resetting environment...
# Episode 145, step 10875, win = False, reward = -324.37043927930927
# Resetting environment...
# Episode 146, step 10950, win = False, reward = -314.1055867299176
# Resetting environment...
# Episode 147, step 11025, win = False, reward = -213.7176322679104
# Resetting environment...
# Episode 148, step 11100, win = False, reward = -192.37062041298893
# Resetting environment...
# Episode 149, step 11175, win = False, reward = -288.56005747125505
# Resetting environment...
# Episode 150, step 11250, win = False, reward = -373.20874212669787
# Resetting environment...
# Episode 151, step 11325, win = False, reward = -453.5105887892675
# Resetting environment...
# Episode 152, step 11400, win = False, reward = -293.00015808081366
# Resetting environment...
# Episode 153, step 11475, win = False, reward = -253.67701972354527
# Resetting environment...
# Episode 154, step 11550, win = False, reward = -235.32537188875926
# Resetting environment...
# Episode 155, step 11625, win = False, reward = -230.6278378108466
# Resetting environment...
# Episode 156, step 11700, win = False, reward = -263.68874228180704
# Resetting environment...
# Episode 157, step 11775, win = False, reward = -638.0229453637792
# Resetting environment...
# Episode 158, step 11850, win = False, reward = -150.85359373256043
# Resetting environment...
# Episode 159, step 11925, win = False, reward = -346.6474025123681
# Resetting environment...
# Episode 160, step 12000, win = False, reward = -224.71787750435234
# Resetting environment...
# Episode 161, step 12075, win = False, reward = -277.45863264517095
# Resetting environment...
# Episode 162, step 12150, win = False, reward = -229.56472221963108
# Resetting environment...
# Episode 163, step 12225, win = False, reward = -368.41246199421596
# Resetting environment...
# Episode 164, step 12300, win = False, reward = -232.76225883426181
# Resetting environment...
# Episode 165, step 12375, win = False, reward = -371.30058002569524
# Resetting environment...
# Episode 166, step 12450, win = False, reward = -373.0119707948945
# Resetting environment...
# Episode 167, step 12525, win = False, reward = -273.251410126678
# Resetting environment...
# Episode 168, step 12600, win = False, reward = -271.7808623571192
# Resetting environment...
# Episode 169, step 12675, win = False, reward = -173.40209404624514
# Resetting environment...
# Episode 170, step 12750, win = False, reward = -126.49053183774167
# Resetting environment...
# Episode 171, step 12825, win = False, reward = -460.22894881732236
# Resetting environment...
# Episode 172, step 12900, win = False, reward = -188.31043210676364
# Resetting environment...
# Episode 173, step 12975, win = False, reward = -326.65610247080957
# Resetting environment...
# Episode 174, step 13050, win = False, reward = -239.77500806374306
# Resetting environment...
# Episode 175, step 13125, win = False, reward = -303.88928506759567
# Resetting environment...
# Episode 176, step 13200, win = False, reward = -278.5615928783406
# Resetting environment...
# Episode 177, step 13275, win = False, reward = -393.21042869478515
# Resetting environment...
# Episode 178, step 13350, win = False, reward = -471.83241088211884
# Resetting environment...
# Episode 179, step 13425, win = False, reward = -365.02319627169294
# Resetting environment...
# Episode 180, step 13500, win = False, reward = -326.68048735086865
# Resetting environment...
# Episode 181, step 13575, win = False, reward = -213.11007836578685
# Resetting environment...
# Episode 182, step 13650, win = False, reward = -288.39041911699894
# Resetting environment...
# Episode 183, step 13725, win = False, reward = -325.24518950057313
# Resetting environment...
# Episode 184, step 13800, win = False, reward = -238.50818012983197
# Resetting environment...
# Episode 185, step 13875, win = False, reward = -261.1810526746484
# Resetting environment...
# Episode 186, step 13950, win = False, reward = -191.63965010346934
# Resetting environment...
# Episode 187, step 14025, win = False, reward = -112.8542338724565
# Resetting environment...
# Episode 188, step 14100, win = False, reward = -326.65905748973
# Resetting environment...
# Episode 189, step 14175, win = False, reward = -308.992972308824
# Resetting environment...
# Episode 190, step 14250, win = False, reward = -279.1579708123742
# Resetting environment...
# Episode 191, step 14325, win = False, reward = -68.89611709318307
# Resetting environment...
# Episode 192, step 14400, win = False, reward = -191.75028268467764
# Resetting environment...
# Episode 193, step 14475, win = False, reward = -251.15784018449148
# Resetting environment...
# Episode 194, step 14550, win = False, reward = -151.2764089034658
# Resetting environment...
# Episode 195, step 14625, win = False, reward = -207.3143735019797
# Resetting environment...
# Episode 196, step 14700, win = False, reward = -185.5514933754746
# Resetting environment...
# Episode 197, step 14775, win = False, reward = -226.70099400404987
# Resetting environment...
# Episode 198, step 14850, win = False, reward = -205.61290184069333
# Resetting environment...
# Episode 199, step 14925, win = False, reward = -174.3058193634656
# Resetting environment...
# Episode 200, step 15000, win = False, reward = -206.27332570531547
# Resetting environment...
# Episode 201, step 15075, win = False, reward = -141.15530087633948
# Resetting environment...
# Episode 202, step 15150, win = False, reward = -230.89777256560168
# Resetting environment...
# Episode 203, step 15225, win = False, reward = -210.54220410004734
# Resetting environment...
# Episode 204, step 15300, win = False, reward = -127.07027197564847
# Resetting environment...
# Episode 205, step 15375, win = False, reward = -162.67536706709035
# Resetting environment...
# Episode 206, step 15450, win = False, reward = -249.20194658278294
# Resetting environment...
# Episode 207, step 15525, win = False, reward = -208.76792187757232
# Resetting environment...
# Episode 208, step 15600, win = False, reward = -409.05143029733387
# Resetting environment...
# Episode 209, step 15675, win = False, reward = -286.50846015376646
# Resetting environment...
# Episode 210, step 15750, win = False, reward = -276.88179088730175
# Resetting environment...
# Episode 211, step 15825, win = False, reward = -254.28607902292865
# Resetting environment...
# Episode 212, step 15900, win = False, reward = -544.5016650734158
# Resetting environment...
# Episode 213, step 15975, win = False, reward = -260.4190501160958
# Resetting environment...
# Episode 214, step 16050, win = False, reward = -176.72729360746882
# Resetting environment...
# Episode 215, step 16125, win = False, reward = -449.0439896427031
# Resetting environment...
# Episode 216, step 16200, win = False, reward = -275.58412245909454
# Resetting environment...
# Episode 217, step 16275, win = False, reward = -344.59134149288195
# Resetting environment...
# Episode 218, step 16350, win = False, reward = -224.06483028652764
# Resetting environment...
# Episode 219, step 16425, win = False, reward = -297.2214791670925
# Resetting environment...
# Episode 220, step 16500, win = False, reward = -217.98186375818474
# Resetting environment...
# Episode 221, step 16575, win = False, reward = -470.9703106199255
# Resetting environment...
# Episode 222, step 16650, win = False, reward = -318.497598089385
# Resetting environment...
# Episode 223, step 16725, win = False, reward = -369.5739509353025
# Resetting environment...
# Episode 224, step 16800, win = False, reward = -235.78585775658985
# Resetting environment...
# Episode 225, step 16875, win = False, reward = -306.273458823818
# Resetting environment...
# Episode 226, step 16950, win = False, reward = -215.21889600109097
# Resetting environment...
# Episode 227, step 17025, win = False, reward = -327.14325844659686
# Resetting environment...
# Episode 228, step 17100, win = False, reward = -234.3772823588395
# Resetting environment...
# Episode 229, step 17175, win = False, reward = -165.3844510727785
# Resetting environment...
# Episode 230, step 17250, win = False, reward = -176.9287869308369
# Resetting environment...
# Episode 231, step 17325, win = False, reward = -311.4884024988906
# Resetting environment...
# Episode 232, step 17400, win = False, reward = -279.87991942741263
# Resetting environment...
# Episode 233, step 17475, win = False, reward = -235.08474628297628
# Resetting environment...
# Episode 234, step 17550, win = False, reward = -204.7087311238216
# Resetting environment...
# Episode 235, step 17625, win = False, reward = -278.2458120289654
# Resetting environment...
# Episode 236, step 17700, win = False, reward = -334.6580540985201
# Resetting environment...
# Episode 237, step 17775, win = False, reward = -254.60667001457747
# Resetting environment...
# Episode 238, step 17850, win = False, reward = -245.21727665092516
# Resetting environment...
# Episode 239, step 17925, win = False, reward = -320.5813645180516
# Resetting environment...
# Episode 240, step 18000, win = False, reward = -352.75603621527375
# Resetting environment...
# Episode 241, step 18075, win = False, reward = -448.9659793461175
# Resetting environment...
# Episode 242, step 18150, win = False, reward = -256.2795552629943
# Resetting environment...
# Episode 243, step 18225, win = False, reward = -118.08006485606533
# Resetting environment...
# Episode 244, step 18300, win = False, reward = -411.0401491290675
# Resetting environment...
# Episode 245, step 18375, win = False, reward = -295.3672146984803
# Resetting environment...
# Episode 246, step 18450, win = False, reward = -318.1912400116337
# Resetting environment...
# Episode 247, step 18525, win = False, reward = -190.29971957788308
# Resetting environment...
# Episode 248, step 18600, win = False, reward = -170.7943196975917
# Resetting environment...
# Episode 249, step 18675, win = False, reward = -189.29119259964992
# Resetting environment...
# Episode 250, step 18750, win = False, reward = -209.8778822581878
# Resetting environment...
# Episode 251, step 18825, win = False, reward = -253.39664632302328
# Resetting environment...
# Episode 252, step 18900, win = False, reward = -442.0159942892182
# Resetting environment...
# Episode 253, step 18975, win = False, reward = -308.16032223999815
# Resetting environment...
# Episode 254, step 19050, win = False, reward = -234.29575276152173
# Resetting environment...
# Episode 255, step 19125, win = False, reward = -279.5904620202504
# Resetting environment...
# Episode 256, step 19200, win = False, reward = -263.6098837841394
# Resetting environment...
# Episode 257, step 19275, win = False, reward = -163.77642902491914
# Resetting environment...
# Episode 258, step 19350, win = False, reward = -131.07804953050075
# Resetting environment...
# Episode 259, step 19425, win = False, reward = -84.77554724145428
# Resetting environment...
# Episode 260, step 19500, win = False, reward = -463.8522450526604
# Resetting environment...
# Episode 261, step 19575, win = False, reward = -403.5795119083999
# Resetting environment...
# Episode 262, step 19650, win = False, reward = -277.3503191917565
# Resetting environment...
# Episode 263, step 19725, win = False, reward = -192.40493281602568
# Resetting environment...
# Episode 264, step 19800, win = False, reward = -306.0288738071216
# Resetting environment...
# Episode 265, step 19875, win = False, reward = -272.91583027447217
# Resetting environment...
# Episode 266, step 19950, win = False, reward = -274.5150766827434
# Resetting environment...
# Episode 267, step 20025, win = False, reward = -218.06201958068235
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Test reward = -934.9017542948288, win_rate = 0.0
# Resetting environment...
# Episode 268, step 20100, win = False, reward = -112.49679818715529
# Resetting environment...
# Episode 269, step 20175, win = False, reward = -102.59881204409136
# Resetting environment...
# Episode 270, step 20250, win = False, reward = -204.25368314022464
# Resetting environment...
# Episode 271, step 20325, win = False, reward = -193.90484926174705
# Resetting environment...
# Episode 272, step 20400, win = False, reward = -193.42191125207043
# Resetting environment...
# Episode 273, step 20475, win = False, reward = -172.57469478799956
# Resetting environment...
# Episode 274, step 20550, win = False, reward = -297.99287779130555
# Resetting environment...
# Episode 275, step 20625, win = False, reward = -236.18437620484642
# Resetting environment...
# Episode 276, step 20700, win = False, reward = -143.99934420333108
# Resetting environment...
# Episode 277, step 20775, win = False, reward = -140.4786664573949
# Resetting environment...
# Episode 278, step 20850, win = False, reward = -374.91862493516584
# Resetting environment...
# Episode 279, step 20925, win = False, reward = -100.68629581756117
# Resetting environment...
# Episode 280, step 21000, win = False, reward = -209.91088949618947
# Resetting environment...
# Episode 281, step 21075, win = False, reward = -216.07328912469183
# Resetting environment...
# Episode 282, step 21150, win = False, reward = -320.65193378198285
# Resetting environment...
# Episode 283, step 21225, win = False, reward = -169.86336026697555
# Resetting environment...
# Episode 284, step 21300, win = False, reward = -218.64630079332122
# Resetting environment...
# Episode 285, step 21375, win = False, reward = -209.31191193892903
# Resetting environment...
# Episode 286, step 21450, win = False, reward = -278.51880734073063
# Resetting environment...
# Episode 287, step 21525, win = False, reward = -163.11230251714738
# Resetting environment...
# Episode 288, step 21600, win = False, reward = -300.3173539688444
# Resetting environment...
# Episode 289, step 21675, win = False, reward = -209.13345315538425
# Resetting environment...
# Episode 290, step 21750, win = False, reward = -413.6691135609823
# Resetting environment...
# Episode 291, step 21825, win = False, reward = -276.06038572761946
# Resetting environment...
# Episode 292, step 21900, win = False, reward = -190.070738093571
# Resetting environment...
# Episode 293, step 21975, win = False, reward = -217.00787443344095
# Resetting environment...
# Episode 294, step 22050, win = False, reward = -231.3190008182278
# Resetting environment...
# Episode 295, step 22125, win = False, reward = -333.2260146883121
# Resetting environment...
# Episode 296, step 22200, win = False, reward = -151.83806682334256
# Resetting environment...
# Episode 297, step 22275, win = False, reward = -227.58662933895897
# Resetting environment...
# Episode 298, step 22350, win = False, reward = -316.9392816555293
# Resetting environment...
# Episode 299, step 22425, win = False, reward = -201.66047689483275
# Resetting environment...
# Episode 300, step 22500, win = False, reward = -272.8854147822515
# Resetting environment...
# Episode 301, step 22575, win = False, reward = -518.8543755171708
# Resetting environment...
# Episode 302, step 22650, win = False, reward = -220.71190302453496
# Resetting environment...
# Episode 303, step 22725, win = False, reward = -112.1946433829824
# Resetting environment...
# Episode 304, step 22800, win = False, reward = -188.17431579707971
# Resetting environment...
# Episode 305, step 22875, win = False, reward = -122.99241677768413
# Resetting environment...
# Episode 306, step 22950, win = False, reward = -211.15567523118253
# Resetting environment...
# Episode 307, step 23025, win = False, reward = -180.93783389453455
# Resetting environment...
# Episode 308, step 23100, win = False, reward = -306.43551590297875
# Resetting environment...
# Episode 309, step 23175, win = False, reward = -202.04926684855764
# Resetting environment...
# Episode 310, step 23250, win = False, reward = -159.00134727573894
# Resetting environment...
# Episode 311, step 23325, win = False, reward = -295.0430421688435
# Resetting environment...
# Episode 312, step 23400, win = False, reward = -172.2186374722269
# Resetting environment...
# Episode 313, step 23475, win = False, reward = -277.4077404879291
# Resetting environment...
# Episode 314, step 23550, win = False, reward = -277.89300935648095
# Resetting environment...
# Episode 315, step 23625, win = False, reward = -201.09217872942583
# Resetting environment...
# Episode 316, step 23700, win = False, reward = -258.0860772269761
# Resetting environment...
# Episode 317, step 23775, win = False, reward = -268.89285859693297
# Resetting environment...
# Episode 318, step 23850, win = False, reward = -322.26600191126306
# Resetting environment...
# Episode 319, step 23925, win = False, reward = -182.9719413279485
# Resetting environment...
# Episode 320, step 24000, win = False, reward = -253.26299770991332
# Resetting environment...
# Episode 321, step 24075, win = False, reward = -219.29617271215568
# Resetting environment...
# Episode 322, step 24150, win = False, reward = -366.39062798136007
# Resetting environment...
# Episode 323, step 24225, win = False, reward = -272.2441320782407
# Resetting environment...
# Episode 324, step 24300, win = False, reward = -255.97735479242766
# Resetting environment...
# Episode 325, step 24375, win = False, reward = -140.00999718560283
# Resetting environment...
# Episode 326, step 24450, win = False, reward = -186.29448879264314
# Resetting environment...
# Episode 327, step 24525, win = False, reward = -239.9770878015813
# Resetting environment...
# Episode 328, step 24600, win = False, reward = -248.89378891181832
# Resetting environment...
# Episode 329, step 24675, win = False, reward = -128.20244033026532
# Resetting environment...
# Episode 330, step 24750, win = False, reward = -175.02904724144238
# Resetting environment...
# Episode 331, step 24825, win = False, reward = -387.99289181224856
# Resetting environment...
# Episode 332, step 24900, win = False, reward = -240.49250913167717
# Resetting environment...
# Episode 333, step 24975, win = False, reward = -166.14652295784725
# Resetting environment...
# Episode 334, step 25050, win = False, reward = -350.40324074443976
# Resetting environment...
# Episode 335, step 25125, win = False, reward = -212.32717003560157
# Resetting environment...
# Episode 336, step 25200, win = False, reward = -246.50191460246182
# Resetting environment...
# Episode 337, step 25275, win = False, reward = -189.70061812642217
# Resetting environment...
# Episode 338, step 25350, win = False, reward = -174.87976832091846
# Resetting environment...
# Episode 339, step 25425, win = False, reward = -98.14426022162733
# Resetting environment...
# Episode 340, step 25500, win = False, reward = -198.89748510633592
# Resetting environment...
# Episode 341, step 25575, win = False, reward = -199.88121572634003
# Resetting environment...
# Episode 342, step 25650, win = False, reward = -260.2740083986148
# Resetting environment...
# Episode 343, step 25725, win = False, reward = -449.20257546672724
# Resetting environment...
# Episode 344, step 25800, win = False, reward = -222.30334419105685
# Resetting environment...
# Episode 345, step 25875, win = False, reward = -345.70417157555363
# Resetting environment...
# Episode 346, step 25950, win = False, reward = -224.01007725643095
# Resetting environment...
# Episode 347, step 26025, win = False, reward = -157.29440556470522
# Resetting environment...
# Episode 348, step 26100, win = False, reward = -108.01585679075407
# Resetting environment...
# Episode 349, step 26175, win = False, reward = -216.08324794043713
# Resetting environment...
# Episode 350, step 26250, win = False, reward = -213.95580121844594
# Resetting environment...
# Episode 351, step 26325, win = False, reward = -106.06017413831516
# Resetting environment...
# Episode 352, step 26400, win = False, reward = -296.05876328605314
# Resetting environment...
# Episode 353, step 26475, win = False, reward = -124.00620516886836
# Resetting environment...
# Episode 354, step 26550, win = False, reward = -233.11328648584978
# Resetting environment...
# Episode 355, step 26625, win = False, reward = -127.81240538664737
# Resetting environment...
# Episode 356, step 26700, win = False, reward = -210.90404928590905
# Resetting environment...
# Episode 357, step 26775, win = False, reward = -178.6084385458363
# Resetting environment...
# Episode 358, step 26850, win = False, reward = -247.62975355229676
# Resetting environment...
# Episode 359, step 26925, win = False, reward = -315.19215769275877
# Resetting environment...
# Episode 360, step 27000, win = False, reward = -230.06764765208678
# Resetting environment...
# Episode 361, step 27075, win = False, reward = -247.44495767538461
# Resetting environment...
# Episode 362, step 27150, win = False, reward = -301.6104621254378
# Resetting environment...
# Episode 363, step 27225, win = False, reward = -262.1025914791643
# Resetting environment...
# Episode 364, step 27300, win = False, reward = -205.09029600289767
# Resetting environment...
# Episode 365, step 27375, win = False, reward = -301.6279396262767
# Resetting environment...
# Episode 366, step 27450, win = False, reward = -207.52296388525681
# Resetting environment...
# Episode 367, step 27525, win = False, reward = -192.4809024934666
# Resetting environment...
# Episode 368, step 27600, win = False, reward = -180.01373477476483
# Resetting environment...
# Episode 369, step 27675, win = False, reward = -196.3792836554268
# Resetting environment...
# Episode 370, step 27750, win = False, reward = -218.33115626622583
# Resetting environment...
# Episode 371, step 27825, win = False, reward = -247.091645677973
# Resetting environment...
# Episode 372, step 27900, win = False, reward = -253.2347435039201
# Resetting environment...
# Episode 373, step 27975, win = False, reward = -318.06953925833454
# Resetting environment...
# Episode 374, step 28050, win = False, reward = -355.7025285527559
# Resetting environment...
# Episode 375, step 28125, win = False, reward = -259.43136741134805
# Resetting environment...
# Episode 376, step 28200, win = False, reward = -253.16255963663716
# Resetting environment...
# Episode 377, step 28275, win = False, reward = -171.27058947159696
# Resetting environment...
# Episode 378, step 28350, win = False, reward = -237.1992587650272
# Resetting environment...
# Episode 379, step 28425, win = False, reward = -215.49348508259732
# Resetting environment...
# Episode 380, step 28500, win = False, reward = -135.91933153886558
# Resetting environment...
# Episode 381, step 28575, win = False, reward = -252.48308462239294
# Resetting environment...
# Episode 382, step 28650, win = False, reward = -108.20346171711829
# Resetting environment...
# Episode 383, step 28725, win = False, reward = -279.0790694681894
# Resetting environment...
# Episode 384, step 28800, win = False, reward = -213.16100955182185
# Resetting environment...
# Episode 385, step 28875, win = False, reward = -139.32350638667606
# Resetting environment...
# Episode 386, step 28950, win = False, reward = -320.10347183536777
# Resetting environment...
# Episode 387, step 29025, win = False, reward = -218.09526076039614
# Resetting environment...
# Episode 388, step 29100, win = False, reward = -103.74325408521749
# Resetting environment...
# Episode 389, step 29175, win = False, reward = -231.04884119333116
# Resetting environment...
# Episode 390, step 29250, win = False, reward = -196.98871036319397
# Resetting environment...
# Episode 391, step 29325, win = False, reward = -174.35843943893852
# Resetting environment...
# Episode 392, step 29400, win = False, reward = -327.32065179758735
# Resetting environment...
# Episode 393, step 29475, win = False, reward = -198.09144542070345
# Resetting environment...
# Episode 394, step 29550, win = False, reward = -262.745070294679
# Resetting environment...
# Episode 395, step 29625, win = False, reward = -205.558385009905
# Resetting environment...
# Episode 396, step 29700, win = False, reward = -347.09873735278705
# Resetting environment...
# Episode 397, step 29775, win = False, reward = -288.81182740004095
# Resetting environment...
# Episode 398, step 29850, win = False, reward = -242.6482558140615
# Resetting environment...
# Episode 399, step 29925, win = False, reward = -240.86608982224
# Resetting environment...
# Episode 400, step 30000, win = False, reward = -264.98455020160105
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Test reward = -461.42810671123567, win_rate = 0.0
# Resetting environment...
# Episode 401, step 30075, win = False, reward = -363.65050189247586
# Resetting environment...
# Episode 402, step 30150, win = False, reward = -176.23989435203544
# Resetting environment...
# Episode 403, step 30225, win = False, reward = -240.35678436021772
# Resetting environment...
# Episode 404, step 30300, win = False, reward = -285.41767775921096
# Resetting environment...
# Episode 405, step 30375, win = False, reward = -187.86271169555027
# Resetting environment...
# Episode 406, step 30450, win = False, reward = -210.59174129843348
# Resetting environment...
# Episode 407, step 30525, win = False, reward = -141.0997211606552
# Resetting environment...
# Episode 408, step 30600, win = False, reward = -227.110605838553
# Resetting environment...
# Episode 409, step 30675, win = False, reward = -355.79762759214594
# Resetting environment...
# Episode 410, step 30750, win = False, reward = -286.91804134333336
# Resetting environment...
# Episode 411, step 30825, win = False, reward = -286.102607097055
# Resetting environment...
# Episode 412, step 30900, win = False, reward = -205.8611914110763
# Resetting environment...
# Episode 413, step 30975, win = False, reward = -369.5909562214301
# Resetting environment...
# Episode 414, step 31050, win = False, reward = -170.9626800640264
# Resetting environment...
# Episode 415, step 31125, win = False, reward = -188.94947624110569
# Resetting environment...
# Episode 416, step 31200, win = False, reward = -316.4574145378589
# Resetting environment...
# Episode 417, step 31275, win = False, reward = -230.69766443219638
# Resetting environment...
# Episode 418, step 31350, win = False, reward = -110.2519247182371
# Resetting environment...
# Episode 419, step 31425, win = False, reward = -292.5234765501543
# Resetting environment...
# Episode 420, step 31500, win = False, reward = -208.17294206966844
# Resetting environment...
# Episode 421, step 31575, win = False, reward = -223.43594599336117
# Resetting environment...
# Episode 422, step 31650, win = False, reward = -492.10533336040504
# Resetting environment...
# Episode 423, step 31725, win = False, reward = -72.09421147386952
# Resetting environment...
# Episode 424, step 31800, win = False, reward = -173.35482104362742
# Resetting environment...
# Episode 425, step 31875, win = False, reward = -239.85164047630448
# Resetting environment...
# Episode 426, step 31950, win = False, reward = -166.74456471375163
# Resetting environment...
# Episode 427, step 32025, win = False, reward = -156.63596613902652
# Resetting environment...
# Episode 428, step 32100, win = False, reward = -113.56986299489583
# Resetting environment...
# Episode 429, step 32175, win = False, reward = -272.6002305160414
# Resetting environment...
# Episode 430, step 32250, win = False, reward = -188.9967953966655
# Resetting environment...
# Episode 431, step 32325, win = False, reward = -197.72707934713128
# Resetting environment...
# Episode 432, step 32400, win = False, reward = -194.45746941898238
# Resetting environment...
# Episode 433, step 32475, win = False, reward = -137.9121449804591
# Resetting environment...
# Episode 434, step 32550, win = False, reward = -209.52723876031922
# Resetting environment...
# Episode 435, step 32625, win = False, reward = -197.21624008114193
# Resetting environment...
# Episode 436, step 32700, win = False, reward = -282.74085435255074
# Resetting environment...
# Episode 437, step 32775, win = False, reward = -212.77079676136765
# Resetting environment...
# Episode 438, step 32850, win = False, reward = -201.18730744310864
# Resetting environment...
# Episode 439, step 32925, win = False, reward = -132.39504576867344
# Resetting environment...
# Episode 440, step 33000, win = False, reward = -206.80543962079446
# Resetting environment...
# Episode 441, step 33075, win = False, reward = -131.16938231999845
# Resetting environment...
# Episode 442, step 33150, win = False, reward = -154.29258557231384
# Resetting environment...
# Episode 443, step 33225, win = False, reward = -117.63096379208353
# Resetting environment...
# Episode 444, step 33300, win = False, reward = -170.78897253781062
# Resetting environment...
# Episode 445, step 33375, win = False, reward = -315.2031093132439
# Resetting environment...
# Episode 446, step 33450, win = False, reward = -210.27925837872496
# Resetting environment...
# Episode 447, step 33525, win = False, reward = -196.12532072567933
# Resetting environment...
# Episode 448, step 33600, win = False, reward = -146.23127022065526
# Resetting environment...
# Episode 449, step 33675, win = False, reward = -179.20171473494244
# Resetting environment...
# Episode 450, step 33750, win = False, reward = -221.40680170225784
# Resetting environment...
# Episode 451, step 33825, win = False, reward = -242.15778667932736
# Resetting environment...
# Episode 452, step 33900, win = False, reward = -203.645027601297
# Resetting environment...
# Episode 453, step 33975, win = False, reward = -211.40492657851402
# Resetting environment...
# Episode 454, step 34050, win = False, reward = -309.1070960649133
# Resetting environment...
# Episode 455, step 34125, win = False, reward = -165.39969550692396
# Resetting environment...
# Episode 456, step 34200, win = False, reward = -159.77382246800923
# Resetting environment...
# Episode 457, step 34275, win = False, reward = -198.07178904311814
# Resetting environment...
# Episode 458, step 34350, win = False, reward = -218.82127237756555
# Resetting environment...
# Episode 459, step 34425, win = False, reward = -351.0955372058672
# Resetting environment...
# Episode 460, step 34500, win = False, reward = -171.4127843178091
# Resetting environment...
# Episode 461, step 34575, win = False, reward = -210.09692130989762
# Resetting environment...
# Episode 462, step 34650, win = False, reward = -158.78045925422182
# Resetting environment...
# Episode 463, step 34725, win = False, reward = -199.1910843837728
# Resetting environment...
# Episode 464, step 34800, win = False, reward = -257.15722273886644
# Resetting environment...
# Episode 465, step 34875, win = False, reward = -174.36871532187433
# Resetting environment...
# Episode 466, step 34950, win = False, reward = -186.71798071605042
# Resetting environment...
# Episode 467, step 35025, win = False, reward = -245.63136415092825
# Resetting environment...
# Episode 468, step 35100, win = False, reward = -320.3577485864855
# Resetting environment...
# Episode 469, step 35175, win = False, reward = -125.60835691959447
# Resetting environment...
# Episode 470, step 35250, win = False, reward = -229.10673807313026
# Resetting environment...
# Episode 471, step 35325, win = False, reward = -214.52685168488273
# Resetting environment...
# Episode 472, step 35400, win = False, reward = -123.30489938090236
# Resetting environment...
# Episode 473, step 35475, win = False, reward = -207.08268237728882
# Resetting environment...
# Episode 474, step 35550, win = False, reward = -198.31398401197288
# Resetting environment...
# Episode 475, step 35625, win = False, reward = -296.62160317132367
# Resetting environment...
# Episode 476, step 35700, win = False, reward = -171.37581863629035
# Resetting environment...
# Episode 477, step 35775, win = False, reward = -199.97438506026705
# Resetting environment...
# Episode 478, step 35850, win = False, reward = -334.7092319715148
# Resetting environment...
# Episode 479, step 35925, win = False, reward = -189.2682340557059
# Resetting environment...
# Episode 480, step 36000, win = False, reward = -166.12870190742507
# Resetting environment...
# Episode 481, step 36075, win = False, reward = -110.0744560002215
# Resetting environment...
# Episode 482, step 36150, win = False, reward = -112.35994047582568
# Resetting environment...
# Episode 483, step 36225, win = False, reward = -182.74400227488286
# Resetting environment...
# Episode 484, step 36300, win = False, reward = -121.17526194514753
# Resetting environment...
# Episode 485, step 36375, win = False, reward = -185.50958235307098
# Resetting environment...
# Episode 486, step 36450, win = False, reward = -298.85345010082074
# Resetting environment...
# Episode 487, step 36525, win = False, reward = -104.41459924183401
# Resetting environment...
# Episode 488, step 36600, win = False, reward = -160.94107829906812
# Resetting environment...
# Episode 489, step 36675, win = False, reward = -146.43647554136865
# Resetting environment...
# Episode 490, step 36750, win = False, reward = -211.30637710290753
# Resetting environment...
# Episode 491, step 36825, win = False, reward = -192.84328904005145
# Resetting environment...
# Episode 492, step 36900, win = False, reward = -174.2044717271953
# Resetting environment...
# Episode 493, step 36975, win = False, reward = -99.90264061317029
# Resetting environment...
# Episode 494, step 37050, win = False, reward = -218.00056243175734
# Resetting environment...
# Episode 495, step 37125, win = False, reward = -157.0428897376957
# Resetting environment...
# Episode 496, step 37200, win = False, reward = -256.72315831003687
# Resetting environment...
# Episode 497, step 37275, win = False, reward = -189.3156717331755
# Resetting environment...
# Episode 498, step 37350, win = False, reward = -100.12603660681422
# Resetting environment...
# ...
# Episode 26518, step 1988850, win = False, reward = -38.347543849500696
# Resetting environment...
# Episode 26519, step 1988925, win = False, reward = -165.16721369576175
# Resetting environment...
# Episode 26520, step 1989000, win = False, reward = -116.88883473500744
# Resetting environment...
# Episode 26521, step 1989075, win = False, reward = -112.72932085354277
# Resetting environment...
# Episode 26522, step 1989150, win = False, reward = -78.61885422538157
# Resetting environment...
# Episode 26523, step 1989225, win = False, reward = -38.54953848181681
# Resetting environment...
# Episode 26524, step 1989300, win = False, reward = -43.61274631303142
# Resetting environment...
# Episode 26525, step 1989375, win = False, reward = -85.95227576860073
# Resetting environment...
# Episode 26526, step 1989450, win = False, reward = -69.47847413542897
# Resetting environment...
# Episode 26527, step 1989525, win = False, reward = -83.05956420891407
# Resetting environment...
# Episode 26528, step 1989600, win = False, reward = -29.57903245841194
# Resetting environment...
# Episode 26529, step 1989675, win = False, reward = -121.17198788900303
# Resetting environment...
# Episode 26530, step 1989750, win = False, reward = -159.75438643369972
# Resetting environment...
# Episode 26531, step 1989825, win = False, reward = -63.6604976350162
# Resetting environment...
# Episode 26532, step 1989900, win = False, reward = -76.85742470239494
# Resetting environment...
# Episode 26533, step 1989975, win = False, reward = -128.04585530769498
# Resetting environment...
# Episode 26534, step 1990050, win = False, reward = -62.057169416823655
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Test reward = -93.33331949488246, win_rate = 0.0
# Resetting environment...
# Episode 26535, step 1990125, win = False, reward = -172.69576899881912
# Resetting environment...
# Episode 26536, step 1990200, win = False, reward = -82.05023923852316
# Resetting environment...
# Episode 26537, step 1990275, win = False, reward = -53.72932471660076
# Resetting environment...
# Episode 26538, step 1990350, win = False, reward = -92.35194153444806
# Resetting environment...
# Episode 26539, step 1990425, win = False, reward = -48.903932461180524
# Resetting environment...
# Episode 26540, step 1990500, win = False, reward = -40.72139942999172
# Resetting environment...
# Episode 26541, step 1990575, win = False, reward = -102.36978129952178
# Resetting environment...
# Episode 26542, step 1990650, win = False, reward = -122.34258175681941
# Resetting environment...
# Episode 26543, step 1990725, win = False, reward = -74.82285106503335
# Resetting environment...
# Episode 26544, step 1990800, win = False, reward = -66.90215187525666
# Resetting environment...
# Episode 26545, step 1990875, win = False, reward = -187.13737459516605
# Resetting environment...
# Episode 26546, step 1990950, win = False, reward = -117.33511187891929
# Resetting environment...
# Episode 26547, step 1991025, win = False, reward = -123.71258516624472
# Resetting environment...
# Episode 26548, step 1991100, win = False, reward = -86.23962264642019
# Resetting environment...
# Episode 26549, step 1991175, win = False, reward = -127.531661403164
# Resetting environment...
# Episode 26550, step 1991250, win = False, reward = -65.209732712924
# Resetting environment...
# Episode 26551, step 1991325, win = False, reward = -84.53860159394071
# Resetting environment...
# Episode 26552, step 1991400, win = False, reward = -115.02361937860377
# Resetting environment...
# Episode 26553, step 1991475, win = False, reward = -87.06666831299391
# Resetting environment...
# Episode 26554, step 1991550, win = False, reward = -96.07043502534736
# Resetting environment...
# Episode 26555, step 1991625, win = False, reward = -135.39350226199235
# Resetting environment...
# Episode 26556, step 1991700, win = False, reward = -62.645456080342015
# Resetting environment...
# Episode 26557, step 1991775, win = False, reward = -146.94938418792427
# Resetting environment...
# Episode 26558, step 1991850, win = False, reward = -67.84997590134714
# Resetting environment...
# Episode 26559, step 1991925, win = False, reward = -111.77591024450324
# Resetting environment...
# Episode 26560, step 1992000, win = False, reward = -72.55330877311846
# Resetting environment...
# Episode 26561, step 1992075, win = False, reward = -138.48112661693776
# Resetting environment...
# Episode 26562, step 1992150, win = False, reward = -161.3087385814797
# Resetting environment...
# Episode 26563, step 1992225, win = False, reward = -159.6765173464763
# Resetting environment...
# Episode 26564, step 1992300, win = False, reward = -42.80820517632623
# Resetting environment...
# Episode 26565, step 1992375, win = False, reward = -53.06539040404648
# Resetting environment...
# Episode 26566, step 1992450, win = False, reward = -122.58764418692449
# Resetting environment...
# Episode 26567, step 1992525, win = False, reward = -122.00341829664302
# Resetting environment...
# Episode 26568, step 1992600, win = False, reward = -103.63315014942565
# Resetting environment...
# Episode 26569, step 1992675, win = False, reward = -136.69083320112685
# Resetting environment...
# Episode 26570, step 1992750, win = False, reward = -95.24153333431013
# Resetting environment...
# Episode 26571, step 1992825, win = False, reward = -142.98732934429412
# Resetting environment...
# Episode 26572, step 1992900, win = False, reward = -133.49661146269256
# Resetting environment...
# Episode 26573, step 1992975, win = False, reward = -117.21678754583702
# Resetting environment...
# Episode 26574, step 1993050, win = False, reward = -124.747946330479
# Resetting environment...
# Episode 26575, step 1993125, win = False, reward = -151.0284986778873
# Resetting environment...
# Episode 26576, step 1993200, win = False, reward = -129.28372720871872
# Resetting environment...
# Episode 26577, step 1993275, win = False, reward = -67.20115482911959
# Resetting environment...
# Episode 26578, step 1993350, win = False, reward = -27.77377956409487
# Resetting environment...
# Episode 26579, step 1993425, win = False, reward = -78.84152397060059
# Resetting environment...
# Episode 26580, step 1993500, win = False, reward = -41.403088292710294
# Resetting environment...
# Episode 26581, step 1993575, win = False, reward = -42.40882889767775
# Resetting environment...
# Episode 26582, step 1993650, win = False, reward = -114.52886880507472
# Resetting environment...
# Episode 26583, step 1993725, win = False, reward = -102.164390668837
# Resetting environment...
# Episode 26584, step 1993800, win = False, reward = -98.20783572825232
# Resetting environment...
# Episode 26585, step 1993875, win = False, reward = -40.286223997016556
# Resetting environment...
# Episode 26586, step 1993950, win = False, reward = -111.61261329365813
# Resetting environment...
# Episode 26587, step 1994025, win = False, reward = -94.09606086152625
# Resetting environment...
# Episode 26588, step 1994100, win = False, reward = -85.68562028509996
# Resetting environment...
# Episode 26589, step 1994175, win = False, reward = -51.540661877766425
# Resetting environment...
# Episode 26590, step 1994250, win = False, reward = -101.56449196140912
# Resetting environment...
# Episode 26591, step 1994325, win = False, reward = -191.03661632013694
# Resetting environment...
# Episode 26592, step 1994400, win = False, reward = -100.36821741746516
# Resetting environment...
# Episode 26593, step 1994475, win = False, reward = -84.94183158111878
# Resetting environment...
# Episode 26594, step 1994550, win = False, reward = -44.49493495607482
# Resetting environment...
# Episode 26595, step 1994625, win = False, reward = -181.58033698659534
# Resetting environment...
# Episode 26596, step 1994700, win = False, reward = -114.42550009582956
# Resetting environment...
# Episode 26597, step 1994775, win = False, reward = -55.97814751086972
# Resetting environment...
# Episode 26598, step 1994850, win = False, reward = -96.87887606660536
# Resetting environment...
# Episode 26599, step 1994925, win = False, reward = -63.41859128005843
# Resetting environment...
# Episode 26600, step 1995000, win = False, reward = -104.20912062033575
# Resetting environment...
# Episode 26601, step 1995075, win = False, reward = -49.906211173746904
# Resetting environment...
# Episode 26602, step 1995150, win = False, reward = -104.24812925873357
# Resetting environment...
# Episode 26603, step 1995225, win = False, reward = -38.927007944943696
# Resetting environment...
# Episode 26604, step 1995300, win = False, reward = -77.63838082085101
# Resetting environment...
# Episode 26605, step 1995375, win = False, reward = -157.44546962269172
# Resetting environment...
# Episode 26606, step 1995450, win = False, reward = -192.15567862935487
# Resetting environment...
# Episode 26607, step 1995525, win = False, reward = -110.90177624163972
# Resetting environment...
# Episode 26608, step 1995600, win = False, reward = -68.69410272294202
# Resetting environment...
# Episode 26609, step 1995675, win = False, reward = -141.58755873617898
# Resetting environment...
# Episode 26610, step 1995750, win = False, reward = -74.4954299741078
# Resetting environment...
# Episode 26611, step 1995825, win = False, reward = -62.68685306039061
# Resetting environment...
# Episode 26612, step 1995900, win = False, reward = -55.683571882008074
# Resetting environment...
# Episode 26613, step 1995975, win = False, reward = -125.7940801657941
# Resetting environment...
# Episode 26614, step 1996050, win = False, reward = -133.1043328265634
# Resetting environment...
# Episode 26615, step 1996125, win = False, reward = -26.698701407561614
# Resetting environment...
# Episode 26616, step 1996200, win = False, reward = -29.232807764061896
# Resetting environment...
# Episode 26617, step 1996275, win = False, reward = -38.847901227599
# Resetting environment...
# Episode 26618, step 1996350, win = False, reward = -51.07716295058967
# Resetting environment...
# Episode 26619, step 1996425, win = False, reward = -106.12382709718176
# Resetting environment...
# Episode 26620, step 1996500, win = False, reward = -80.40711773492195
# Resetting environment...
# Episode 26621, step 1996575, win = False, reward = -65.58637723322828
# Resetting environment...
# Episode 26622, step 1996650, win = False, reward = -120.25773099177917
# Resetting environment...
# Episode 26623, step 1996725, win = False, reward = -87.34888170639391
# Resetting environment...
# Episode 26624, step 1996800, win = False, reward = -96.58076409304532
# Resetting environment...
# Episode 26625, step 1996875, win = False, reward = -85.60974714582686
# Resetting environment...
# Episode 26626, step 1996950, win = False, reward = -60.1169579159995
# Resetting environment...
# Episode 26627, step 1997025, win = False, reward = -100.04943223093004
# Resetting environment...
# Episode 26628, step 1997100, win = False, reward = -114.80035335739674
# Resetting environment...
# Episode 26629, step 1997175, win = False, reward = -101.8196814297293
# Resetting environment...
# Episode 26630, step 1997250, win = False, reward = -83.78190272050173
# Resetting environment...
# Episode 26631, step 1997325, win = False, reward = -71.69462715265288
# Resetting environment...
# Episode 26632, step 1997400, win = False, reward = -124.17896024678052
# Resetting environment...
# Episode 26633, step 1997475, win = False, reward = -88.07849084125212
# Resetting environment...
# Episode 26634, step 1997550, win = False, reward = -114.26531270142873
# Resetting environment...
# Episode 26635, step 1997625, win = False, reward = -137.7498724193819
# Resetting environment...
# Episode 26636, step 1997700, win = False, reward = -65.71583240499703
# Resetting environment...
# Episode 26637, step 1997775, win = False, reward = -124.2487268067787
# Resetting environment...
# Episode 26638, step 1997850, win = False, reward = -42.18562182980765
# Resetting environment...
# Episode 26639, step 1997925, win = False, reward = -36.129212183567546
# Resetting environment...
# Episode 26640, step 1998000, win = False, reward = -143.3199619526521
# Resetting environment...
# Episode 26641, step 1998075, win = False, reward = -66.72993574723026
# Resetting environment...
# Episode 26642, step 1998150, win = False, reward = -60.64364081501569
# Resetting environment...
# Episode 26643, step 1998225, win = False, reward = -134.98432390820605
# Resetting environment...
# Episode 26644, step 1998300, win = False, reward = -94.28133481894825
# Resetting environment...
# Episode 26645, step 1998375, win = False, reward = -127.89048564125389
# Resetting environment...
# Episode 26646, step 1998450, win = False, reward = -102.05913696299822
# Resetting environment...
# Episode 26647, step 1998525, win = False, reward = -39.58821775351412
# Resetting environment...
# Episode 26648, step 1998600, win = False, reward = -116.69063285777924
# Resetting environment...
# Episode 26649, step 1998675, win = False, reward = -69.54455400062689
# Resetting environment...
# Episode 26650, step 1998750, win = False, reward = -123.79926910988894
# Resetting environment...
# Episode 26651, step 1998825, win = False, reward = -86.98904984981141
# Resetting environment...
# Episode 26652, step 1998900, win = False, reward = -37.68886164860428
# Resetting environment...
# Episode 26653, step 1998975, win = False, reward = -82.04507719712436
# Resetting environment...
# Episode 26654, step 1999050, win = False, reward = -59.00621032200038
# Resetting environment...
# Episode 26655, step 1999125, win = False, reward = -141.80701469466732
# Resetting environment...
# Episode 26656, step 1999200, win = False, reward = -87.51786073459606
# Resetting environment...
# Episode 26657, step 1999275, win = False, reward = -58.71599998882414
# Resetting environment...
# Episode 26658, step 1999350, win = False, reward = -168.49015378004145
# Resetting environment...
# Episode 26659, step 1999425, win = False, reward = -81.40162675265863
# Resetting environment...
# Episode 26660, step 1999500, win = False, reward = -61.89974808584043
# Resetting environment...
# Episode 26661, step 1999575, win = False, reward = -61.58243508364238
# Resetting environment...
# Episode 26662, step 1999650, win = False, reward = -42.80848566154203
# Resetting environment...
# Episode 26663, step 1999725, win = False, reward = -143.94193601087622
# Resetting environment...
# Episode 26664, step 1999800, win = False, reward = -107.16931802845335
# Resetting environment...
# Episode 26665, step 1999875, win = False, reward = -30.03565255213313
# Resetting environment...
# Episode 26666, step 1999950, win = False, reward = -176.33969302661194
# Resetting environment...
# Episode 26667, step 2000025, win = False, reward = -100.37123069874863
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Resetting environment...
# Test reward = -90.13106213022989, win_rate = 0.0

# %%
import torch
import imageio
import numpy as np
from pettingzoo.mpe import simple_spread_v3

# Model Actor
class Actor(torch.nn.Module):
    def __init__(self):
        super(Actor, self).__init__()
        self.input_dim = 23
        self.hidden_dim = 64
        self.n_actions = 5
        self.fc1 = torch.nn.Linear(self.input_dim, self.hidden_dim)
        self.rnn = torch.nn.GRUCell(self.hidden_dim, self.hidden_dim)
        self.fc2 = torch.nn.Linear(self.hidden_dim, self.n_actions)

    def init_hidden(self, batch_size):
        return torch.zeros(batch_size, self.hidden_dim)

    def forward(self, inputs, avail_actions, h_last):
        x = torch.relu(self.fc1(inputs))
        h = self.rnn(x, h_last)
        q_values = self.fc2(h)
        q_values[avail_actions == 0] = -float('inf')
        probabilities = torch.nn.functional.softmax(q_values, dim=-1)
        return probabilities, h

# Funkcja rozszerzająca obserwacje
def augment_observation(obs, agent_id, n_agents):
    agent_id_one_hot = np.eye(n_agents)[agent_id]  # One-hot encoding agenta
    return np.concatenate([obs, agent_id_one_hot])

# Funkcja usuwająca prefiks
def remove_prefix_from_state_dict(state_dict, prefix="agent."):
    return {key[len(prefix):] if key.startswith(prefix) else key: value for key, value in state_dict.items()}

# Wizualizator
class AgentVisualizer:
    def __init__(self, actor, env, device='cpu'):
        self.device = torch.device(device)
        self.env = env
        self.actor = actor.to(self.device)
        self.actor.eval()
        self.n_agents = len(env.possible_agents)

    def run_episode(self, save_gif=True, gif_path='trained_agent_demo.gif'):
        frames = []
        obs, infos = self.env.reset(seed=42)
        hidden_state = self.actor.init_hidden(1).to(self.device)
        done = False

        while not done:
            actions = {}
            with torch.no_grad():
                for idx, agent_id in enumerate(self.env.agents):
                    obs_tensor = augment_observation(
                        obs[agent_id], agent_id=idx, n_agents=self.n_agents
                    )
                    obs_tensor = torch.tensor(obs_tensor, dtype=torch.float32).unsqueeze(0).to(self.device)
                    avail_actions = torch.ones((1, self.actor.n_actions), device=self.device)
                    probabilities, hidden_state = self.actor.forward(obs_tensor, avail_actions, hidden_state)
                    actions[agent_id] = torch.argmax(probabilities, dim=-1).item()

            next_obs, rewards, terminations, truncations, infos = self.env.step(actions)
            done = all(terminations.values()) or all(truncations.values())
            frames.append(self.env.render())

            obs = next_obs

        if save_gif:
            imageio.mimsave(gif_path, frames, fps=60)
            print(f"Zapisano epizod jako GIF: {gif_path}")

# Załaduj model
actor_path = "results/A_Final_simple_referenece_3e-4.tar"
state_dict = torch.load(actor_path, map_location='cpu')
state_dict = remove_prefix_from_state_dict(state_dict)

actor = Actor()
actor.load_state_dict(state_dict)

# Środowisko
env = simple_reference_v3.parallel_env(
    local_ratio=0.5,
    max_cycles=75,
    continuous_actions=False,
    render_mode="rgb_array"
)

# Wizualizacja
visualizer = AgentVisualizer(actor=actor, env=env, device='cuda' if torch.cuda.is_available() else 'cpu')
visualizer.run_episode(save_gif=True, gif_path='trained_agent_reference.gif')
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[20], line 76
#      74 # Załaduj model
#      75 actor_path = "results/A_Final_simple_referenece_3e-4.npy"
# ---> 76 state_dict = torch.load(actor_path, map_location='cpu')
#      77 state_dict = remove_prefix_from_state_dict(state_dict)
#      79 actor = Actor()
#
# File ~/miniconda/envs/drlzh/lib/python3.11/site-packages/torch/serialization.py:1040, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1038     except RuntimeError as e:
#    1039         raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# -> 1040 return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#
# File ~/miniconda/envs/drlzh/lib/python3.11/site-packages/torch/serialization.py:1258, in _legacy_load(f, map_location, pickle_module, **pickle_load_args)
#    1252 if not hasattr(f, 'readinto') and (3, 8, 0) <= sys.version_info < (3, 8, 2):
#    1253     raise RuntimeError(
#    1254         "torch.load does not work with file-like objects that do not implement readinto on Python 3.8.0 and 3.8.1. "
#    1255         f"Received object of type \"{type(f)}\". Please update to Python 3.8.2 or newer to restore this "
#    1256         "functionality.")
# -> 1258 magic_number = pickle_module.load(f, **pickle_load_args)
#    1259 if magic_number != MAGIC_NUMBER:
#    1260     raise RuntimeError("Invalid magic number; corrupt file?")
#
# UnpicklingError: unpickling stack underflow
